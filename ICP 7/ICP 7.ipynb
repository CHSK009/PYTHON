# %%
import sys
import requests
from bs4 import BeautifulSoup

# %%
urls =["https://en.wikipedia.org/wiki/Google"]
text="input"
list = ['h1', 'h2', 'h3', 'p', 'a', 'ul', 'span', 'input']

with open(str(text) +'.txt','w',encoding='utf-8') as outfile:
    for url in urls:
        website = requests.get(url)
        soup = BeautifulSoup(website.content, "lxml")
        tags = soup.find_all(list)
        text = ["".join(s.findAll(text=True)) for s in tags]
        for item in text:
            print(item, file=outfile)

    print("Done! File is saved where you have your scrape-website.py")
# Out:
# Done! File is saved where you have your scrape-website.py

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     C:\Users\KRISH\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all
# True

# %%
from nltk.tokenize import sent_tokenize,word_tokenize
with open('input.txt','r',encoding="utf8") as myfile:
    data=myfile.read().replace('\n','  ')
    print(data)
# Out:
#     Google  Jump to navigation  Jump to search  Google Search  Google (disambiguation)  Googol            [update]    Googleplex  Type  Subsidiary  InternetCloud computingComputer softwareComputer hardwareArtificial intelligenceAdvertising  Internet  Cloud computing  Computer software  Computer hardware  Artificial intelligence  Advertising  ; 20 years ago   (1998-09-04)  1998-09-04  Menlo Park  Larry PageSergey Brin  Larry Page  Sergey Brin  Mountain View, California  Sundar Pichai (CEO)Ruth Porat (CFO)  Sundar Pichai  CEO  Ruth Porat  CFO  List of Google products  [update]  Parent  Alphabet Inc.  Subsidiaries  List of subsidiaries  google.com  google.com  [1]  [2]  [3]  [4]  Google LLC[5] is an American multinational technology company that specializes in Internet-related services and products, which include online advertising technologies, search engine, cloud computing, software, and hardware. It is considered one of the Big Four technology companies, alongside Amazon, Apple and Facebook.[6][7]    [5]  online advertising technologies  search engine  cloud computing  Big Four  Amazon  Apple  Facebook  [6]  [7]  Google was founded in 1998 by Larry Page and Sergey Brin while they were Ph.D. students at Stanford University in California. Together they own about 14 percent of its shares and control 56 percent of the stockholder voting power through supervoting stock. They incorporated Google as a privately held company on September 4, 1998. An initial public offering (IPO) took place on August 19, 2004, and Google moved to its headquarters in Mountain View, California, nicknamed the Googleplex. In August 2015, Google announced plans to reorganize its various interests as a conglomerate called Alphabet Inc. Google is Alphabet's leading subsidiary and will continue to be the umbrella company for Alphabet's Internet interests. Sundar Pichai was appointed CEO of Google, replacing Larry Page who became the CEO of Alphabet.    Larry Page  Sergey Brin  Stanford University  California  supervoting  Googleplex  Alphabet Inc.  Sundar Pichai  The company's rapid growth since incorporation has triggered a chain of products, acquisitions, and partnerships beyond Google's core search engine (Google Search). It offers services designed for work and productivity (Google Docs, Google Sheets, and Google Slides), email (Gmail/Inbox), scheduling and time management (Google Calendar), cloud storage (Google Drive), instant messaging and video chat (Google Allo, Duo, Hangouts), language translation (Google Translate), mapping and navigation (Google Maps, Waze, Google Earth, Street View), video sharing (YouTube), note-taking (Google Keep), and photo organizing and editing (Google Photos). The company leads the development of the Android mobile operating system, the Google Chrome web browser, and Chrome OS, a lightweight operating system based on the Chrome browser. Google has moved increasingly into hardware; from 2010 to 2015, it partnered with major electronics manufacturers in the production of its Nexus devices, and it released multiple hardware products in October 2016, including the Google Pixel smartphone, Google Home smart speaker, Google Wifi mesh wireless router, and Google Daydream virtual reality headset. Google has also experimented with becoming an Internet carrier (Google Fiber, Google Fi, and Google Station).[8]    Google Search  Google Docs  Google Sheets  Google Slides  Gmail  Inbox  Google Calendar  Google Drive  Google Allo  Duo  Hangouts  Google Translate  Google Maps  Waze  Google Earth  Street View  YouTube  Google Keep  Google Photos  Android  Google Chrome  Chrome OS  Nexus  Google Pixel  Google Home  Google Wifi  Google Daydream  Google Fiber  Google Fi  Google Station  [8]  Google.com is the most visited website in the world.[9] Several other Google services also figure in the top 100 most visited websites, including YouTube and Blogger. Google was the most valuable brand in the world as of 2017,[update][10] but has received ...

# %%
tokens=word_tokenize(data)
pos=nltk.pos_tag(tokens)
print(tokens[0:10])
print(pos[0:10])
# Out:
# ['Google', 'Jump', 'to', 'navigation', 'Jump', 'to', 'search', 'Google', 'Search', 'Google']
# [('Google', 'NNP'), ('Jump', 'NNP'), ('to', 'TO'), ('navigation', 'VB'), ('Jump', 'NNP'), ('to', 'TO'), ('search', 'VB'), ('Google', 'NNP'), ('Search', 'NNP'), ('Google', 'NNP')]

# %%
from nltk.stem import PorterStemmer
ps=PorterStemmer()
for w in tokens:
    print(w,":",ps.stem(w))
# Out:
# Google : googl
# Jump : jump
# to : to
# navigation : navig
# Jump : jump
# to : to
# search : search
# Google : googl
# Search : search
# Google : googl
# ( : (
# disambiguation : disambigu
# ) : )
# Googol : googol
# [ : [
# update : updat
# ] : ]
# Googleplex : googleplex
# Type : type
# Subsidiary : subsidiari
# InternetCloud : internetcloud
# computingComputer : computingcomput
# softwareComputer : softwarecomput
# hardwareArtificial : hardwareartifici
# intelligenceAdvertising : intelligenceadvertis
# Internet : internet
# Cloud : cloud
# computing : comput
# Computer : comput
# software : softwar
# Computer : comput
# hardware : hardwar
# Artificial : artifici
# intelligence : intellig
# Advertising : advertis
# ; : ;
# 20 : 20
# years : year
# ago : ago
# ( : (
# 1998-09-04 : 1998-09-04
# ) : )
# 1998-09-04 : 1998-09-04
# Menlo : menlo
# Park : park
# Larry : larri
# PageSergey : pagesergey
# Brin : brin
# Larry : larri
# Page : page
# Sergey : sergey
# Brin : brin
# Mountain : mountain
# View : view
# , : ,
# California : california
# Sundar : sundar
# Pichai : pichai
# ( : (
# CEO : ceo
# ) : )
# Ruth : ruth
# Porat : porat
# ( : (
# CFO : cfo
# ) : )
# Sundar : sundar
# Pichai : pichai
# CEO : ceo
# Ruth : ruth
# Porat : porat
# CFO : cfo
# List : list
# of : of
# Google : googl
# products : product
# [ : [
# update : updat
# ] : ]
# Parent : parent
# Alphabet : alphabet
# Inc. : inc.
# Subsidiaries : subsidiari
# List : list
# of : of
# subsidiaries : subsidiari
# google.com : google.com
# google.com : google.com
# [ : [
# 1 : 1
# ] : ]
# [ : [
# 2 : 2
# ] : ]
# [ : [
# 3 : 3
# ] : ]
# [ : [
# 4 : 4
# ] : ]
# Google : googl
# LLC : llc
# [ : [
# 5 : 5
# ] : ]
# is : is
# an : an
# American : american
# multinational : multin
# technology : technolog
# company : compani
# that : that
# specializes : special
# in : in
# Internet-related : internet-rel
# services : servic
# and : and
# products : product
# , : ,
# which : which
# include : includ
# online : onlin
# advertising : advertis
# technologies : technolog
# , : ,
# search : search
# engine : engin
# , : ,
# cloud : cloud
# computing : comput
# , : ,
# software : softwar
# , : ,
# and : and
# hardware : hardwar
# . : .
# It : It
# is : is
# considered : consid
# one : one
# of : of
# the : the
# Big : big
# Four : four
# technology : technolog
# companies : compani
# , : ,
# alongside : alongsid
# Amazon : amazon
# , : ,
# Apple : appl
# and : and
# Facebook : facebook
# . : .
# [ : [
# 6 : 6
# ] : ]
# [ : [
# 7 : 7
# ] : ]
# [ : [
# 5 : 5
# ] : ]
# online : onlin
# advertising : advertis
# technologies : technolog
# search : search
# engine : engin
# cloud : cloud
# computing : comput
# Big : big
# Four : four
# Amazon : amazon
# Apple : appl
# Facebook : facebook
# [ : [
# 6 : 6
# ] : ]
# [ : [
# 7 : 7
# ] : ]
# Google : googl
# was : wa
# founded : found
# in : in
# 1998 : 1998
# by : by
# Larry : larri
# Page : page
# and : and
# Sergey : sergey
# Brin : brin
# while : while
# they : they
# were : were
# Ph.D. : ph.d.
# students : student
# at : at
# Stanford : stanford
# University : univers
# in : in
# California : california
# . : .
# Together : togeth
# they : they
# own : own
# about : about
# 14 : 14
# percent : percent
# of : of
# its : it
# shares : share
# and : and
# control : control
# 56 : 56
# percent : percent
# of : of
# the : the
# stockholder : stockhold
# voting : vote
# power : power
# through : through
# supervoting : supervot
# stock : stock
# . : .
# They : they
# incorporated : incorpor
# Google : googl
# as : as
# a : a
# privately : privat
# held : held
# company : compani
# on : on
# September : septemb
# 4 : 4
# , : ,
# 1998 : 1998
# . : .
# An : An
# initial : initi
# public : public
# offering : offer
# ( : (
# IPO : ipo
# ) : )
# took : took
# place : place
# on : on
# August : august
# 19 : 19
# , : ,
# 2004 : 2004
# , : ,
# and : and
# Google : googl
# moved : move
# to : to
# its : it
# headquarters : headquart
# in : in
# Mountain : mountain
# View : view
# , : ,
# California : california
# , : ,
# nicknamed : nicknam
# the : the
# Googleplex : googleplex
# . : .
# In : In
# August : august
# 2015 : 2015
# , : ,
# Google : googl
# announced : announc
# plans : plan
# to : to
# reorganize : reorgan
# its : it
# various : variou
# interests : interest
# as : as
# a : a
# conglomerate : conglomer
# called : call
# Alphabet : alphabet
# Inc. : inc.
# Google : googl
# is : is
# Alphabet : alphabet
# 's : 's
# leading : lead
# subsidiary : subsidiari
# and : and
# will : will
# continue : continu
# to : to
# be : be
# the : the
# umbrella : umbrella
# company : compani
# for : for
# Alphabet : alphabet
# 's : 's
# Internet : internet
# interests : interest
# . : .
# Sundar : sundar
# Pichai : pichai
# was : wa
# appointed : appoint
# CEO : ceo
# of : of
# Google : googl
# , : ,
# replacing : replac
# Larry : larri
# Page : page
# who : who
# became : becam
# the : the
# CEO : ceo
# of : of
# Alphabet : alphabet
# . : .
# Larry : larri
# Page : page
# Sergey : sergey
# Brin : brin
# Stanford : stanford
# University : univers
# California : california
# supervoting : supervot
# Googleplex : googleplex
# Alphabet : alphabet
# Inc. : inc.
# Sundar : sundar
# Pichai : pichai
# The : the
# company : compani
# 's : 's
# rapid : rapid
# growth : growth
# since : sinc
# incorporation : incorpor
# has : ha
# triggered : trigger
# a : a
# chain : chain
# of : of
# products : product
# , : ,
# acquisitions : acquisit
# , : ,
# and : and
# partnerships : partnership
# beyond : beyond
# Google : googl
# 's : 's
# core : core
# search : search
# engine : engin
# ( : (
# Google : googl
# Search : search
# ) : )
# . : .
# It : It
# offers : offer
# services : servic
# designed : design
# for : for
# work : work
# and : and
# productivity : product
# ( : (
# Google : googl
# Docs : doc
# , : ,
# Google : googl
# Sheets : sheet
# , : ,
# and : and
# Google : googl
# Slides : slide
# ) : )
# , : ,
# email : email
# ( : (
# Gmail/Inbox : gmail/inbox
# ) : )
# , : ,
# scheduling : schedul
# and : and
# time : time
# management : manag
# ( : (
# Google : googl
# Calendar : calendar
# ) : )
# , : ,
# cloud : cloud
# storage : storag
# ( : (
# Google : googl
# Drive : drive
# ) : )
# , : ,
# instant : instant
# messaging : messag
# and : and
# video : video
# chat : chat
# ( : (
# Google : googl
# Allo : allo
# , : ,
# Duo : duo
# , : ,
# Hangouts : hangout
# ) : )
# , : ,
# language : languag
# translation : translat
# ( : (
# Google : googl
# Translate : translat
# ) : )
# , : ,
# mapping : map
# and : and
# navigation : navig
# ( : (
# Google : googl
# Maps : map
# , : ,
# Waze : waze
# , : ,
# Google : googl
# Earth : earth
# , : ,
# Street : street
# View : view
# ) : )
# , : ,
# video : video
# sharing : share
# ( : (
# YouTube : youtub
# ) : )
# , : ,
# note-taking : note-tak
# ( : (
# Google : googl
# Keep : keep
# ) : )
# , : ,
# and : and
# photo : photo
# organizing : organ
# and : and
# editing : edit
# ( : (
# Google : googl
# Photos : photo
# ) : )
# . : .
# The : the
# company : compani
# leads : lead
# the : the
# development : develop
# of : of
# the : the
# Android : android
# mobile : mobil
# operating : oper
# system : system
# , : ,
# the : the
# Google : googl
# Chrome : chrome
# web : web
# browser : browser
# , : ,
# and : and
# Chrome : chrome
# OS : OS
# , : ,
# a : a
# lightweight : lightweight
# operating : oper
# system : system
# based : base
# on : on
# the : the
# Chrome : chrome
# browser : browser
# . : .
# Google : googl
# has : ha
# moved : move
# increasingly : increasingli
# into : into
# hardware : hardwar
# ; : ;
# from : from
# 2010 : 2010
# to : to
# 2015 : 2015
# , : ,
# it : it
# partnered : partner
# with : with
# major : major
# electronics : electron
# manufacturers : manufactur
# in : in
# the : the
# production : product
# of : of
# its : it
# Nexus : nexu
# devices : devic
# , : ,
# and : and
# it : it
# released : releas
# multiple : multipl
# hardware : hardwar
# products : product
# in : in
# October : octob
# 2016 : 2016
# , : ,
# including : includ
# the : the
# Google : googl
# Pixel : pixel
# smartphone : smartphon
# , : ,
# Google : googl
# Home : home
# smart : smart
# speaker : speaker
# , : ,
# Google : googl
# Wifi : wifi
# mesh : mesh
# wireless : wireless
# router : router
# , : ,
# and : and
# Google : googl
# Daydream : daydream
# virtual : virtual
# reality : realiti
# headset : headset
# . : .
# Google : googl
# has : ha
# also : also
# experimented : experi
# with : with
# becoming : becom
# an : an
# Internet : internet
# carrier : carrier
# ( : (
# Google : googl
# Fiber : fiber
# , : ,
# Google : googl
# Fi : Fi
# , : ,
# and : and
# Google : googl
# Station : station
# ) : )
# . : .
# [ : [
# 8 : 8
# ] : ]
# Google : googl
# Search : search
# Google : googl
# Docs : doc
# Google : googl
# Sheets : sheet
# Google : googl
# Slides : slide
# Gmail : gmail
# Inbox : inbox
# Google : googl
# Calendar : calendar
# Google : googl
# Drive : drive
# Google : googl
# Allo : allo
# Duo : duo
# Hangouts : hangout
# Google : googl
# Translate : translat
# Google : googl
# Maps : map
# Waze : waze
# Google : googl
# Earth : earth
# Street : street
# View : view
# YouTube : youtub
# Google : googl
# Keep : keep
# Google : googl
# Photos : photo
# Android : android
# Google : googl
# Chrome : chrome
# Chrome : chrome
# OS : OS
# Nexus : nexu
# Google : googl
# Pixel : pixel
# Google : googl
# Home : home
# Google : googl
# Wifi : wifi
# Google : googl
# Daydream : daydream
# Google : googl
# Fiber : fiber
# Google : googl
# Fi : Fi
# Google : googl
# Station : station
# [ : [
# 8 : 8
# ] : ]
# Google.com : google.com
# is : is
# the : the
# most : most
# visited : visit
# website : websit
# in : in
# the : the
# world : world
# . : .
# [ : [
# 9 : 9
# ] : ]
# Several : sever
# other : other
# Google : googl
# services : servic
# also : also
# figure : figur
# in : in
# the : the
# top : top
# 100 : 100
# most : most
# visited : visit
# websites : websit
# , : ,
# including : includ
# YouTube : youtub
# and : and
# Blogger : blogger
# . : .
# Google : googl
# was : wa
# the : the
# most : most
# valuable : valuabl
# brand : brand
# in : in
# the : the
# world : world
# as : as
# of : of
# 2017 : 2017
# , : ,
# [ : [
# update : updat
# ] : ]
# [ : [
# 10 : 10
# ] : ]
# but : but
# has : ha
# received : receiv
# significant : signific
# criticism : critic
# involving : involv
# issues : issu
# such : such
# as : as
# privacy : privaci
# concerns : concern
# , : ,
# tax : tax
# avoidance : avoid
# , : ,
# antitrust : antitrust
# , : ,
# censorship : censorship
# , : ,
# and : and
# search : search
# neutrality : neutral
# . : .
# Google : googl
# 's : 's
# mission : mission
# statement : statement
# is : is
# `` : ``
# to : to
# organize : organ
# the : the
# world : world
# 's : 's
# information : inform
# and : and
# make : make
# it : it
# universally : univers
# accessible : access
# and : and
# useful : use
# '' : ''
# . : .
# The : the
# company : compani
# 's : 's
# unofficial : unoffici
# slogan : slogan
# `` : ``
# Do : Do
# n't : n't
# be : be
# evil : evil
# '' : ''
# was : wa
# removed : remov
# from : from
# the : the
# company : compani
# 's : 's
# code : code
# of : of
# conduct : conduct
# around : around
# May : may
# 2018 : 2018
# , : ,
# but : but
# reinstated : reinstat
# by : by
# July : juli
# 31 : 31
# , : ,
# 2018 : 2018
# . : .
# [ : [
# 11 : 11
# ] : ]
# [ : [
# 12 : 12
# ] : ]
# [ : [
# 9 : 9
# ] : ]
# YouTube : youtub
# Blogger : blogger
# [ : [
# update : updat
# ] : ]
# [ : [
# 10 : 10
# ] : ]
# criticism : critic
# privacy : privaci
# concerns : concern
# censorship : censorship
# mission : mission
# statement : statement
# [ : [
# 11 : 11
# ] : ]
# [ : [
# 12 : 12
# ] : ]
# Contents : content
# 1 : 1
# History : histori
# 1.1 : 1.1
# Early : earli
# years : year
# 1.2 : 1.2
# Growth : growth
# 1.3 : 1.3
# Initial : initi
# public : public
# offering : offer
# 1.4 : 1.4
# 2012 : 2012
# onward : onward
# 2 : 2
# Products : product
# and : and
# services : servic
# 2.1 : 2.1
# Search : search
# engine : engin
# 2.2 : 2.2
# Advertising : advertis
# 2.3 : 2.3
# Consumer : consum
# services : servic
# 2.3.1 : 2.3.1
# Web-based : web-bas
# services : servic
# 2.3.2 : 2.3.2
# Software : softwar
# 2.3.3 : 2.3.3
# Hardware : hardwar
# 2.4 : 2.4
# Enterprise : enterpris
# services : servic
# 2.5 : 2.5
# Internet : internet
# services : servic
# 2.6 : 2.6
# Other : other
# products : product
# 3 : 3
# Corporate : corpor
# affairs : affair
# 3.1 : 3.1
# Finance : financ
# 3.2 : 3.2
# Corporate : corpor
# identity : ident
# 3.3 : 3.3
# Workplace : workplac
# culture : cultur
# 3.4 : 3.4
# Office : offic
# locations : locat
# 3.5 : 3.5
# Infrastructure : infrastructur
# 3.6 : 3.6
# Environment : environ
# 3.7 : 3.7
# Philanthropy : philanthropi
# 4 : 4
# Criticism : critic
# and : and
# controversy : controversi
# 4.1 : 4.1
# Litigation : litig
# 5 : 5
# See : see
# also : also
# 6 : 6
# References : refer
# 7 : 7
# Further : further
# reading : read
# 8 : 8
# External : extern
# links : link
# 1 : 1
# History : histori
# 1 : 1
# History : histori
# 1.1 : 1.1
# Early : earli
# years : year
# 1.2 : 1.2
# Growth : growth
# 1.3 : 1.3
# Initial : initi
# public : public
# offering : offer
# 1.4 : 1.4
# 2012 : 2012
# onward : onward
# 1.1 : 1.1
# Early : earli
# years : year
# 1.1 : 1.1
# Early : earli
# years : year
# 1.2 : 1.2
# Growth : growth
# 1.2 : 1.2
# Growth : growth
# 1.3 : 1.3
# Initial : initi
# public : public
# offering : offer
# 1.3 : 1.3
# Initial : initi
# public : public
# offering : offer
# 1.4 : 1.4
# 2012 : 2012
# onward : onward
# 1.4 : 1.4
# 2012 : 2012
# onward : onward
# 2 : 2
# Products : product
# and : and
# services : servic
# 2 : 2
# Products : product
# and : and
# services : servic
# 2.1 : 2.1
# Search : search
# engine : engin
# 2.2 : 2.2
# Advertising : advertis
# 2.3 : 2.3
# Consumer : consum
# services : servic
# 2.3.1 : 2.3.1
# Web-based : web-bas
# services : servic
# 2.3.2 : 2.3.2
# Software : softwar
# 2.3.3 : 2.3.3
# Hardware : hardwar
# 2.4 : 2.4
# Enterprise : enterpris
# services : servic
# 2.5 : 2.5
# Internet : internet
# services : servic
# 2.6 : 2.6
# Other : other
# products : product
# 2.1 : 2.1
# Search : search
# engine : engin
# 2.1 : 2.1
# Search : search
# engine : engin
# 2.2 : 2.2
# Advertising : advertis
# 2.2 : 2.2
# Advertising : advertis
# 2.3 : 2.3
# Consumer : consum
# services : servic
# 2.3 : 2.3
# Consumer : consum
# services : servic
# 2.3.1 : 2.3.1
# Web-based : web-bas
# services : servic
# 2.3.2 : 2.3.2
# Software : softwar
# 2.3.3 : 2.3.3
# Hardware : hardwar
# 2.3.1 : 2.3.1
# Web-based : web-bas
# services : servic
# 2.3.1 : 2.3.1
# Web-based : web-bas
# services : servic
# 2.3.2 : 2.3.2
# Software : softwar
# 2.3.2 : 2.3.2
# Software : softwar
# 2.3.3 : 2.3.3
# Hardware : hardwar
# 2.3.3 : 2.3.3
# Hardware : hardwar
# 2.4 : 2.4
# Enterprise : enterpris
# services : servic
# 2.4 : 2.4
# Enterprise : enterpris
# services : servic
# 2.5 : 2.5
# Internet : internet
# services : servic
# 2.5 : 2.5
# Internet : internet
# services : servic
# 2.6 : 2.6
# Other : other
# products : product
# 2.6 : 2.6
# Other : other
# products : product
# 3 : 3
# Corporate : corpor
# affairs : affair
# 3 : 3
# Corporate : corpor
# affairs : affair
# 3.1 : 3.1
# Finance : financ
# 3.2 : 3.2
# Corporate : corpor
# identity : ident
# 3.3 : 3.3
# Workplace : workplac
# culture : cultur
# 3.4 : 3.4
# Office : offic
# locations : locat
# 3.5 : 3.5
# Infrastructure : infrastructur
# 3.6 : 3.6
# Environment : environ
# 3.7 : 3.7
# Philanthropy : philanthropi
# 3.1 : 3.1
# Finance : financ
# 3.1 : 3.1
# Finance : financ
# 3.2 : 3.2
# Corporate : corpor
# identity : ident
# 3.2 : 3.2
# Corporate : corpor
# identity : ident
# 3.3 : 3.3
# Workplace : workplac
# culture : cultur
# 3.3 : 3.3
# Workplace : workplac
# culture : cultur
# 3.4 : 3.4
# Office : offic
# locations : locat
# 3.4 : 3.4
# Office : offic
# locations : locat
# 3.5 : 3.5
# Infrastructure : infrastructur
# 3.5 : 3.5
# Infrastructure : infrastructur
# 3.6 : 3.6
# Environment : environ
# 3.6 : 3.6
# Environment : environ
# 3.7 : 3.7
# Philanthropy : philanthropi
# 3.7 : 3.7
# Philanthropy : philanthropi
# 4 : 4
# Criticism : critic
# and : and
# controversy : controversi
# 4 : 4
# Criticism : critic
# and : and
# controversy : controversi
# 4.1 : 4.1
# Litigation : litig
# 4.1 : 4.1
# Litigation : litig
# 4.1 : 4.1
# Litigation : litig
# 5 : 5
# See : see
# also : also
# 5 : 5
# See : see
# also : also
# 6 : 6
# References : refer
# 6 : 6
# References : refer
# 7 : 7
# Further : further
# reading : read
# 7 : 7
# Further : further
# reading : read
# 8 : 8
# External : extern
# links : link
# 8 : 8
# External : extern
# links : link
# History : histori
# History : histori
# History : histori
# of : of
# Google : googl
# List : list
# of : of
# mergers : merger
# and : and
# acquisitions : acquisit
# by : by
# Alphabet : alphabet
# Alphabet : alphabet
# Inc : inc
# . : .
# Early : earli
# years : year
# Early : earli
# years : year
# Larry : larri
# Page : page
# Sergey : sergey
# Brin : brin
# Google : googl
# began : began
# in : in
# January : januari
# 1996 : 1996
# as : as
# a : a
# research : research
# project : project
# by : by
# Larry : larri
# Page : page
# and : and
# Sergey : sergey
# Brin : brin
# when : when
# they : they
# were : were
# both : both
# PhD : phd
# students : student
# at : at
# Stanford : stanford
# University : univers
# in : in
# Stanford : stanford
# , : ,
# California : california
# . : .
# [ : [
# 13 : 13
# ] : ]
# Larry : larri
# Page : page
# Sergey : sergey
# Brin : brin
# Stanford : stanford
# University : univers
# Stanford : stanford
# , : ,
# California : california
# [ : [
# 13 : 13
# ] : ]
# While : while
# conventional : convent
# search : search
# engines : engin
# ranked : rank
# results : result
# by : by
# counting : count
# how : how
# many : mani
# times : time
# the : the
# search : search
# terms : term
# appeared : appear
# on : on
# the : the
# page : page
# , : ,
# the : the
# two : two
# theorized : theoriz
# about : about
# a : a
# better : better
# system : system
# that : that
# analyzed : analyz
# the : the
# relationships : relationship
# among : among
# websites : websit
# . : .
# [ : [
# 14 : 14
# ] : ]
# They : they
# called : call
# this : thi
# algorithm : algorithm
# PageRank : pagerank
# ; : ;
# it : it
# determined : determin
# a : a
# website : websit
# 's : 's
# relevance : relev
# by : by
# the : the
# number : number
# of : of
# pages : page
# , : ,
# and : and
# the : the
# importance : import
# of : of
# those : those
# pages : page
# that : that
# linked : link
# back : back
# to : to
# the : the
# original : origin
# site : site
# . : .
# [ : [
# 15 : 15
# ] : ]
# [ : [
# 16 : 16
# ] : ]
# PageRank : pagerank
# was : wa
# influenced : influenc
# by : by
# a : a
# similar : similar
# page-ranking : page-rank
# and : and
# site-scoring : site-scor
# algorithm : algorithm
# earlier : earlier
# used : use
# for : for
# RankDex : rankdex
# , : ,
# developed : develop
# by : by
# Robin : robin
# Li : Li
# in : in
# 1996 : 1996
# , : ,
# with : with
# Larry : larri
# Page : page
# 's : 's
# PageRank : pagerank
# patent : patent
# including : includ
# a : a
# citation : citat
# to : to
# Li : Li
# 's : 's
# earlier : earlier
# RankDex : rankdex
# patent : patent
# ; : ;
# Li : Li
# later : later
# went : went
# on : on
# to : to
# create : creat
# the : the
# Chinese : chines
# search : search
# engine : engin
# Baidu : baidu
# . : .
# [ : [
# 17 : 17
# ] : ]
# [ : [
# 18 : 18
# ] : ]
# [ : [
# 19 : 19
# ] : ]
# [ : [
# 14 : 14
# ] : ]
# PageRank : pagerank
# relevance : relev
# [ : [
# 15 : 15
# ] : ]
# [ : [
# 16 : 16
# ] : ]
# RankDex : rankdex
# Robin : robin
# Li : Li
# Baidu : baidu
# [ : [
# 17 : 17
# ] : ]
# [ : [
# 18 : 18
# ] : ]
# [ : [
# 19 : 19
# ] : ]
# Page : page
# and : and
# Brin : brin
# originally : origin
# nicknamed : nicknam
# their : their
# new : new
# search : search
# engine : engin
# `` : ``
# BackRub : backrub
# '' : ''
# , : ,
# because : becaus
# the : the
# system : system
# checked : check
# backlinks : backlink
# to : to
# estimate : estim
# the : the
# importance : import
# of : of
# a : a
# site : site
# . : .
# [ : [
# 20 : 20
# ] : ]
# [ : [
# 21 : 21
# ] : ]
# [ : [
# 22 : 22
# ] : ]
# Eventually : eventu
# , : ,
# they : they
# changed : chang
# the : the
# name : name
# to : to
# Google : googl
# ; : ;
# the : the
# name : name
# of : of
# the : the
# search : search
# engine : engin
# originated : origin
# from : from
# a : a
# misspelling : misspel
# of : of
# the : the
# word : word
# `` : ``
# googol : googol
# '' : ''
# , : ,
# [ : [
# 23 : 23
# ] : ]
# [ : [
# 24 : 24
# ] : ]
# the : the
# number : number
# 1 : 1
# followed : follow
# by : by
# 100 : 100
# zeros : zero
# , : ,
# which : which
# was : wa
# picked : pick
# to : to
# signify : signifi
# that : that
# the : the
# search : search
# engine : engin
# was : wa
# intended : intend
# to : to
# provide : provid
# large : larg
# quantities : quantiti
# of : of
# information : inform
# . : .
# [ : [
# 25 : 25
# ] : ]
# [ : [
# 20 : 20
# ] : ]
# [ : [
# 21 : 21
# ] : ]
# [ : [
# 22 : 22
# ] : ]
# googol : googol
# [ : [
# 23 : 23
# ] : ]
# [ : [
# 24 : 24
# ] : ]
# [ : [
# 25 : 25
# ] : ]
# HTML : html
# markup : markup
# language : languag
# [ : [
# 26 : 26
# ] : ]
# The : the
# domain : domain
# name : name
# for : for
# Google : googl
# was : wa
# registered : regist
# on : on
# September : septemb
# 15 : 15
# , : ,
# 1997 : 1997
# , : ,
# [ : [
# 27 : 27
# ] : ]
# and : and
# the : the
# company : compani
# was : wa
# incorporated : incorpor
# on : on
# September : septemb
# 4 : 4
# , : ,
# 1998 : 1998
# . : .
# It : It
# was : wa
# based : base
# in : in
# the : the
# garage : garag
# of : of
# a : a
# friend : friend
# ( : (
# Susan : susan
# Wojcicki : wojcicki
# [ : [
# 13 : 13
# ] : ]
# ) : )
# in : in
# Menlo : menlo
# Park : park
# , : ,
# California : california
# . : .
# Craig : craig
# Silverstein : silverstein
# , : ,
# a : a
# fellow : fellow
# PhD : phd
# student : student
# at : at
# Stanford : stanford
# , : ,
# was : wa
# hired : hire
# as : as
# the : the
# first : first
# employee : employe
# . : .
# [ : [
# 13 : 13
# ] : ]
# [ : [
# 28 : 28
# ] : ]
# [ : [
# 29 : 29
# ] : ]
# [ : [
# 27 : 27
# ] : ]
# Susan : susan
# Wojcicki : wojcicki
# [ : [
# 13 : 13
# ] : ]
# Menlo : menlo
# Park : park
# , : ,
# California : california
# Craig : craig
# Silverstein : silverstein
# [ : [
# 13 : 13
# ] : ]
# [ : [
# 28 : 28
# ] : ]
# [ : [
# 29 : 29
# ] : ]
# Google : googl
# was : wa
# initially : initi
# funded : fund
# by : by
# an : an
# August : august
# 1998 : 1998
# contribution : contribut
# of : of
# $ : $
# 100,000 : 100,000
# from : from
# Andy : andi
# Bechtolsheim : bechtolsheim
# , : ,
# co-founder : co-found
# of : of
# Sun : sun
# Microsystems : microsystem
# ; : ;
# the : the
# money : money
# was : wa
# given : given
# before : befor
# Google : googl
# was : wa
# incorporated : incorpor
# . : .
# [ : [
# 30 : 30
# ] : ]
# Google : googl
# received : receiv
# money : money
# from : from
# three : three
# other : other
# angel : angel
# investors : investor
# in : in
# 1998 : 1998
# : : :
# Amazon.com : amazon.com
# founder : founder
# Jeff : jeff
# Bezos : bezo
# , : ,
# Stanford : stanford
# University : univers
# computer : comput
# science : scienc
# professor : professor
# David : david
# Cheriton : cheriton
# , : ,
# and : and
# entrepreneur : entrepreneur
# Ram : ram
# Shriram : shriram
# . : .
# [ : [
# 31 : 31
# ] : ]
# Between : between
# these : these
# initial : initi
# investors : investor
# , : ,
# friends : friend
# , : ,
# and : and
# family : famili
# Google : googl
# raised : rais
# around : around
# 1 : 1
# million : million
# dollars : dollar
# , : ,
# which : which
# is : is
# what : what
# allowed : allow
# them : them
# to : to
# open : open
# up : up
# their : their
# original : origin
# shop : shop
# in : in
# Menlo : menlo
# Park : park
# , : ,
# California : california
# [ : [
# 32 : 32
# ] : ]
# Andy : andi
# Bechtolsheim : bechtolsheim
# Sun : sun
# Microsystems : microsystem
# [ : [
# 30 : 30
# ] : ]
# angel : angel
# investors : investor
# Amazon.com : amazon.com
# Jeff : jeff
# Bezos : bezo
# David : david
# Cheriton : cheriton
# Ram : ram
# Shriram : shriram
# [ : [
# 31 : 31
# ] : ]
# Menlo : menlo
# Park : park
# , : ,
# California : california
# [ : [
# 32 : 32
# ] : ]
# After : after
# some : some
# additional : addit
# , : ,
# small : small
# investments : invest
# through : through
# the : the
# end : end
# of : of
# 1998 : 1998
# to : to
# early : earli
# 1999 : 1999
# , : ,
# [ : [
# 31 : 31
# ] : ]
# a : a
# new : new
# $ : $
# 25 : 25
# million : million
# round : round
# of : of
# funding : fund
# was : wa
# announced : announc
# on : on
# June : june
# 7 : 7
# , : ,
# 1999 : 1999
# , : ,
# [ : [
# 33 : 33
# ] : ]
# with : with
# major : major
# investors : investor
# including : includ
# the : the
# venture : ventur
# capital : capit
# firms : firm
# Kleiner : kleiner
# Perkins : perkin
# and : and
# Sequoia : sequoia
# Capital : capit
# . : .
# [ : [
# 30 : 30
# ] : ]
# [ : [
# 31 : 31
# ] : ]
# [ : [
# 33 : 33
# ] : ]
# venture : ventur
# capital : capit
# Kleiner : kleiner
# Perkins : perkin
# Sequoia : sequoia
# Capital : capit
# [ : [
# 30 : 30
# ] : ]
# Growth : growth
# Growth : growth
# In : In
# March : march
# 1999 : 1999
# , : ,
# the : the
# company : compani
# moved : move
# its : it
# offices : offic
# to : to
# Palo : palo
# Alto : alto
# , : ,
# California : california
# , : ,
# [ : [
# 34 : 34
# ] : ]
# which : which
# is : is
# home : home
# to : to
# several : sever
# prominent : promin
# Silicon : silicon
# Valley : valley
# technology : technolog
# start-ups : start-up
# . : .
# [ : [
# 35 : 35
# ] : ]
# The : the
# next : next
# year : year
# , : ,
# Google : googl
# began : began
# selling : sell
# advertisements : advertis
# associated : associ
# with : with
# search : search
# keywords : keyword
# against : against
# Page : page
# and : and
# Brin : brin
# 's : 's
# initial : initi
# opposition : opposit
# toward : toward
# an : an
# advertising-funded : advertising-fund
# search : search
# engine : engin
# . : .
# [ : [
# 36 : 36
# ] : ]
# [ : [
# 13 : 13
# ] : ]
# To : To
# maintain : maintain
# an : an
# uncluttered : unclutt
# page : page
# design : design
# , : ,
# advertisements : advertis
# were : were
# solely : sole
# text-based : text-bas
# . : .
# [ : [
# 37 : 37
# ] : ]
# In : In
# June : june
# 2000 : 2000
# , : ,
# it : it
# was : wa
# announced : announc
# that : that
# Google : googl
# would : would
# become : becom
# the : the
# default : default
# search : search
# engine : engin
# provider : provid
# for : for
# Yahoo : yahoo
# ! : !
# , : ,
# one : one
# of : of
# the : the
# most : most
# popular : popular
# websites : websit
# at : at
# the : the
# time : time
# , : ,
# replacing : replac
# Inktomi : inktomi
# . : .
# [ : [
# 38 : 38
# ] : ]
# [ : [
# 39 : 39
# ] : ]
# Palo : palo
# Alto : alto
# , : ,
# California : california
# [ : [
# 34 : 34
# ] : ]
# Silicon : silicon
# Valley : valley
# [ : [
# 35 : 35
# ] : ]
# [ : [
# 36 : 36
# ] : ]
# [ : [
# 13 : 13
# ] : ]
# [ : [
# 37 : 37
# ] : ]
# Yahoo : yahoo
# ! : !
# Inktomi : inktomi
# [ : [
# 38 : 38
# ] : ]
# [ : [
# 39 : 39
# ] : ]
# [ : [
# 40 : 40
# ] : ]
# In : In
# 2003 : 2003
# , : ,
# after : after
# outgrowing : outgrow
# two : two
# other : other
# locations : locat
# , : ,
# the : the
# company : compani
# leased : leas
# an : an
# office : offic
# complex : complex
# from : from
# Silicon : silicon
# Graphics : graphic
# , : ,
# at : at
# 1600 : 1600
# Amphitheatre : amphitheatr
# Parkway : parkway
# in : in
# Mountain : mountain
# View : view
# , : ,
# California : california
# . : .
# [ : [
# 41 : 41
# ] : ]
# The : the
# complex : complex
# became : becam
# known : known
# as : as
# the : the
# Googleplex : googleplex
# , : ,
# a : a
# play : play
# on : on
# the : the
# word : word
# googolplex : googolplex
# , : ,
# the : the
# number : number
# one : one
# followed : follow
# by : by
# a : a
# googol : googol
# zeroes : zero
# . : .
# Three : three
# years : year
# later : later
# , : ,
# Google : googl
# bought : bought
# the : the
# property : properti
# from : from
# SGI : sgi
# for : for
# $ : $
# 319 : 319
# million : million
# . : .
# [ : [
# 42 : 42
# ] : ]
# By : By
# that : that
# time : time
# , : ,
# the : the
# name : name
# `` : ``
# Google : googl
# '' : ''
# had : had
# found : found
# its : it
# way : way
# into : into
# everyday : everyday
# language : languag
# , : ,
# causing : caus
# the : the
# verb : verb
# `` : ``
# google : googl
# '' : ''
# to : to
# be : be
# added : ad
# to : to
# the : the
# Merriam-Webster : merriam-webst
# Collegiate : collegi
# Dictionary : dictionari
# and : and
# the : the
# Oxford : oxford
# English : english
# Dictionary : dictionari
# , : ,
# denoted : denot
# as : as
# : : :
# `` : ``
# to : to
# use : use
# the : the
# Google : googl
# search : search
# engine : engin
# to : to
# obtain : obtain
# information : inform
# on : on
# the : the
# Internet : internet
# '' : ''
# . : .
# [ : [
# 43 : 43
# ] : ]
# [ : [
# 44 : 44
# ] : ]
# Additionally : addit
# , : ,
# in : in
# 2001 : 2001
# Google : googl
# 's : 's
# Investors : investor
# felt : felt
# the : the
# need : need
# to : to
# have : have
# a : a
# strong : strong
# internal : intern
# management : manag
# , : ,
# and : and
# they : they
# agreed : agre
# to : to
# hire : hire
# Eric : eric
# Schmidt : schmidt
# as : as
# the : the
# Chairman : chairman
# and : and
# CEO : ceo
# of : of
# Google : googl
# [ : [
# 45 : 45
# ] : ]
# Silicon : silicon
# Graphics : graphic
# Mountain : mountain
# View : view
# , : ,
# California : california
# [ : [
# 41 : 41
# ] : ]
# Googleplex : googleplex
# googolplex : googolplex
# [ : [
# 42 : 42
# ] : ]
# google : googl
# Merriam-Webster : merriam-webst
# Collegiate : collegi
# Dictionary : dictionari
# Oxford : oxford
# English : english
# Dictionary : dictionari
# [ : [
# 43 : 43
# ] : ]
# [ : [
# 44 : 44
# ] : ]
# Eric : eric
# Schmidt : schmidt
# [ : [
# 45 : 45
# ] : ]
# Initial : initi
# public : public
# offering : offer
# Initial : initi
# public : public
# offering : offer
# Google : googl
# 's : 's
# initial : initi
# public : public
# offering : offer
# ( : (
# IPO : ipo
# ) : )
# took : took
# place : place
# five : five
# years : year
# later : later
# , : ,
# on : on
# August : august
# 19 : 19
# , : ,
# 2004 : 2004
# . : .
# At : At
# that : that
# time : time
# Larry : larri
# Page : page
# , : ,
# Sergey : sergey
# Brin : brin
# , : ,
# and : and
# Eric : eric
# Schmidt : schmidt
# agreed : agre
# to : to
# work : work
# together : togeth
# at : at
# Google : googl
# for : for
# 20 : 20
# years : year
# , : ,
# until : until
# the : the
# year : year
# 2024 : 2024
# . : .
# [ : [
# 46 : 46
# ] : ]
# At : At
# IPO : ipo
# , : ,
# the : the
# company : compani
# offered : offer
# 19,605,052 : 19,605,052
# shares : share
# at : at
# a : a
# price : price
# of : of
# $ : $
# 85 : 85
# per : per
# share : share
# . : .
# [ : [
# 47 : 47
# ] : ]
# [ : [
# 48 : 48
# ] : ]
# Shares : share
# were : were
# sold : sold
# in : in
# an : an
# online : onlin
# auction : auction
# format : format
# using : use
# a : a
# system : system
# built : built
# by : by
# Morgan : morgan
# Stanley : stanley
# and : and
# Credit : credit
# Suisse : suiss
# , : ,
# underwriters : underwrit
# for : for
# the : the
# deal : deal
# . : .
# [ : [
# 49 : 49
# ] : ]
# [ : [
# 50 : 50
# ] : ]
# The : the
# sale : sale
# of : of
# $ : $
# 1.67 : 1.67
# billion : billion
# gave : gave
# Google : googl
# a : a
# market : market
# capitalization : capit
# of : of
# more : more
# than : than
# $ : $
# 23 : 23
# billion : billion
# . : .
# [ : [
# 51 : 51
# ] : ]
# initial : initi
# public : public
# offering : offer
# [ : [
# 46 : 46
# ] : ]
# [ : [
# 47 : 47
# ] : ]
# [ : [
# 48 : 48
# ] : ]
# Morgan : morgan
# Stanley : stanley
# Credit : credit
# Suisse : suiss
# [ : [
# 49 : 49
# ] : ]
# [ : [
# 50 : 50
# ] : ]
# market : market
# capitalization : capit
# [ : [
# 51 : 51
# ] : ]
# Eric : eric
# Schmidt : schmidt
# In : In
# October : octob
# 2006 : 2006
# , : ,
# Google : googl
# announced : announc
# that : that
# it : it
# had : had
# acquired : acquir
# the : the
# video-sharing : video-shar
# site : site
# YouTube : youtub
# for : for
# $ : $
# 1.65 : 1.65
# billion : billion
# in : in
# Google : googl
# stock : stock
# , : ,
# [ : [
# 52 : 52
# ] : ]
# [ : [
# 53 : 53
# ] : ]
# and : and
# the : the
# deal : deal
# was : wa
# finalized : final
# on : on
# November : novemb
# 13 : 13
# , : ,
# 2006 : 2006
# . : .
# [ : [
# 54 : 54
# ] : ]
# [ : [
# 55 : 55
# ] : ]
# On : On
# April : april
# 13 : 13
# , : ,
# 2007 : 2007
# , : ,
# Google : googl
# reached : reach
# an : an
# agreement : agreement
# to : to
# acquire : acquir
# DoubleClick : doubleclick
# for : for
# $ : $
# 3.1 : 3.1
# billion : billion
# , : ,
# transferring : transfer
# to : to
# Google : googl
# valuable : valuabl
# relationships : relationship
# that : that
# DoubleClick : doubleclick
# had : had
# with : with
# Web : web
# publishers : publish
# and : and
# advertising : advertis
# agencies : agenc
# . : .
# [ : [
# 56 : 56
# ] : ]
# [ : [
# 52 : 52
# ] : ]
# [ : [
# 53 : 53
# ] : ]
# [ : [
# 54 : 54
# ] : ]
# [ : [
# 55 : 55
# ] : ]
# DoubleClick : doubleclick
# [ : [
# 56 : 56
# ] : ]
# In : In
# 2005 : 2005
# , : ,
# The : the
# Washington : washington
# Post : post
# reported : report
# on : on
# a : a
# 700 : 700
# percent : percent
# increase : increas
# in : in
# third-quarter : third-quart
# profit : profit
# for : for
# Google : googl
# , : ,
# largely : larg
# thanks : thank
# to : to
# large : larg
# companies : compani
# shifting : shift
# their : their
# advertising : advertis
# strategies : strategi
# from : from
# newspapers : newspap
# , : ,
# magazines : magazin
# , : ,
# and : and
# television : televis
# to : to
# the : the
# Internet : internet
# . : .
# [ : [
# 57 : 57
# ] : ]
# In : In
# May : may
# 2011 : 2011
# , : ,
# the : the
# number : number
# of : of
# monthly : monthli
# unique : uniqu
# visitors : visitor
# to : to
# Google : googl
# surpassed : surpass
# one : one
# billion : billion
# for : for
# the : the
# first : first
# time : time
# . : .
# [ : [
# 58 : 58
# ] : ]
# By : By
# 2011 : 2011
# , : ,
# Google : googl
# was : wa
# handling : handl
# approximately : approxim
# 3 : 3
# billion : billion
# searches : search
# per : per
# day : day
# . : .
# To : To
# handle : handl
# this : thi
# workload : workload
# , : ,
# Google : googl
# built : built
# 11 : 11
# datacenters : datacent
# around : around
# the : the
# world : world
# with : with
# some : some
# several : sever
# thousand : thousand
# servers : server
# in : in
# each : each
# . : .
# These : these
# datacenters : datacent
# allowed : allow
# Google : googl
# to : to
# handle : handl
# the : the
# ever : ever
# changing : chang
# workload : workload
# more : more
# efficiently : effici
# . : .
# [ : [
# 45 : 45
# ] : ]
# The : the
# Washington : washington
# Post : post
# [ : [
# 57 : 57
# ] : ]
# [ : [
# 58 : 58
# ] : ]
# datacenters : datacent
# [ : [
# 45 : 45
# ] : ]
# On : On
# August : august
# 15 : 15
# , : ,
# 2011 : 2011
# , : ,
# Google : googl
# made : made
# its : it
# largest-ever : largest-ev
# acquisition : acquisit
# to : to
# date : date
# when : when
# it : it
# announced : announc
# that : that
# it : it
# would : would
# acquire : acquir
# Motorola : motorola
# Mobility : mobil
# for : for
# $ : $
# 12.5 : 12.5
# billion : billion
# [ : [
# 59 : 59
# ] : ]
# [ : [
# 60 : 60
# ] : ]
# This : thi
# purchase : purchas
# was : wa
# made : made
# in : in
# part : part
# to : to
# help : help
# Google : googl
# gain : gain
# Motorola : motorola
# 's : 's
# considerable : consider
# patent : patent
# portfolio : portfolio
# on : on
# mobile : mobil
# phones : phone
# and : and
# wireless : wireless
# technologies : technolog
# , : ,
# to : to
# help : help
# protect : protect
# Google : googl
# in : in
# its : it
# ongoing : ongo
# patent : patent
# disputes : disput
# with : with
# other : other
# companies : compani
# , : ,
# [ : [
# 61 : 61
# ] : ]
# mainly : mainli
# Apple : appl
# and : and
# Microsoft : microsoft
# , : ,
# [ : [
# 62 : 62
# ] : ]
# and : and
# to : to
# allow : allow
# it : it
# to : to
# continue : continu
# to : to
# freely : freeli
# offer : offer
# Android : android
# . : .
# [ : [
# 63 : 63
# ] : ]
# Motorola : motorola
# Mobility : mobil
# [ : [
# 59 : 59
# ] : ]
# [ : [
# 60 : 60
# ] : ]
# [ : [
# 61 : 61
# ] : ]
# Apple : appl
# Microsoft : microsoft
# [ : [
# 62 : 62
# ] : ]
# Android : android
# [ : [
# 63 : 63
# ] : ]
# 2012 : 2012
# onward : onward
# 2012 : 2012
# onward : onward
# The : the
# year : year
# 2012 : 2012
# was : wa
# the : the
# first : first
# time : time
# that : that
# Google : googl
# generated : gener
# $ : $
# 50 : 50
# billion : billion
# in : in
# annual : annual
# revenue : revenu
# , : ,
# generating : gener
# $ : $
# 38 : 38
# billion : billion
# the : the
# previous : previou
# year : year
# . : .
# In : In
# January : januari
# 2013 : 2013
# , : ,
# then-CEO : then-ceo
# Larry : larri
# Page : page
# commented : comment
# , : ,
# `` : ``
# We : We
# ended : end
# 2012 : 2012
# with : with
# a : a
# strong : strong
# quarter : quarter
# ... : ...
# Revenues : revenu
# were : were
# up : up
# 36 : 36
# % : %
# year-on-year : year-on-year
# , : ,
# and : and
# 8 : 8
# % : %
# quarter-on-quarter : quarter-on-quart
# . : .
# And : and
# we : we
# hit : hit
# $ : $
# 50 : 50
# billion : billion
# in : in
# revenues : revenu
# for : for
# the : the
# first : first
# time : time
# last : last
# year : year
# – : –
# not : not
# a : a
# bad : bad
# achievement : achiev
# in : in
# just : just
# a : a
# decade : decad
# and : and
# a : a
# half : half
# . : .
# `` : ``
# [ : [
# 64 : 64
# ] : ]
# [ : [
# 64 : 64
# ] : ]
# In : In
# June : june
# 2013 : 2013
# , : ,
# Google : googl
# acquired : acquir
# Waze : waze
# , : ,
# a : a
# $ : $
# 966 : 966
# million : million
# deal : deal
# . : .
# [ : [
# 65 : 65
# ] : ]
# While : while
# Waze : waze
# would : would
# remain : remain
# an : an
# independent : independ
# entity : entiti
# , : ,
# its : it
# social : social
# features : featur
# , : ,
# such : such
# as : as
# its : it
# crowdsourced : crowdsourc
# location : locat
# platform : platform
# , : ,
# were : were
# reportedly : reportedli
# valuable : valuabl
# integrations : integr
# between : between
# Waze : waze
# and : and
# Google : googl
# Maps : map
# , : ,
# Google : googl
# 's : 's
# own : own
# mapping : map
# service : servic
# . : .
# [ : [
# 66 : 66
# ] : ]
# Waze : waze
# [ : [
# 65 : 65
# ] : ]
# Google : googl
# Maps : map
# [ : [
# 66 : 66
# ] : ]
# Google : googl
# announced : announc
# the : the
# launch : launch
# of : of
# a : a
# new : new
# company : compani
# , : ,
# called : call
# Calico : calico
# , : ,
# on : on
# September : septemb
# 19 : 19
# , : ,
# 2013 : 2013
# , : ,
# to : to
# be : be
# led : led
# by : by
# Apple : appl
# , : ,
# Inc. : inc.
# chairman : chairman
# Arthur : arthur
# Levinson : levinson
# . : .
# In : In
# the : the
# official : offici
# public : public
# statement : statement
# , : ,
# Page : page
# explained : explain
# that : that
# the : the
# `` : ``
# health : health
# and : and
# well-being : well-b
# '' : ''
# company : compani
# would : would
# focus : focu
# on : on
# `` : ``
# the : the
# challenge : challeng
# of : of
# ageing : age
# and : and
# associated : associ
# diseases : diseas
# '' : ''
# . : .
# [ : [
# 67 : 67
# ] : ]
# Calico : calico
# Apple : appl
# , : ,
# Inc. : inc.
# Arthur : arthur
# Levinson : levinson
# [ : [
# 67 : 67
# ] : ]
# On : On
# January : januari
# 26 : 26
# , : ,
# 2014 : 2014
# , : ,
# Google : googl
# announced : announc
# it : it
# had : had
# agreed : agre
# to : to
# acquire : acquir
# DeepMind : deepmind
# Technologies : technolog
# , : ,
# a : a
# privately : privat
# held : held
# artificial : artifici
# intelligence : intellig
# company : compani
# from : from
# London : london
# . : .
# [ : [
# 68 : 68
# ] : ]
# Technology : technolog
# news : news
# website : websit
# Recode : recod
# reported : report
# that : that
# the : the
# company : compani
# was : wa
# purchased : purchas
# for : for
# $ : $
# 400 : 400
# million : million
# though : though
# it : it
# was : wa
# not : not
# disclosed : disclos
# where : where
# the : the
# information : inform
# came : came
# from : from
# . : .
# A : A
# Google : googl
# spokesman : spokesman
# would : would
# not : not
# comment : comment
# of : of
# the : the
# price : price
# . : .
# [ : [
# 69 : 69
# ] : ]
# [ : [
# 70 : 70
# ] : ]
# The : the
# purchase : purchas
# of : of
# DeepMind : deepmind
# aids : aid
# in : in
# Google : googl
# 's : 's
# recent : recent
# growth : growth
# in : in
# the : the
# artificial : artifici
# intelligence : intellig
# and : and
# robotics : robot
# community : commun
# . : .
# [ : [
# 71 : 71
# ] : ]
# DeepMind : deepmind
# Technologies : technolog
# London : london
# [ : [
# 68 : 68
# ] : ]
# Recode : recod
# [ : [
# 69 : 69
# ] : ]
# [ : [
# 70 : 70
# ] : ]
# [ : [
# 71 : 71
# ] : ]
# According : accord
# to : to
# Interbrand : interbrand
# 's : 's
# annual : annual
# Best : best
# Global : global
# Brands : brand
# report : report
# , : ,
# Google : googl
# has : ha
# been : been
# the : the
# second : second
# most : most
# valuable : valuabl
# brand : brand
# in : in
# the : the
# world : world
# ( : (
# behind : behind
# Apple : appl
# Inc. : inc.
# ) : )
# in : in
# 2013 : 2013
# , : ,
# [ : [
# 72 : 72
# ] : ]
# 2014 : 2014
# , : ,
# [ : [
# 73 : 73
# ] : ]
# 2015 : 2015
# , : ,
# [ : [
# 74 : 74
# ] : ]
# and : and
# 2016 : 2016
# , : ,
# with : with
# a : a
# valuation : valuat
# of : of
# $ : $
# 133 : 133
# billion : billion
# . : .
# [ : [
# 75 : 75
# ] : ]
# Interbrand : interbrand
# Apple : appl
# Inc. : inc.
# [ : [
# 72 : 72
# ] : ]
# [ : [
# 73 : 73
# ] : ]
# [ : [
# 74 : 74
# ] : ]
# [ : [
# 75 : 75
# ] : ]
# On : On
# August : august
# 10 : 10
# , : ,
# 2015 : 2015
# , : ,
# Google : googl
# announced : announc
# plans : plan
# to : to
# reorganize : reorgan
# its : it
# various : variou
# interests : interest
# as : as
# a : a
# conglomerate : conglomer
# called : call
# Alphabet : alphabet
# . : .
# Google : googl
# became : becam
# Alphabet : alphabet
# 's : 's
# leading : lead
# subsidiary : subsidiari
# , : ,
# and : and
# will : will
# continue : continu
# to : to
# be : be
# the : the
# umbrella : umbrella
# company : compani
# for : for
# Alphabet : alphabet
# 's : 's
# Internet : internet
# interests : interest
# . : .
# Upon : upon
# completion : complet
# of : of
# the : the
# restructure : restructur
# , : ,
# Sundar : sundar
# Pichai : pichai
# became : becam
# CEO : ceo
# of : of
# Google : googl
# , : ,
# replacing : replac
# Larry : larri
# Page : page
# , : ,
# who : who
# became : becam
# CEO : ceo
# of : of
# Alphabet : alphabet
# . : .
# [ : [
# 76 : 76
# ] : ]
# [ : [
# 77 : 77
# ] : ]
# [ : [
# 78 : 78
# ] : ]
# conglomerate : conglomer
# Alphabet : alphabet
# Sundar : sundar
# Pichai : pichai
# Larry : larri
# Page : page
# [ : [
# 76 : 76
# ] : ]
# [ : [
# 77 : 77
# ] : ]
# [ : [
# 78 : 78
# ] : ]
# As : As
# of : of
# October : octob
# 2016 : 2016
# , : ,
# [ : [
# update : updat
# ] : ]
# Google : googl
# operates : oper
# 70 : 70
# offices : offic
# in : in
# more : more
# than : than
# 40 : 40
# countries : countri
# . : .
# [ : [
# 79 : 79
# ] : ]
# Alexa : alexa
# , : ,
# a : a
# company : compani
# that : that
# monitors : monitor
# commercial : commerci
# web : web
# traffic : traffic
# , : ,
# lists : list
# Google.com : google.com
# as : as
# the : the
# most : most
# visited : visit
# website : websit
# in : in
# the : the
# world : world
# . : .
# [ : [
# 9 : 9
# ] : ]
# Several : sever
# other : other
# Google : googl
# services : servic
# also : also
# figure : figur
# in : in
# the : the
# top : top
# 100 : 100
# most : most
# visited : visit
# websites : websit
# , : ,
# including : includ
# YouTube : youtub
# [ : [
# 80 : 80
# ] : ]
# and : and
# Blogger : blogger
# . : .
# [ : [
# 81 : 81
# ] : ]
# [ : [
# update : updat
# ] : ]
# [ : [
# 79 : 79
# ] : ]
# Alexa : alexa
# [ : [
# 9 : 9
# ] : ]
# [ : [
# 80 : 80
# ] : ]
# [ : [
# 81 : 81
# ] : ]
# On : On
# August : august
# 8 : 8
# , : ,
# 2017 : 2017
# , : ,
# Google : googl
# fired : fire
# employee : employe
# James : jame
# Damore : damor
# after : after
# he : he
# distributed : distribut
# a : a
# memo : memo
# throughout : throughout
# the : the
# company : compani
# which : which
# argued : argu
# that : that
# `` : ``
# Google : googl
# 's : 's
# ideological : ideolog
# echo : echo
# chamber : chamber
# '' : ''
# and : and
# bias : bia
# clouded : cloud
# their : their
# thinking : think
# about : about
# diversity : divers
# and : and
# inclusion : inclus
# , : ,
# and : and
# that : that
# it : it
# is : is
# also : also
# biological : biolog
# factors : factor
# , : ,
# not : not
# discrimination : discrimin
# alone : alon
# , : ,
# that : that
# cause : caus
# the : the
# average : averag
# woman : woman
# to : to
# be : be
# less : less
# interested : interest
# than : than
# men : men
# in : in
# technical : technic
# positions : posit
# . : .
# [ : [
# 82 : 82
# ] : ]
# Google : googl
# CEO : ceo
# Sundar : sundar
# Pichai : pichai
# accused : accus
# Damore : damor
# in : in
# violating : violat
# company : compani
# policy : polici
# by : by
# `` : ``
# advancing : advanc
# harmful : harm
# gender : gender
# stereotypes : stereotyp
# in : in
# our : our
# workplace : workplac
# '' : ''
# , : ,
# and : and
# he : he
# was : wa
# fired : fire
# on : on
# the : the
# same : same
# day : day
# . : .
# [ : [
# 83 : 83
# ] : ]
# [ : [
# 84 : 84
# ] : ]
# [ : [
# 85 : 85
# ] : ]
# New : new
# York : york
# Times : time
# columnist : columnist
# David : david
# Brooks : brook
# argued : argu
# Pichai : pichai
# had : had
# mishandled : mishandl
# the : the
# case : case
# , : ,
# and : and
# called : call
# for : for
# his : hi
# resignation : resign
# . : .
# [ : [
# 86 : 86
# ] : ]
# [ : [
# 87 : 87
# ] : ]
# Google : googl
# 's : 's
# ideological : ideolog
# echo : echo
# chamber : chamber
# [ : [
# 82 : 82
# ] : ]
# [ : [
# 83 : 83
# ] : ]
# [ : [
# 84 : 84
# ] : ]
# [ : [
# 85 : 85
# ] : ]
# David : david
# Brooks : brook
# [ : [
# 86 : 86
# ] : ]
# [ : [
# 87 : 87
# ] : ]
# On : On
# October : octob
# 25 : 25
# , : ,
# 2018 : 2018
# , : ,
# The : the
# New : new
# York : york
# Times : time
# published : publish
# the : the
# exposé : exposé
# , : ,
# `` : ``
# How : how
# Google : googl
# Protected : protect
# Andy : andi
# Rubin : rubin
# , : ,
# the : the
# ‘ : ‘
# Father : father
# of : of
# Android : android
# ’ : ’
# '' : ''
# . : .
# The : the
# company : compani
# subsequently : subsequ
# announced : announc
# that : that
# `` : ``
# 48 : 48
# employees : employe
# have : have
# been : been
# fired : fire
# over : over
# the : the
# last : last
# two : two
# years : year
# '' : ''
# for : for
# sexual : sexual
# misconduct : misconduct
# . : .
# [ : [
# 88 : 88
# ] : ]
# On : On
# November : novemb
# 1 : 1
# , : ,
# 2018 : 2018
# , : ,
# more : more
# than : than
# 20,000 : 20,000
# Google : googl
# employees : employe
# and : and
# contractors : contractor
# staged : stage
# a : a
# global : global
# walk-out : walk-out
# to : to
# protest : protest
# the : the
# company : compani
# 's : 's
# handling : handl
# of : of
# sexual : sexual
# harassment : harass
# complaints : complaint
# . : .
# [ : [
# 89 : 89
# ] : ]
# [ : [
# 90 : 90
# ] : ]
# The : the
# New : new
# York : york
# Times : time
# Andy : andi
# Rubin : rubin
# [ : [
# 88 : 88
# ] : ]
# [ : [
# 89 : 89
# ] : ]
# [ : [
# 90 : 90
# ] : ]
# On : On
# March : march
# 19 : 19
# , : ,
# 2019 : 2019
# , : ,
# Google : googl
# announced : announc
# that : that
# it : it
# would : would
# enter : enter
# the : the
# video : video
# game : game
# market : market
# , : ,
# launching : launch
# a : a
# cloud : cloud
# gaming : game
# platform : platform
# called : call
# Google : googl
# Stadia : stadia
# . : .
# [ : [
# 91 : 91
# ] : ]
# cloud : cloud
# gaming : game
# Google : googl
# Stadia : stadia
# [ : [
# 91 : 91
# ] : ]
# On : On
# June : june
# 3 : 3
# , : ,
# 2019 : 2019
# , : ,
# the : the
# United : unit
# States : state
# Department : depart
# of : of
# Justice : justic
# reported : report
# that : that
# it : it
# would : would
# investigate : investig
# Google : googl
# for : for
# antitrust : antitrust
# violations : violat
# . : .
# [ : [
# 92 : 92
# ] : ]
# United : unit
# States : state
# Department : depart
# of : of
# Justice : justic
# antitrust : antitrust
# [ : [
# 92 : 92
# ] : ]
# Products : product
# and : and
# services : servic
# Products : product
# and : and
# services : servic
# List : list
# of : of
# Google : googl
# products : product
# Search : search
# engine : engin
# Search : search
# engine : engin
# Google : googl
# Search : search
# Google : googl
# Images : imag
# [ : [
# update : updat
# ] : ]
# Google : googl
# indexes : index
# billions : billion
# of : of
# web : web
# pages : page
# to : to
# allow : allow
# users : user
# to : to
# search : search
# for : for
# the : the
# information : inform
# they : they
# desire : desir
# through : through
# the : the
# use : use
# of : of
# keywords : keyword
# and : and
# operators : oper
# . : .
# [ : [
# 93 : 93
# ] : ]
# According : accord
# to : to
# comScore : comscor
# market : market
# research : research
# from : from
# November : novemb
# 2009 : 2009
# , : ,
# Google : googl
# Search : search
# is : is
# the : the
# dominant : domin
# search : search
# engine : engin
# in : in
# the : the
# United : unit
# States : state
# market : market
# , : ,
# with : with
# a : a
# market : market
# share : share
# of : of
# 65.6 : 65.6
# % : %
# . : .
# [ : [
# 94 : 94
# ] : ]
# In : In
# May : may
# 2017 : 2017
# , : ,
# Google : googl
# enabled : enabl
# a : a
# new : new
# `` : ``
# Personal : person
# '' : ''
# tab : tab
# in : in
# Google : googl
# Search : search
# , : ,
# letting : let
# users : user
# search : search
# for : for
# content : content
# in : in
# their : their
# Google : googl
# accounts : account
# ' : '
# various : variou
# services : servic
# , : ,
# including : includ
# email : email
# messages : messag
# from : from
# Gmail : gmail
# and : and
# photos : photo
# from : from
# Google : googl
# Photos : photo
# . : .
# [ : [
# 95 : 95
# ] : ]
# [ : [
# 96 : 96
# ] : ]
# indexes : index
# operators : oper
# [ : [
# 93 : 93
# ] : ]
# comScore : comscor
# Google : googl
# Search : search
# market : market
# share : share
# [ : [
# 94 : 94
# ] : ]
# Gmail : gmail
# Google : googl
# Photos : photo
# [ : [
# 95 : 95
# ] : ]
# [ : [
# 96 : 96
# ] : ]
# Google : googl
# launched : launch
# its : it
# Google : googl
# News : new
# service : servic
# in : in
# 2002 : 2002
# , : ,
# an : an
# automated : autom
# service : servic
# which : which
# summarizes : summar
# news : news
# articles : articl
# from : from
# various : variou
# websites : websit
# . : .
# [ : [
# 97 : 97
# ] : ]
# Google : googl
# also : also
# hosts : host
# Google : googl
# Books : book
# , : ,
# a : a
# service : servic
# which : which
# searches : search
# the : the
# text : text
# found : found
# in : in
# books : book
# in : in
# its : it
# database : databas
# and : and
# shows : show
# limited : limit
# previews : preview
# or : or
# and : and
# the : the
# full : full
# book : book
# where : where
# allowed : allow
# . : .
# [ : [
# 98 : 98
# ] : ]
# Google : googl
# News : new
# [ : [
# 97 : 97
# ] : ]
# Google : googl
# Books : book
# [ : [
# 98 : 98
# ] : ]
# Advertising : advertis
# Advertising : advertis
# As : As
# per : per
# its : it
# 2017 : 2017
# Annual : annual
# report : report
# , : ,
# Google : googl
# generates : gener
# most : most
# of : of
# its : it
# revenues : revenu
# from : from
# advertising : advertis
# . : .
# This : thi
# includes : includ
# sales : sale
# of : of
# apps : app
# , : ,
# purchases : purchas
# made : made
# in-app : in-app
# , : ,
# digital : digit
# content : content
# products : product
# on : on
# google : googl
# and : and
# YouTube : youtub
# , : ,
# android : android
# and : and
# licensing : licens
# and : and
# service : servic
# fees : fee
# , : ,
# including : includ
# fees : fee
# received : receiv
# for : for
# Google : googl
# Cloud : cloud
# offerings : offer
# . : .
# 46 : 46
# % : %
# of : of
# this : thi
# was : wa
# from : from
# clicks : click
# ( : (
# cost : cost
# per : per
# clicks : click
# ) : )
# , : ,
# amounting : amount
# to : to
# US : US
# $ : $
# 109,652 : 109,652
# million : million
# in : in
# 2017 : 2017
# . : .
# This : thi
# includes : includ
# three : three
# principal : princip
# methods : method
# , : ,
# namely : name
# AdMob : admob
# , : ,
# AdSense : adsens
# ( : (
# such : such
# as : as
# AdSense : adsens
# for : for
# Content : content
# , : ,
# AdSense : adsens
# for : for
# Search : search
# , : ,
# etc : etc
# . : .
# ) : )
# and : and
# DoubleClick : doubleclick
# AdExchange : adexchang
# . : .
# [ : [
# 99 : 99
# ] : ]
# AdMob : admob
# AdSense : adsens
# AdSense : adsens
# [ : [
# 99 : 99
# ] : ]
# For : for
# the : the
# 2006 : 2006
# fiscal : fiscal
# year : year
# , : ,
# the : the
# company : compani
# reported : report
# $ : $
# 10.492 : 10.492
# billion : billion
# in : in
# total : total
# advertising : advertis
# revenues : revenu
# and : and
# only : onli
# $ : $
# 112 : 112
# million : million
# in : in
# licensing : licens
# and : and
# other : other
# revenues : revenu
# . : .
# [ : [
# 100 : 100
# ] : ]
# In : In
# 2011 : 2011
# , : ,
# 96 : 96
# % : %
# of : of
# Google : googl
# 's : 's
# revenue : revenu
# was : wa
# derived : deriv
# from : from
# its : it
# advertising : advertis
# programs : program
# . : .
# [ : [
# 101 : 101
# ] : ]
# In : In
# addition : addit
# to : to
# its : it
# own : own
# algorithms : algorithm
# for : for
# understanding : understand
# search : search
# requests : request
# , : ,
# Google : googl
# uses : use
# technology : technolog
# from : from
# the : the
# company : compani
# DoubleClick : doubleclick
# , : ,
# to : to
# project : project
# user : user
# interest : interest
# and : and
# target : target
# advertising : advertis
# to : to
# the : the
# search : search
# context : context
# and : and
# the : the
# user : user
# history : histori
# . : .
# [ : [
# 102 : 102
# ] : ]
# [ : [
# 103 : 103
# ] : ]
# [ : [
# 100 : 100
# ] : ]
# [ : [
# 101 : 101
# ] : ]
# DoubleClick : doubleclick
# [ : [
# 102 : 102
# ] : ]
# [ : [
# 103 : 103
# ] : ]
# In : In
# 2007 : 2007
# , : ,
# Google : googl
# launched : launch
# `` : ``
# AdSense : adsens
# for : for
# Mobile : mobil
# '' : ''
# , : ,
# taking : take
# advantage : advantag
# of : of
# the : the
# emerging : emerg
# mobile : mobil
# advertising : advertis
# market : market
# . : .
# [ : [
# 104 : 104
# ] : ]
# AdSense : adsens
# for : for
# Mobile : mobil
# [ : [
# 104 : 104
# ] : ]
# Google : googl
# Analytics : analyt
# allows : allow
# website : websit
# owners : owner
# to : to
# ...
# indefinitely : indefinit
# semi-protected : semi-protect
# pagesWikipedia : pageswikipedia
# indefinitely : indefinit
# move-protected : move-protect
# pagesArticles : pagesarticl
# with : with
# short : short
# descriptionUse : descriptionus
# American : american
# English : english
# from : from
# July : juli
# 2018All : 2018all
# Wikipedia : wikipedia
# articles : articl
# written : written
# in : in
# American : american
# EnglishUse : englishus
# mdy : mdi
# dates : date
# from : from
# April : april
# 2019Articles : 2019articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# 2015All : 2015all
# articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statementsArticles : statementsarticl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# December : decemb
# 2018Articles : 2018articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# 2017Articles : 2017articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# October : octob
# 2016Articles : 2016articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# April : april
# 2019Articles : 2019articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# August : august
# 2015Articles : 2015articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# 1998Articles : 1998articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# June : june
# 2017Articles : 2017articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# 2007Articles : 2007articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# February : februari
# 2009Portal : 2009portal
# templates : templat
# with : with
# redlinked : redlink
# portalsCrunchbase : portalscrunchbas
# template : templat
# with : with
# organization : organ
# IDOpenCorporates : idopencorpor
# groupingsWikipedia : groupingswikipedia
# articles : articl
# with : with
# BIBSYS : bibsi
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# BNF : bnf
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# GND : gnd
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# ISNI : isni
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# LCCN : lccn
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# NKC : nkc
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# NLA : nla
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# SELIBR : selibr
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# SUDOC : sudoc
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# VIAF : viaf
# identifiersWikipedia : identifierswikipedia
# articles : articl
# with : with
# WorldCat-VIAF : worldcat-viaf
# identifiers : identifi
# Webarchive : webarch
# template : templat
# wayback : wayback
# links : link
# Webarchive : webarch
# template : templat
# webcite : webcit
# links : link
# CS1 : cs1
# maint : maint
# : : :
# Multiple : multipl
# names : name
# : : :
# authors : author
# list : list
# CS1 : cs1
# maint : maint
# : : :
# Archived : archiv
# copy : copi
# as : as
# title : titl
# CS1 : cs1
# maint : maint
# : : :
# BOT : bot
# : : :
# original-url : original-url
# status : statu
# unknown : unknown
# Webarchive : webarch
# template : templat
# archiveis : archivei
# links : link
# Pages : page
# containing : contain
# links : link
# to : to
# subscription-only : subscription-onli
# content : content
# Wikipedia : wikipedia
# indefinitely : indefinit
# semi-protected : semi-protect
# pages : page
# Wikipedia : wikipedia
# indefinitely : indefinit
# move-protected : move-protect
# pages : page
# Articles : articl
# with : with
# short : short
# description : descript
# Use : use
# American : american
# English : english
# from : from
# July : juli
# 2018 : 2018
# All : all
# Wikipedia : wikipedia
# articles : articl
# written : written
# in : in
# American : american
# English : english
# Use : use
# mdy : mdi
# dates : date
# from : from
# April : april
# 2019 : 2019
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# 2015 : 2015
# All : all
# articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# December : decemb
# 2018 : 2018
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# 2017 : 2017
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# October : octob
# 2016 : 2016
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# April : april
# 2019 : 2019
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# August : august
# 2015 : 2015
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# 1998 : 1998
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# June : june
# 2017 : 2017
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# 2007 : 2007
# Articles : articl
# containing : contain
# potentially : potenti
# dated : date
# statements : statement
# from : from
# February : februari
# 2009 : 2009
# Portal : portal
# templates : templat
# with : with
# redlinked : redlink
# portals : portal
# Crunchbase : crunchbas
# template : templat
# with : with
# organization : organ
# ID : ID
# OpenCorporates : opencorpor
# groupings : group
# Wikipedia : wikipedia
# articles : articl
# with : with
# BIBSYS : bibsi
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# BNF : bnf
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# GND : gnd
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# ISNI : isni
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# LCCN : lccn
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# NKC : nkc
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# NLA : nla
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# SELIBR : selibr
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# SUDOC : sudoc
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# VIAF : viaf
# identifiers : identifi
# Wikipedia : wikipedia
# articles : articl
# with : with
# WorldCat-VIAF : worldcat-viaf
# identifiers : identifi
# Navigation : navig
# menu : menu
# Personal : person
# tools : tool
# Not : not
# logged : log
# inTalkContributionsCreate : intalkcontributionscr
# accountLog : accountlog
# in : in
# Talk : talk
# Contributions : contribut
# Create : creat
# account : account
# Log : log
# in : in
# Namespaces : namespac
# ArticleTalk : articletalk
# Article : articl
# Article : articl
# Talk : talk
# Talk : talk
# Variants : variant
# Variants : variant
# Views : view
# ReadView : readview
# sourceView : sourceview
# history : histori
# Read : read
# Read : read
# View : view
# source : sourc
# View : view
# source : sourc
# View : view
# history : histori
# View : view
# history : histori
# More : more
# More : more
# Search : search
# Navigation : navig
# Main : main
# pageContentsFeatured : pagecontentsfeatur
# contentCurrent : contentcurr
# eventsRandom : eventsrandom
# articleDonate : articledon
# to : to
# WikipediaWikipedia : wikipediawikipedia
# store : store
# Main : main
# page : page
# Contents : content
# Featured : featur
# content : content
# Current : current
# events : event
# Random : random
# article : articl
# Donate : donat
# to : to
# Wikipedia : wikipedia
# Wikipedia : wikipedia
# store : store
# Interaction : interact
# HelpAbout : helpabout
# WikipediaCommunity : wikipediacommun
# portalRecent : portalrec
# changesContact : changescontact
# page : page
# Help : help
# About : about
# Wikipedia : wikipedia
# Community : commun
# portal : portal
# Recent : recent
# changes : chang
# Contact : contact
# page : page
# Tools : tool
# What : what
# links : link
# hereRelated : hererel
# changesUpload : changesupload
# fileSpecial : filespeci
# pagesPermanent : pagesperman
# linkPage : linkpag
# informationWikidata : informationwikidata
# itemCite : itemcit
# this : thi
# page : page
# What : what
# links : link
# here : here
# Related : relat
# changes : chang
# Upload : upload
# file : file
# Special : special
# pages : page
# Permanent : perman
# link : link
# Page : page
# information : inform
# Wikidata : wikidata
# item : item
# Cite : cite
# this : thi
# page : page
# In : In
# other : other
# projects : project
# Wikimedia : wikimedia
# CommonsMeta-WikiWikiquoteWikiversity : commonsmeta-wikiwikiquotewikivers
# Wikimedia : wikimedia
# Commons : common
# Meta-Wiki : meta-wiki
# Wikiquote : wikiquot
# Wikiversity : wikivers
# Print/export : print/export
# Create : creat
# a : a
# bookDownload : bookdownload
# as : as
# PDFPrintable : pdfprintabl
# version : version
# Create : creat
# a : a
# book : book
# Download : download
# as : as
# PDF : pdf
# Printable : printabl
# version : version
# Languages : languag
# AfrikaansአማርኛÆngliscالعربيةঅসমীয়াAsturianuAzərbaycancaتۆرکجهBamanankanবাংলাBahasa : afrikaansአማርኛængliscالعربيةঅসমীয়াasturianuazərbaycancaتۆرکجهbamanankanবাংলাbahasa
# BanjarBân-lâm-gúБеларускаяБеларуская : banjarbân-lâm-gúбеларускаябеларуская
# ( : (
# тарашкевіца : тарашкевіца
# ) : )
# ‎भोजपुरीБългарскиBoarischBosanskiBrezhonegCatalàЧӑвашлаCebuanoČeštinaCymraegDanskDeutschDolnoserbskiडोटेलीEestiΕλληνικάEspañolEsperantoEuskaraفارسیFøroysktFrançaisGaeilgeGalego贛語ગુજરાતી客家語/Hak-kâ-ngî한국어Հայերենहिन्दीHornjoserbsceHrvatskiBahasa : ‎भोजपुरीбългарскиboarischbosanskibrezhonegcatalàчӑвашлаcebuanočeštinacymraegdanskdeutschdolnoserbskiडोटेलीeestiελληνικάespañolesperantoeuskaraفارسیføroysktfrançaisgaeilgegalego贛語ગુજરાતી客家語/hak-kâ-ngî한국어հայերենहिन्दीhornjoserbscehrvatskibahasa
# HulontaloIdoBahasa : hulontaloidobahasa
# Indonesiaᐃᓄᒃᑎᑐᑦ/inuktitutÍslenskaItalianoעבריתJawaKabɩyɛಕನ್ನಡქართულიҚазақшаKirundiKreyòl : indonesiaᐃᓄᒃᑎᑐᑦ/inuktitutíslenskaitalianoעבריתjawakabɩyɛಕನ್ನಡქართულიқазақшаkirundikreyòl
# ayisyenKurdîКыргызчаລາວلۊری : ayisyenkurdîкыргызчаລາວلۊری
# شومالیLatinaLatviešuLietuviųMagyarमैथिलीМакедонскиMalagasyമലയാളംमराठीმარგალურიمصرىمازِرونیBahasa : شومالیlatinalatviešulietuviųmagyarमैथिलीмакедонскиmalagasyമലയാളംमराठीმარგალურიمصرىمازِرونیbahasa
# MelayuMìng-dĕ̤ng-ngṳ̄Монголမြန်မာဘာသာNāhuatlNederlandsनेपाली日本語NorskNorsk : melayumìng-dĕ̤ng-ngṳ̄монголမြန်မာဘာသာnāhuatlnederlandsनेपाली日本語norsknorsk
# nynorskOccitanଓଡ଼ିଆOʻzbekcha/ўзбекчаਪੰਜਾਬੀپنجابیپښتوភាសាខ្មែរPiemontèisPlattdüütschPolskiPortuguêsQaraqalpaqshaRomânăRuna : nynorskoccitanଓଡ଼ିଆoʻzbekcha/ўзбекчаਪੰਜਾਬੀپنجابیپښتوភាសាខ្មែរpiemontèisplattdüütschpolskiportuguêsqaraqalpaqsharomânăruna
# SimiРусскийСаха : simiрусскийсаха
# тылаᱥᱟᱱᱛᱟᱲᱤScotsShqipSicilianuසිංහලSimple : тылаᱥᱟᱱᱛᱟᱲᱤscotsshqipsicilianuසිංහලsimpl
# EnglishسنڌيSlovenčinaSlovenščinaSoomaaligaکوردیСрпски : englishسنڌيslovenčinaslovenščinasoomaaligaکوردیсрпски
# / : /
# srpskiSrpskohrvatski : srpskisrpskohrvatski
# / : /
# српскохрватскиBasa : српскохрватскиbasa
# SundaSuomiSvenskaTagalogதமிழ்Татарча/tatarçaతెలుగుTetunไทยТоҷикӣತುಳುTürkçeTürkmençeThuɔŋjäŋУкраїнськаاردوئۇيغۇرچە : sundasuomisvenskatagalogதமிழ்татарча/tatarçaతెలుగుtetunไทยтоҷикӣತುಳುtürkçetürkmençethuɔŋjäŋукраїнськаاردوئۇيغۇرچە
# / : /
# UyghurcheVènetoTiếng : uyghurchevènetotiếng
# ViệtWalon文言West-VlamsWinaray吴语ייִדישYorùbá粵語ZazakiZeêuwsŽemaitėška中文 : việtwalon文言west-vlamswinaray吴语ייִדישyorùbá粵語zazakizeêuwsžemaitėška中文
# Afrikaans : afrikaan
# አማርኛ : አማርኛ
# Ænglisc : ænglisc
# العربية : العربية
# অসমীয়া : অসমীয়া
# Asturianu : asturianu
# Azərbaycanca : azərbaycanca
# تۆرکجه : تۆرکجه
# Bamanankan : bamanankan
# বাংলা : বাংলা
# Bahasa : bahasa
# Banjar : banjar
# Bân-lâm-gú : bân-lâm-gú
# Беларуская : беларуская
# Беларуская : беларуская
# ( : (
# тарашкевіца : тарашкевіца
# ) : )
# ‎ : ‎
# भोजपुरी : भोजपुरी
# Български : български
# Boarisch : boarisch
# Bosanski : bosanski
# Brezhoneg : brezhoneg
# Català : català
# Чӑвашла : чӑвашла
# Cebuano : cebuano
# Čeština : čeština
# Cymraeg : cymraeg
# Dansk : dansk
# Deutsch : deutsch
# Dolnoserbski : dolnoserbski
# डोटेली : डोटेली
# Eesti : eesti
# Ελληνικά : ελληνικά
# Español : español
# Esperanto : esperanto
# Euskara : euskara
# فارسی : فارسی
# Føroyskt : føroyskt
# Français : françai
# Gaeilge : gaeilg
# Galego : galego
# 贛語 : 贛語
# ગુજરાતી : ગુજરાતી
# 客家語/Hak-kâ-ngî : 客家語/hak-kâ-ngî
# 한국어 : 한국어
# Հայերեն : հայերեն
# हिन्दी : हिन्दी
# Hornjoserbsce : hornjoserbsc
# Hrvatski : hrvatski
# Bahasa : bahasa
# Hulontalo : hulontalo
# Ido : ido
# Bahasa : bahasa
# Indonesia : indonesia
# ᐃᓄᒃᑎᑐᑦ/inuktitut : ᐃᓄᒃᑎᑐᑦ/inuktitut
# Íslenska : íslenska
# Italiano : italiano
# עברית : עברית
# Jawa : jawa
# Kabɩyɛ : kabɩyɛ
# ಕನ್ನಡ : ಕನ್ನಡ
# ქართული : ქართული
# Қазақша : қазақша
# Kirundi : kirundi
# Kreyòl : kreyòl
# ayisyen : ayisyen
# Kurdî : kurdî
# Кыргызча : кыргызча
# ລາວ : ລາວ
# لۊری : لۊری
# شومالی : شومالی
# Latina : latina
# Latviešu : latviešu
# Lietuvių : lietuvių
# Magyar : magyar
# मैथिली : मैथिली
# Македонски : македонски
# Malagasy : malagasi
# മലയാളം : മലയാളം
# मराठी : मराठी
# მარგალური : მარგალური
# مصرى : مصرى
# مازِرونی : مازِرونی
# Bahasa : bahasa
# Melayu : melayu
# Mìng-dĕ̤ng-ngṳ̄ : mìng-dĕ̤ng-ngṳ̄
# Монгол : монгол
# မြန်မာဘာသာ : မြန်မာဘာသာ
# Nāhuatl : nāhuatl
# Nederlands : nederland
# नेपाली : नेपाली
# 日本語 : 日本語
# Norsk : norsk
# Norsk : norsk
# nynorsk : nynorsk
# Occitan : occitan
# ଓଡ଼ିଆ : ଓଡ଼ିଆ
# Oʻzbekcha/ўзбекча : oʻzbekcha/ўзбекча
# ਪੰਜਾਬੀ : ਪੰਜਾਬੀ
# پنجابی : پنجابی
# پښتو : پښتو
# ភាសាខ្មែរ : ភាសាខ្មែរ
# Piemontèis : piemontèi
# Plattdüütsch : plattdüütsch
# Polski : polski
# Português : portuguê
# Qaraqalpaqsha : qaraqalpaqsha
# Română : română
# Runa : runa
# Simi : simi
# Русский : русский
# Саха : саха
# тыла : тыла
# ᱥᱟᱱᱛᱟᱲᱤ : ᱥᱟᱱᱛᱟᱲᱤ
# Scots : scot
# Shqip : shqip
# Sicilianu : sicilianu
# සිංහල : සිංහල
# Simple : simpl
# English : english
# سنڌي : سنڌي
# Slovenčina : slovenčina
# Slovenščina : slovenščina
# Soomaaliga : soomaaliga
# کوردی : کوردی
# Српски : српски
# / : /
# srpski : srpski
# Srpskohrvatski : srpskohrvatski
# / : /
# српскохрватски : српскохрватски
# Basa : basa
# Sunda : sunda
# Suomi : suomi
# Svenska : svenska
# Tagalog : tagalog
# தமிழ் : தமிழ்
# Татарча/tatarça : татарча/tatarça
# తెలుగు : తెలుగు
# Tetun : tetun
# ไทย : ไทย
# Тоҷикӣ : тоҷикӣ
# ತುಳು : ತುಳು
# Türkçe : türkçe
# Türkmençe : türkmenç
# Thuɔŋjäŋ : thuɔŋjäŋ
# Українська : українська
# اردو : اردو
# ئۇيغۇرچە : ئۇيغۇرچە
# / : /
# Uyghurche : uyghurch
# Vèneto : vèneto
# Tiếng : tiếng
# Việt : việt
# Walon : walon
# 文言 : 文言
# West-Vlams : west-vlam
# Winaray : winaray
# 吴语 : 吴语
# ייִדיש : ייִדיש
# Yorùbá : yorùbá
# 粵語 : 粵語
# Zazaki : zazaki
# Zeêuws : zeêuw
# Žemaitėška : žemaitėška
# 中文 : 中文
# Edit : edit
# links : link
# Edit : edit
# links : link
# This : thi
# page : page
# was : wa
# last : last
# edited : edit
# on : on
# 16 : 16
# June : june
# 2019 : 2019
# , : ,
# at : at
# 18:31 : 18:31
# ( : (
# UTC : utc
# ) : )
# . : .
# Text : text
# is : is
# available : avail
# under : under
# the : the
# Creative : creativ
# Commons : common
# Attribution-ShareAlike : attribution-sharealik
# License : licens
# ; : ;
# additional : addit
# terms : term
# may : may
# apply : appli
# . : .
# By : By
# using : use
# this : thi
# site : site
# , : ,
# you : you
# agree : agre
# to : to
# the : the
# Terms : term
# of : of
# Use : use
# and : and
# Privacy : privaci
# Policy : polici
# . : .
# Wikipedia® : wikipedia®
# is : is
# a : a
# registered : regist
# trademark : trademark
# of : of
# the : the
# Wikimedia : wikimedia
# Foundation : foundat
# , : ,
# Inc. : inc.
# , : ,
# a : a
# non-profit : non-profit
# organization : organ
# . : .
# ( : (
# UTC : utc
# ) : )
# Creative : creativ
# Commons : common
# Attribution-ShareAlike : attribution-sharealik
# License : licens
# Terms : term
# of : of
# Use : use
# Privacy : privaci
# Policy : polici
# Wikimedia : wikimedia
# Foundation : foundat
# , : ,
# Inc. : inc.
# Privacy : privaci
# policy : polici
# About : about
# Wikipedia : wikipedia
# Disclaimers : disclaim
# Contact : contact
# Wikipedia : wikipedia
# Developers : develop
# Cookie : cooki
# statement : statement
# Mobile : mobil
# view : view
# Privacy : privaci
# policy : polici
# About : about
# Wikipedia : wikipedia
# Disclaimers : disclaim
# Contact : contact
# Wikipedia : wikipedia
# Developers : develop
# Cookie : cooki
# statement : statement
# Mobile : mobil
# view : view

# %%
from nltk.stem import WordNetLemmatizer
lem=WordNetLemmatizer()
for l in tokens:
    print(l,":",lem.lemmatize(l))
# Out:
# Google : Google
# Jump : Jump
# to : to
# navigation : navigation
# Jump : Jump
# to : to
# search : search
# Google : Google
# Search : Search
# Google : Google
# ( : (
# disambiguation : disambiguation
# ) : )
# Googol : Googol
# [ : [
# update : update
# ] : ]
# Googleplex : Googleplex
# Type : Type
# Subsidiary : Subsidiary
# InternetCloud : InternetCloud
# computingComputer : computingComputer
# softwareComputer : softwareComputer
# hardwareArtificial : hardwareArtificial
# intelligenceAdvertising : intelligenceAdvertising
# Internet : Internet
# Cloud : Cloud
# computing : computing
# Computer : Computer
# software : software
# Computer : Computer
# hardware : hardware
# Artificial : Artificial
# intelligence : intelligence
# Advertising : Advertising
# ; : ;
# 20 : 20
# years : year
# ago : ago
# ( : (
# 1998-09-04 : 1998-09-04
# ) : )
# 1998-09-04 : 1998-09-04
# Menlo : Menlo
# Park : Park
# Larry : Larry
# PageSergey : PageSergey
# Brin : Brin
# Larry : Larry
# Page : Page
# Sergey : Sergey
# Brin : Brin
# Mountain : Mountain
# View : View
# , : ,
# California : California
# Sundar : Sundar
# Pichai : Pichai
# ( : (
# CEO : CEO
# ) : )
# Ruth : Ruth
# Porat : Porat
# ( : (
# CFO : CFO
# ) : )
# Sundar : Sundar
# Pichai : Pichai
# CEO : CEO
# Ruth : Ruth
# Porat : Porat
# CFO : CFO
# List : List
# of : of
# Google : Google
# products : product
# [ : [
# update : update
# ] : ]
# Parent : Parent
# Alphabet : Alphabet
# Inc. : Inc.
# Subsidiaries : Subsidiaries
# List : List
# of : of
# subsidiaries : subsidiary
# google.com : google.com
# google.com : google.com
# [ : [
# 1 : 1
# ] : ]
# [ : [
# 2 : 2
# ] : ]
# [ : [
# 3 : 3
# ] : ]
# [ : [
# 4 : 4
# ] : ]
# Google : Google
# LLC : LLC
# [ : [
# 5 : 5
# ] : ]
# is : is
# an : an
# American : American
# multinational : multinational
# technology : technology
# company : company
# that : that
# specializes : specializes
# in : in
# Internet-related : Internet-related
# services : service
# and : and
# products : product
# , : ,
# which : which
# include : include
# online : online
# advertising : advertising
# technologies : technology
# , : ,
# search : search
# engine : engine
# , : ,
# cloud : cloud
# computing : computing
# , : ,
# software : software
# , : ,
# and : and
# hardware : hardware
# . : .
# It : It
# is : is
# considered : considered
# one : one
# of : of
# the : the
# Big : Big
# Four : Four
# technology : technology
# companies : company
# , : ,
# alongside : alongside
# Amazon : Amazon
# , : ,
# Apple : Apple
# and : and
# Facebook : Facebook
# . : .
# [ : [
# 6 : 6
# ] : ]
# [ : [
# 7 : 7
# ] : ]
# [ : [
# 5 : 5
# ] : ]
# online : online
# advertising : advertising
# technologies : technology
# search : search
# engine : engine
# cloud : cloud
# computing : computing
# Big : Big
# Four : Four
# Amazon : Amazon
# Apple : Apple
# Facebook : Facebook
# [ : [
# 6 : 6
# ] : ]
# [ : [
# 7 : 7
# ] : ]
# Google : Google
# was : wa
# founded : founded
# in : in
# 1998 : 1998
# by : by
# Larry : Larry
# Page : Page
# and : and
# Sergey : Sergey
# Brin : Brin
# while : while
# they : they
# were : were
# Ph.D. : Ph.D.
# students : student
# at : at
# Stanford : Stanford
# University : University
# in : in
# California : California
# . : .
# Together : Together
# they : they
# own : own
# about : about
# 14 : 14
# percent : percent
# of : of
# its : it
# shares : share
# and : and
# control : control
# 56 : 56
# percent : percent
# of : of
# the : the
# stockholder : stockholder
# voting : voting
# power : power
# through : through
# supervoting : supervoting
# stock : stock
# . : .
# They : They
# incorporated : incorporated
# Google : Google
# as : a
# a : a
# privately : privately
# held : held
# company : company
# on : on
# September : September
# 4 : 4
# , : ,
# 1998 : 1998
# . : .
# An : An
# initial : initial
# public : public
# offering : offering
# ( : (
# IPO : IPO
# ) : )
# took : took
# place : place
# on : on
# August : August
# 19 : 19
# , : ,
# 2004 : 2004
# , : ,
# and : and
# Google : Google
# moved : moved
# to : to
# its : it
# headquarters : headquarters
# in : in
# Mountain : Mountain
# View : View
# , : ,
# California : California
# , : ,
# nicknamed : nicknamed
# the : the
# Googleplex : Googleplex
# . : .
# In : In
# August : August
# 2015 : 2015
# , : ,
# Google : Google
# announced : announced
# plans : plan
# to : to
# reorganize : reorganize
# its : it
# various : various
# interests : interest
# as : a
# a : a
# conglomerate : conglomerate
# called : called
# Alphabet : Alphabet
# Inc. : Inc.
# Google : Google
# is : is
# Alphabet : Alphabet
# 's : 's
# leading : leading
# subsidiary : subsidiary
# and : and
# will : will
# continue : continue
# to : to
# be : be
# the : the
# umbrella : umbrella
# company : company
# for : for
# Alphabet : Alphabet
# 's : 's
# Internet : Internet
# interests : interest
# . : .
# Sundar : Sundar
# Pichai : Pichai
# was : wa
# appointed : appointed
# CEO : CEO
# of : of
# Google : Google
# , : ,
# replacing : replacing
# Larry : Larry
# Page : Page
# who : who
# became : became
# the : the
# CEO : CEO
# of : of
# Alphabet : Alphabet
# . : .
# Larry : Larry
# Page : Page
# Sergey : Sergey
# Brin : Brin
# Stanford : Stanford
# University : University
# California : California
# supervoting : supervoting
# Googleplex : Googleplex
# Alphabet : Alphabet
# Inc. : Inc.
# Sundar : Sundar
# Pichai : Pichai
# The : The
# company : company
# 's : 's
# rapid : rapid
# growth : growth
# since : since
# incorporation : incorporation
# has : ha
# triggered : triggered
# a : a
# chain : chain
# of : of
# products : product
# , : ,
# acquisitions : acquisition
# , : ,
# and : and
# partnerships : partnership
# beyond : beyond
# Google : Google
# 's : 's
# core : core
# search : search
# engine : engine
# ( : (
# Google : Google
# Search : Search
# ) : )
# . : .
# It : It
# offers : offer
# services : service
# designed : designed
# for : for
# work : work
# and : and
# productivity : productivity
# ( : (
# Google : Google
# Docs : Docs
# , : ,
# Google : Google
# Sheets : Sheets
# , : ,
# and : and
# Google : Google
# Slides : Slides
# ) : )
# , : ,
# email : email
# ( : (
# Gmail/Inbox : Gmail/Inbox
# ) : )
# , : ,
# scheduling : scheduling
# and : and
# time : time
# management : management
# ( : (
# Google : Google
# Calendar : Calendar
# ) : )
# , : ,
# cloud : cloud
# storage : storage
# ( : (
# Google : Google
# Drive : Drive
# ) : )
# , : ,
# instant : instant
# messaging : messaging
# and : and
# video : video
# chat : chat
# ( : (
# Google : Google
# Allo : Allo
# , : ,
# Duo : Duo
# , : ,
# Hangouts : Hangouts
# ) : )
# , : ,
# language : language
# translation : translation
# ( : (
# Google : Google
# Translate : Translate
# ) : )
# , : ,
# mapping : mapping
# and : and
# navigation : navigation
# ( : (
# Google : Google
# Maps : Maps
# , : ,
# Waze : Waze
# , : ,
# Google : Google
# Earth : Earth
# , : ,
# Street : Street
# View : View
# ) : )
# , : ,
# video : video
# sharing : sharing
# ( : (
# YouTube : YouTube
# ) : )
# , : ,
# note-taking : note-taking
# ( : (
# Google : Google
# Keep : Keep
# ) : )
# , : ,
# and : and
# photo : photo
# organizing : organizing
# and : and
# editing : editing
# ( : (
# Google : Google
# Photos : Photos
# ) : )
# . : .
# The : The
# company : company
# leads : lead
# the : the
# development : development
# of : of
# the : the
# Android : Android
# mobile : mobile
# operating : operating
# system : system
# , : ,
# the : the
# Google : Google
# Chrome : Chrome
# web : web
# browser : browser
# , : ,
# and : and
# Chrome : Chrome
# OS : OS
# , : ,
# a : a
# lightweight : lightweight
# operating : operating
# system : system
# based : based
# on : on
# the : the
# Chrome : Chrome
# browser : browser
# . : .
# Google : Google
# has : ha
# moved : moved
# increasingly : increasingly
# into : into
# hardware : hardware
# ; : ;
# from : from
# 2010 : 2010
# to : to
# 2015 : 2015
# , : ,
# it : it
# partnered : partnered
# with : with
# major : major
# electronics : electronics
# manufacturers : manufacturer
# in : in
# the : the
# production : production
# of : of
# its : it
# Nexus : Nexus
# devices : device
# , : ,
# and : and
# it : it
# released : released
# multiple : multiple
# hardware : hardware
# products : product
# in : in
# October : October
# 2016 : 2016
# , : ,
# including : including
# the : the
# Google : Google
# Pixel : Pixel
# smartphone : smartphone
# , : ,
# Google : Google
# Home : Home
# smart : smart
# speaker : speaker
# , : ,
# Google : Google
# Wifi : Wifi
# mesh : mesh
# wireless : wireless
# router : router
# , : ,
# and : and
# Google : Google
# Daydream : Daydream
# virtual : virtual
# reality : reality
# headset : headset
# . : .
# Google : Google
# has : ha
# also : also
# experimented : experimented
# with : with
# becoming : becoming
# an : an
# Internet : Internet
# carrier : carrier
# ( : (
# Google : Google
# Fiber : Fiber
# , : ,
# Google : Google
# Fi : Fi
# , : ,
# and : and
# Google : Google
# Station : Station
# ) : )
# . : .
# [ : [
# 8 : 8
# ] : ]
# Google : Google
# Search : Search
# Google : Google
# Docs : Docs
# Google : Google
# Sheets : Sheets
# Google : Google
# Slides : Slides
# Gmail : Gmail
# Inbox : Inbox
# Google : Google
# Calendar : Calendar
# Google : Google
# Drive : Drive
# Google : Google
# Allo : Allo
# Duo : Duo
# Hangouts : Hangouts
# Google : Google
# Translate : Translate
# Google : Google
# Maps : Maps
# Waze : Waze
# Google : Google
# Earth : Earth
# Street : Street
# View : View
# YouTube : YouTube
# Google : Google
# Keep : Keep
# Google : Google
# Photos : Photos
# Android : Android
# Google : Google
# Chrome : Chrome
# Chrome : Chrome
# OS : OS
# Nexus : Nexus
# Google : Google
# Pixel : Pixel
# Google : Google
# Home : Home
# Google : Google
# Wifi : Wifi
# Google : Google
# Daydream : Daydream
# Google : Google
# Fiber : Fiber
# Google : Google
# Fi : Fi
# Google : Google
# Station : Station
# [ : [
# 8 : 8
# ] : ]
# Google.com : Google.com
# is : is
# the : the
# most : most
# visited : visited
# website : website
# in : in
# the : the
# world : world
# . : .
# [ : [
# 9 : 9
# ] : ]
# Several : Several
# other : other
# Google : Google
# services : service
# also : also
# figure : figure
# in : in
# the : the
# top : top
# 100 : 100
# most : most
# visited : visited
# websites : website
# , : ,
# including : including
# YouTube : YouTube
# and : and
# Blogger : Blogger
# . : .
# Google : Google
# was : wa
# the : the
# most : most
# valuable : valuable
# brand : brand
# in : in
# the : the
# world : world
# as : a
# of : of
# 2017 : 2017
# , : ,
# [ : [
# update : update
# ] : ]
# [ : [
# 10 : 10
# ] : ]
# but : but
# has : ha
# received : received
# significant : significant
# criticism : criticism
# involving : involving
# issues : issue
# such : such
# as : a
# privacy : privacy
# concerns : concern
# , : ,
# tax : tax
# avoidance : avoidance
# , : ,
# antitrust : antitrust
# , : ,
# censorship : censorship
# , : ,
# and : and
# search : search
# neutrality : neutrality
# . : .
# Google : Google
# 's : 's
# mission : mission
# statement : statement
# is : is
# `` : ``
# to : to
# organize : organize
# the : the
# world : world
# 's : 's
# information : information
# and : and
# make : make
# it : it
# universally : universally
# accessible : accessible
# and : and
# useful : useful
# '' : ''
# . : .
# The : The
# company : company
# 's : 's
# unofficial : unofficial
# slogan : slogan
# `` : ``
# Do : Do
# n't : n't
# be : be
# evil : evil
# '' : ''
# was : wa
# removed : removed
# from : from
# the : the
# company : company
# 's : 's
# code : code
# of : of
# conduct : conduct
# around : around
# May : May
# 2018 : 2018
# , : ,
# but : but
# reinstated : reinstated
# by : by
# July : July
# 31 : 31
# , : ,
# 2018 : 2018
# . : .
# [ : [
# 11 : 11
# ] : ]
# [ : [
# 12 : 12
# ] : ]
# [ : [
# 9 : 9
# ] : ]
# YouTube : YouTube
# Blogger : Blogger
# [ : [
# update : update
# ] : ]
# [ : [
# 10 : 10
# ] : ]
# criticism : criticism
# privacy : privacy
# concerns : concern
# censorship : censorship
# mission : mission
# statement : statement
# [ : [
# 11 : 11
# ] : ]
# [ : [
# 12 : 12
# ] : ]
# Contents : Contents
# 1 : 1
# History : History
# 1.1 : 1.1
# Early : Early
# years : year
# 1.2 : 1.2
# Growth : Growth
# 1.3 : 1.3
# Initial : Initial
# public : public
# offering : offering
# 1.4 : 1.4
# 2012 : 2012
# onward : onward
# 2 : 2
# Products : Products
# and : and
# services : service
# 2.1 : 2.1
# Search : Search
# engine : engine
# 2.2 : 2.2
# Advertising : Advertising
# 2.3 : 2.3
# Consumer : Consumer
# services : service
# 2.3.1 : 2.3.1
# Web-based : Web-based
# services : service
# 2.3.2 : 2.3.2
# Software : Software
# 2.3.3 : 2.3.3
# Hardware : Hardware
# 2.4 : 2.4
# Enterprise : Enterprise
# services : service
# 2.5 : 2.5
# Internet : Internet
# services : service
# 2.6 : 2.6
# Other : Other
# products : product
# 3 : 3
# Corporate : Corporate
# affairs : affair
# 3.1 : 3.1
# Finance : Finance
# 3.2 : 3.2
# Corporate : Corporate
# identity : identity
# 3.3 : 3.3
# Workplace : Workplace
# culture : culture
# 3.4 : 3.4
# Office : Office
# locations : location
# 3.5 : 3.5
# Infrastructure : Infrastructure
# 3.6 : 3.6
# Environment : Environment
# 3.7 : 3.7
# Philanthropy : Philanthropy
# 4 : 4
# Criticism : Criticism
# and : and
# controversy : controversy
# 4.1 : 4.1
# Litigation : Litigation
# 5 : 5
# See : See
# also : also
# 6 : 6
# References : References
# 7 : 7
# Further : Further
# reading : reading
# 8 : 8
# External : External
# links : link
# 1 : 1
# History : History
# 1 : 1
# History : History
# 1.1 : 1.1
# Early : Early
# years : year
# 1.2 : 1.2
# Growth : Growth
# 1.3 : 1.3
# Initial : Initial
# public : public
# offering : offering
# 1.4 : 1.4
# 2012 : 2012
# onward : onward
# 1.1 : 1.1
# Early : Early
# years : year
# 1.1 : 1.1
# Early : Early
# years : year
# 1.2 : 1.2
# Growth : Growth
# 1.2 : 1.2
# Growth : Growth
# 1.3 : 1.3
# Initial : Initial
# public : public
# offering : offering
# 1.3 : 1.3
# Initial : Initial
# public : public
# offering : offering
# 1.4 : 1.4
# 2012 : 2012
# onward : onward
# 1.4 : 1.4
# 2012 : 2012
# onward : onward
# 2 : 2
# Products : Products
# and : and
# services : service
# 2 : 2
# Products : Products
# and : and
# services : service
# 2.1 : 2.1
# Search : Search
# engine : engine
# 2.2 : 2.2
# Advertising : Advertising
# 2.3 : 2.3
# Consumer : Consumer
# services : service
# 2.3.1 : 2.3.1
# Web-based : Web-based
# services : service
# 2.3.2 : 2.3.2
# Software : Software
# 2.3.3 : 2.3.3
# Hardware : Hardware
# 2.4 : 2.4
# Enterprise : Enterprise
# services : service
# 2.5 : 2.5
# Internet : Internet
# services : service
# 2.6 : 2.6
# Other : Other
# products : product
# 2.1 : 2.1
# Search : Search
# engine : engine
# 2.1 : 2.1
# Search : Search
# engine : engine
# 2.2 : 2.2
# Advertising : Advertising
# 2.2 : 2.2
# Advertising : Advertising
# 2.3 : 2.3
# Consumer : Consumer
# services : service
# 2.3 : 2.3
# Consumer : Consumer
# services : service
# 2.3.1 : 2.3.1
# Web-based : Web-based
# services : service
# 2.3.2 : 2.3.2
# Software : Software
# 2.3.3 : 2.3.3
# Hardware : Hardware
# 2.3.1 : 2.3.1
# Web-based : Web-based
# services : service
# 2.3.1 : 2.3.1
# Web-based : Web-based
# services : service
# 2.3.2 : 2.3.2
# Software : Software
# 2.3.2 : 2.3.2
# Software : Software
# 2.3.3 : 2.3.3
# Hardware : Hardware
# 2.3.3 : 2.3.3
# Hardware : Hardware
# 2.4 : 2.4
# Enterprise : Enterprise
# services : service
# 2.4 : 2.4
# Enterprise : Enterprise
# services : service
# 2.5 : 2.5
# Internet : Internet
# services : service
# 2.5 : 2.5
# Internet : Internet
# services : service
# 2.6 : 2.6
# Other : Other
# products : product
# 2.6 : 2.6
# Other : Other
# products : product
# 3 : 3
# Corporate : Corporate
# affairs : affair
# 3 : 3
# Corporate : Corporate
# affairs : affair
# 3.1 : 3.1
# Finance : Finance
# 3.2 : 3.2
# Corporate : Corporate
# identity : identity
# 3.3 : 3.3
# Workplace : Workplace
# culture : culture
# 3.4 : 3.4
# Office : Office
# locations : location
# 3.5 : 3.5
# Infrastructure : Infrastructure
# 3.6 : 3.6
# Environment : Environment
# 3.7 : 3.7
# Philanthropy : Philanthropy
# 3.1 : 3.1
# Finance : Finance
# 3.1 : 3.1
# Finance : Finance
# 3.2 : 3.2
# Corporate : Corporate
# identity : identity
# 3.2 : 3.2
# Corporate : Corporate
# identity : identity
# 3.3 : 3.3
# Workplace : Workplace
# culture : culture
# 3.3 : 3.3
# Workplace : Workplace
# culture : culture
# 3.4 : 3.4
# Office : Office
# locations : location
# 3.4 : 3.4
# Office : Office
# locations : location
# 3.5 : 3.5
# Infrastructure : Infrastructure
# 3.5 : 3.5
# Infrastructure : Infrastructure
# 3.6 : 3.6
# Environment : Environment
# 3.6 : 3.6
# Environment : Environment
# 3.7 : 3.7
# Philanthropy : Philanthropy
# 3.7 : 3.7
# Philanthropy : Philanthropy
# 4 : 4
# Criticism : Criticism
# and : and
# controversy : controversy
# 4 : 4
# Criticism : Criticism
# and : and
# controversy : controversy
# 4.1 : 4.1
# Litigation : Litigation
# 4.1 : 4.1
# Litigation : Litigation
# 4.1 : 4.1
# Litigation : Litigation
# 5 : 5
# See : See
# also : also
# 5 : 5
# See : See
# also : also
# 6 : 6
# References : References
# 6 : 6
# References : References
# 7 : 7
# Further : Further
# reading : reading
# 7 : 7
# Further : Further
# reading : reading
# 8 : 8
# External : External
# links : link
# 8 : 8
# External : External
# links : link
# History : History
# History : History
# History : History
# of : of
# Google : Google
# List : List
# of : of
# mergers : merger
# and : and
# acquisitions : acquisition
# by : by
# Alphabet : Alphabet
# Alphabet : Alphabet
# Inc : Inc
# . : .
# Early : Early
# years : year
# Early : Early
# years : year
# Larry : Larry
# Page : Page
# Sergey : Sergey
# Brin : Brin
# Google : Google
# began : began
# in : in
# January : January
# 1996 : 1996
# as : a
# a : a
# research : research
# project : project
# by : by
# Larry : Larry
# Page : Page
# and : and
# Sergey : Sergey
# Brin : Brin
# when : when
# they : they
# were : were
# both : both
# PhD : PhD
# students : student
# at : at
# Stanford : Stanford
# University : University
# in : in
# Stanford : Stanford
# , : ,
# California : California
# . : .
# [ : [
# 13 : 13
# ] : ]
# Larry : Larry
# Page : Page
# Sergey : Sergey
# Brin : Brin
# Stanford : Stanford
# University : University
# Stanford : Stanford
# , : ,
# California : California
# [ : [
# 13 : 13
# ] : ]
# While : While
# conventional : conventional
# search : search
# engines : engine
# ranked : ranked
# results : result
# by : by
# counting : counting
# how : how
# many : many
# times : time
# the : the
# search : search
# terms : term
# appeared : appeared
# on : on
# the : the
# page : page
# , : ,
# the : the
# two : two
# theorized : theorized
# about : about
# a : a
# better : better
# system : system
# that : that
# analyzed : analyzed
# the : the
# relationships : relationship
# among : among
# websites : website
# . : .
# [ : [
# 14 : 14
# ] : ]
# They : They
# called : called
# this : this
# algorithm : algorithm
# PageRank : PageRank
# ; : ;
# it : it
# determined : determined
# a : a
# website : website
# 's : 's
# relevance : relevance
# by : by
# the : the
# number : number
# of : of
# pages : page
# , : ,
# and : and
# the : the
# importance : importance
# of : of
# those : those
# pages : page
# that : that
# linked : linked
# back : back
# to : to
# the : the
# original : original
# site : site
# . : .
# [ : [
# 15 : 15
# ] : ]
# [ : [
# 16 : 16
# ] : ]
# PageRank : PageRank
# was : wa
# influenced : influenced
# by : by
# a : a
# similar : similar
# page-ranking : page-ranking
# and : and
# site-scoring : site-scoring
# algorithm : algorithm
# earlier : earlier
# used : used
# for : for
# RankDex : RankDex
# , : ,
# developed : developed
# by : by
# Robin : Robin
# Li : Li
# in : in
# 1996 : 1996
# , : ,
# with : with
# Larry : Larry
# Page : Page
# 's : 's
# PageRank : PageRank
# patent : patent
# including : including
# a : a
# citation : citation
# to : to
# Li : Li
# 's : 's
# earlier : earlier
# RankDex : RankDex
# patent : patent
# ; : ;
# Li : Li
# later : later
# went : went
# on : on
# to : to
# create : create
# the : the
# Chinese : Chinese
# search : search
# engine : engine
# Baidu : Baidu
# . : .
# [ : [
# 17 : 17
# ] : ]
# [ : [
# 18 : 18
# ] : ]
# [ : [
# 19 : 19
# ] : ]
# [ : [
# 14 : 14
# ] : ]
# PageRank : PageRank
# relevance : relevance
# [ : [
# 15 : 15
# ] : ]
# [ : [
# 16 : 16
# ] : ]
# RankDex : RankDex
# Robin : Robin
# Li : Li
# Baidu : Baidu
# [ : [
# 17 : 17
# ] : ]
# [ : [
# 18 : 18
# ] : ]
# [ : [
# 19 : 19
# ] : ]
# Page : Page
# and : and
# Brin : Brin
# originally : originally
# nicknamed : nicknamed
# their : their
# new : new
# search : search
# engine : engine
# `` : ``
# BackRub : BackRub
# '' : ''
# , : ,
# because : because
# the : the
# system : system
# checked : checked
# backlinks : backlinks
# to : to
# estimate : estimate
# the : the
# importance : importance
# of : of
# a : a
# site : site
# . : .
# [ : [
# 20 : 20
# ] : ]
# [ : [
# 21 : 21
# ] : ]
# [ : [
# 22 : 22
# ] : ]
# Eventually : Eventually
# , : ,
# they : they
# changed : changed
# the : the
# name : name
# to : to
# Google : Google
# ; : ;
# the : the
# name : name
# of : of
# the : the
# search : search
# engine : engine
# originated : originated
# from : from
# a : a
# misspelling : misspelling
# of : of
# the : the
# word : word
# `` : ``
# googol : googol
# '' : ''
# , : ,
# [ : [
# 23 : 23
# ] : ]
# [ : [
# 24 : 24
# ] : ]
# the : the
# number : number
# 1 : 1
# followed : followed
# by : by
# 100 : 100
# zeros : zero
# , : ,
# which : which
# was : wa
# picked : picked
# to : to
# signify : signify
# that : that
# the : the
# search : search
# engine : engine
# was : wa
# intended : intended
# to : to
# provide : provide
# large : large
# quantities : quantity
# of : of
# information : information
# . : .
# [ : [
# 25 : 25
# ] : ]
# [ : [
# 20 : 20
# ] : ]
# [ : [
# 21 : 21
# ] : ]
# [ : [
# 22 : 22
# ] : ]
# googol : googol
# [ : [
# 23 : 23
# ] : ]
# [ : [
# 24 : 24
# ] : ]
# [ : [
# 25 : 25
# ] : ]
# HTML : HTML
# markup : markup
# language : language
# [ : [
# 26 : 26
# ] : ]
# The : The
# domain : domain
# name : name
# for : for
# Google : Google
# was : wa
# registered : registered
# on : on
# September : September
# 15 : 15
# , : ,
# 1997 : 1997
# , : ,
# [ : [
# 27 : 27
# ] : ]
# and : and
# the : the
# company : company
# was : wa
# incorporated : incorporated
# on : on
# September : September
# 4 : 4
# , : ,
# 1998 : 1998
# . : .
# It : It
# was : wa
# based : based
# in : in
# the : the
# garage : garage
# of : of
# a : a
# friend : friend
# ( : (
# Susan : Susan
# Wojcicki : Wojcicki
# [ : [
# 13 : 13
# ] : ]
# ) : )
# in : in
# Menlo : Menlo
# Park : Park
# , : ,
# California : California
# . : .
# Craig : Craig
# Silverstein : Silverstein
# , : ,
# a : a
# fellow : fellow
# PhD : PhD
# student : student
# at : at
# Stanford : Stanford
# , : ,
# was : wa
# hired : hired
# as : a
# the : the
# first : first
# employee : employee
# . : .
# [ : [
# 13 : 13
# ] : ]
# [ : [
# 28 : 28
# ] : ]
# [ : [
# 29 : 29
# ] : ]
# [ : [
# 27 : 27
# ] : ]
# Susan : Susan
# Wojcicki : Wojcicki
# [ : [
# 13 : 13
# ] : ]
# Menlo : Menlo
# Park : Park
# , : ,
# California : California
# Craig : Craig
# Silverstein : Silverstein
# [ : [
# 13 : 13
# ] : ]
# [ : [
# 28 : 28
# ] : ]
# [ : [
# 29 : 29
# ] : ]
# Google : Google
# was : wa
# initially : initially
# funded : funded
# by : by
# an : an
# August : August
# 1998 : 1998
# contribution : contribution
# of : of
# $ : $
# 100,000 : 100,000
# from : from
# Andy : Andy
# Bechtolsheim : Bechtolsheim
# , : ,
# co-founder : co-founder
# of : of
# Sun : Sun
# Microsystems : Microsystems
# ; : ;
# the : the
# money : money
# was : wa
# given : given
# before : before
# Google : Google
# was : wa
# incorporated : incorporated
# . : .
# [ : [
# 30 : 30
# ] : ]
# Google : Google
# received : received
# money : money
# from : from
# three : three
# other : other
# angel : angel
# investors : investor
# in : in
# 1998 : 1998
# : : :
# Amazon.com : Amazon.com
# founder : founder
# Jeff : Jeff
# Bezos : Bezos
# , : ,
# Stanford : Stanford
# University : University
# computer : computer
# science : science
# professor : professor
# David : David
# Cheriton : Cheriton
# , : ,
# and : and
# entrepreneur : entrepreneur
# Ram : Ram
# Shriram : Shriram
# . : .
# [ : [
# 31 : 31
# ] : ]
# Between : Between
# these : these
# initial : initial
# investors : investor
# , : ,
# friends : friend
# , : ,
# and : and
# family : family
# Google : Google
# raised : raised
# around : around
# 1 : 1
# million : million
# dollars : dollar
# , : ,
# which : which
# is : is
# what : what
# allowed : allowed
# them : them
# to : to
# open : open
# up : up
# their : their
# original : original
# shop : shop
# in : in
# Menlo : Menlo
# Park : Park
# , : ,
# California : California
# [ : [
# 32 : 32
# ] : ]
# Andy : Andy
# Bechtolsheim : Bechtolsheim
# Sun : Sun
# Microsystems : Microsystems
# [ : [
# 30 : 30
# ] : ]
# angel : angel
# investors : investor
# Amazon.com : Amazon.com
# Jeff : Jeff
# Bezos : Bezos
# David : David
# Cheriton : Cheriton
# Ram : Ram
# Shriram : Shriram
# [ : [
# 31 : 31
# ] : ]
# Menlo : Menlo
# Park : Park
# , : ,
# California : California
# [ : [
# 32 : 32
# ] : ]
# After : After
# some : some
# additional : additional
# , : ,
# small : small
# investments : investment
# through : through
# the : the
# end : end
# of : of
# 1998 : 1998
# to : to
# early : early
# 1999 : 1999
# , : ,
# [ : [
# 31 : 31
# ] : ]
# a : a
# new : new
# $ : $
# 25 : 25
# million : million
# round : round
# of : of
# funding : funding
# was : wa
# announced : announced
# on : on
# June : June
# 7 : 7
# , : ,
# 1999 : 1999
# , : ,
# [ : [
# 33 : 33
# ] : ]
# with : with
# major : major
# investors : investor
# including : including
# the : the
# venture : venture
# capital : capital
# firms : firm
# Kleiner : Kleiner
# Perkins : Perkins
# and : and
# Sequoia : Sequoia
# Capital : Capital
# . : .
# [ : [
# 30 : 30
# ] : ]
# [ : [
# 31 : 31
# ] : ]
# [ : [
# 33 : 33
# ] : ]
# venture : venture
# capital : capital
# Kleiner : Kleiner
# Perkins : Perkins
# Sequoia : Sequoia
# Capital : Capital
# [ : [
# 30 : 30
# ] : ]
# Growth : Growth
# Growth : Growth
# In : In
# March : March
# 1999 : 1999
# , : ,
# the : the
# company : company
# moved : moved
# its : it
# offices : office
# to : to
# Palo : Palo
# Alto : Alto
# , : ,
# California : California
# , : ,
# [ : [
# 34 : 34
# ] : ]
# which : which
# is : is
# home : home
# to : to
# several : several
# prominent : prominent
# Silicon : Silicon
# Valley : Valley
# technology : technology
# start-ups : start-ups
# . : .
# [ : [
# 35 : 35
# ] : ]
# The : The
# next : next
# year : year
# , : ,
# Google : Google
# began : began
# selling : selling
# advertisements : advertisement
# associated : associated
# with : with
# search : search
# keywords : keywords
# against : against
# Page : Page
# and : and
# Brin : Brin
# 's : 's
# initial : initial
# opposition : opposition
# toward : toward
# an : an
# advertising-funded : advertising-funded
# search : search
# engine : engine
# . : .
# [ : [
# 36 : 36
# ] : ]
# [ : [
# 13 : 13
# ] : ]
# To : To
# maintain : maintain
# an : an
# uncluttered : uncluttered
# page : page
# design : design
# , : ,
# advertisements : advertisement
# were : were
# solely : solely
# text-based : text-based
# . : .
# [ : [
# 37 : 37
# ] : ]
# In : In
# June : June
# 2000 : 2000
# , : ,
# it : it
# was : wa
# announced : announced
# that : that
# Google : Google
# would : would
# become : become
# the : the
# default : default
# search : search
# engine : engine
# provider : provider
# for : for
# Yahoo : Yahoo
# ! : !
# , : ,
# one : one
# of : of
# the : the
# most : most
# popular : popular
# websites : website
# at : at
# the : the
# time : time
# , : ,
# replacing : replacing
# Inktomi : Inktomi
# . : .
# [ : [
# 38 : 38
# ] : ]
# [ : [
# 39 : 39
# ] : ]
# Palo : Palo
# Alto : Alto
# , : ,
# California : California
# [ : [
# 34 : 34
# ] : ]
# Silicon : Silicon
# Valley : Valley
# [ : [
# 35 : 35
# ] : ]
# [ : [
# 36 : 36
# ] : ]
# [ : [
# 13 : 13
# ] : ]
# [ : [
# 37 : 37
# ] : ]
# Yahoo : Yahoo
# ! : !
# Inktomi : Inktomi
# [ : [
# 38 : 38
# ] : ]
# [ : [
# 39 : 39
# ] : ]
# [ : [
# 40 : 40
# ] : ]
# In : In
# 2003 : 2003
# , : ,
# after : after
# outgrowing : outgrowing
# two : two
# other : other
# locations : location
# , : ,
# the : the
# company : company
# leased : leased
# an : an
# office : office
# complex : complex
# from : from
# Silicon : Silicon
# Graphics : Graphics
# , : ,
# at : at
# 1600 : 1600
# Amphitheatre : Amphitheatre
# Parkway : Parkway
# in : in
# Mountain : Mountain
# View : View
# , : ,
# California : California
# . : .
# [ : [
# 41 : 41
# ] : ]
# The : The
# complex : complex
# became : became
# known : known
# as : a
# the : the
# Googleplex : Googleplex
# , : ,
# a : a
# play : play
# on : on
# the : the
# word : word
# googolplex : googolplex
# , : ,
# the : the
# number : number
# one : one
# followed : followed
# by : by
# a : a
# googol : googol
# zeroes : zero
# . : .
# Three : Three
# years : year
# later : later
# , : ,
# Google : Google
# bought : bought
# the : the
# property : property
# from : from
# SGI : SGI
# for : for
# $ : $
# 319 : 319
# million : million
# . : .
# [ : [
# 42 : 42
# ] : ]
# By : By
# that : that
# time : time
# , : ,
# the : the
# name : name
# `` : ``
# Google : Google
# '' : ''
# had : had
# found : found
# its : it
# way : way
# into : into
# everyday : everyday
# language : language
# , : ,
# causing : causing
# the : the
# verb : verb
# `` : ``
# google : google
# '' : ''
# to : to
# be : be
# added : added
# to : to
# the : the
# Merriam-Webster : Merriam-Webster
# Collegiate : Collegiate
# Dictionary : Dictionary
# and : and
# the : the
# Oxford : Oxford
# English : English
# Dictionary : Dictionary
# , : ,
# denoted : denoted
# as : a
# : : :
# `` : ``
# to : to
# use : use
# the : the
# Google : Google
# search : search
# engine : engine
# to : to
# obtain : obtain
# information : information
# on : on
# the : the
# Internet : Internet
# '' : ''
# . : .
# [ : [
# 43 : 43
# ] : ]
# [ : [
# 44 : 44
# ] : ]
# Additionally : Additionally
# , : ,
# in : in
# 2001 : 2001
# Google : Google
# 's : 's
# Investors : Investors
# felt : felt
# the : the
# need : need
# to : to
# have : have
# a : a
# strong : strong
# internal : internal
# management : management
# , : ,
# and : and
# they : they
# agreed : agreed
# to : to
# hire : hire
# Eric : Eric
# Schmidt : Schmidt
# as : a
# the : the
# Chairman : Chairman
# and : and
# CEO : CEO
# of : of
# Google : Google
# [ : [
# 45 : 45
# ] : ]
# Silicon : Silicon
# Graphics : Graphics
# Mountain : Mountain
# View : View
# , : ,
# California : California
# [ : [
# 41 : 41
# ] : ]
# Googleplex : Googleplex
# googolplex : googolplex
# [ : [
# 42 : 42
# ] : ]
# google : google
# Merriam-Webster : Merriam-Webster
# Collegiate : Collegiate
# Dictionary : Dictionary
# Oxford : Oxford
# English : English
# Dictionary : Dictionary
# [ : [
# 43 : 43
# ] : ]
# [ : [
# 44 : 44
# ] : ]
# Eric : Eric
# Schmidt : Schmidt
# [ : [
# 45 : 45
# ] : ]
# Initial : Initial
# public : public
# offering : offering
# Initial : Initial
# public : public
# offering : offering
# Google : Google
# 's : 's
# initial : initial
# public : public
# offering : offering
# ( : (
# IPO : IPO
# ) : )
# took : took
# place : place
# five : five
# years : year
# later : later
# , : ,
# on : on
# August : August
# 19 : 19
# , : ,
# 2004 : 2004
# . : .
# At : At
# that : that
# time : time
# Larry : Larry
# Page : Page
# , : ,
# Sergey : Sergey
# Brin : Brin
# , : ,
# and : and
# Eric : Eric
# Schmidt : Schmidt
# agreed : agreed
# to : to
# work : work
# together : together
# at : at
# Google : Google
# for : for
# 20 : 20
# years : year
# , : ,
# until : until
# the : the
# year : year
# 2024 : 2024
# . : .
# [ : [
# 46 : 46
# ] : ]
# At : At
# IPO : IPO
# , : ,
# the : the
# company : company
# offered : offered
# 19,605,052 : 19,605,052
# shares : share
# at : at
# a : a
# price : price
# of : of
# $ : $
# 85 : 85
# per : per
# share : share
# . : .
# [ : [
# 47 : 47
# ] : ]
# [ : [
# 48 : 48
# ] : ]
# Shares : Shares
# were : were
# sold : sold
# in : in
# an : an
# online : online
# auction : auction
# format : format
# using : using
# a : a
# system : system
# built : built
# by : by
# Morgan : Morgan
# Stanley : Stanley
# and : and
# Credit : Credit
# Suisse : Suisse
# , : ,
# underwriters : underwriter
# for : for
# the : the
# deal : deal
# . : .
# [ : [
# 49 : 49
# ] : ]
# [ : [
# 50 : 50
# ] : ]
# The : The
# sale : sale
# of : of
# $ : $
# 1.67 : 1.67
# billion : billion
# gave : gave
# Google : Google
# a : a
# market : market
# capitalization : capitalization
# of : of
# more : more
# than : than
# $ : $
# 23 : 23
# billion : billion
# . : .
# [ : [
# 51 : 51
# ] : ]
# initial : initial
# public : public
# offering : offering
# [ : [
# 46 : 46
# ] : ]
# [ : [
# 47 : 47
# ] : ]
# [ : [
# 48 : 48
# ] : ]
# Morgan : Morgan
# Stanley : Stanley
# Credit : Credit
# Suisse : Suisse
# [ : [
# 49 : 49
# ] : ]
# [ : [
# 50 : 50
# ] : ]
# market : market
# capitalization : capitalization
# [ : [
# 51 : 51
# ] : ]
# Eric : Eric
# Schmidt : Schmidt
# In : In
# October : October
# 2006 : 2006
# , : ,
# Google : Google
# announced : announced
# that : that
# it : it
# had : had
# acquired : acquired
# the : the
# video-sharing : video-sharing
# site : site
# YouTube : YouTube
# for : for
# $ : $
# 1.65 : 1.65
# billion : billion
# in : in
# Google : Google
# stock : stock
# , : ,
# [ : [
# 52 : 52
# ] : ]
# [ : [
# 53 : 53
# ] : ]
# and : and
# the : the
# deal : deal
# was : wa
# finalized : finalized
# on : on
# November : November
# 13 : 13
# , : ,
# 2006 : 2006
# . : .
# [ : [
# 54 : 54
# ] : ]
# [ : [
# 55 : 55
# ] : ]
# On : On
# April : April
# 13 : 13
# , : ,
# 2007 : 2007
# , : ,
# Google : Google
# reached : reached
# an : an
# agreement : agreement
# to : to
# acquire : acquire
# DoubleClick : DoubleClick
# for : for
# $ : $
# 3.1 : 3.1
# billion : billion
# , : ,
# transferring : transferring
# to : to
# Google : Google
# valuable : valuable
# relationships : relationship
# that : that
# DoubleClick : DoubleClick
# had : had
# with : with
# Web : Web
# publishers : publisher
# and : and
# advertising : advertising
# agencies : agency
# . : .
# [ : [
# 56 : 56
# ] : ]
# [ : [
# 52 : 52
# ] : ]
# [ : [
# 53 : 53
# ] : ]
# [ : [
# 54 : 54
# ] : ]
# [ : [
# 55 : 55
# ] : ]
# DoubleClick : DoubleClick
# [ : [
# 56 : 56
# ] : ]
# In : In
# 2005 : 2005
# , : ,
# The : The
# Washington : Washington
# Post : Post
# reported : reported
# on : on
# a : a
# 700 : 700
# percent : percent
# increase : increase
# in : in
# third-quarter : third-quarter
# profit : profit
# for : for
# Google : Google
# , : ,
# largely : largely
# thanks : thanks
# to : to
# large : large
# companies : company
# shifting : shifting
# their : their
# advertising : advertising
# strategies : strategy
# from : from
# newspapers : newspaper
# , : ,
# magazines : magazine
# , : ,
# and : and
# television : television
# to : to
# the : the
# Internet : Internet
# . : .
# [ : [
# 57 : 57
# ] : ]
# In : In
# May : May
# 2011 : 2011
# , : ,
# the : the
# number : number
# of : of
# monthly : monthly
# unique : unique
# visitors : visitor
# to : to
# Google : Google
# surpassed : surpassed
# one : one
# billion : billion
# for : for
# the : the
# first : first
# time : time
# . : .
# [ : [
# 58 : 58
# ] : ]
# By : By
# 2011 : 2011
# , : ,
# Google : Google
# was : wa
# handling : handling
# approximately : approximately
# 3 : 3
# billion : billion
# searches : search
# per : per
# day : day
# . : .
# To : To
# handle : handle
# this : this
# workload : workload
# , : ,
# Google : Google
# built : built
# 11 : 11
# datacenters : datacenters
# around : around
# the : the
# world : world
# with : with
# some : some
# several : several
# thousand : thousand
# servers : server
# in : in
# each : each
# . : .
# These : These
# datacenters : datacenters
# allowed : allowed
# Google : Google
# to : to
# handle : handle
# the : the
# ever : ever
# changing : changing
# workload : workload
# more : more
# efficiently : efficiently
# . : .
# [ : [
# 45 : 45
# ] : ]
# The : The
# Washington : Washington
# Post : Post
# [ : [
# 57 : 57
# ] : ]
# [ : [
# 58 : 58
# ] : ]
# datacenters : datacenters
# [ : [
# 45 : 45
# ] : ]
# On : On
# August : August
# 15 : 15
# , : ,
# 2011 : 2011
# , : ,
# Google : Google
# made : made
# its : it
# largest-ever : largest-ever
# acquisition : acquisition
# to : to
# date : date
# when : when
# it : it
# announced : announced
# that : that
# it : it
# would : would
# acquire : acquire
# Motorola : Motorola
# Mobility : Mobility
# for : for
# $ : $
# 12.5 : 12.5
# billion : billion
# [ : [
# 59 : 59
# ] : ]
# [ : [
# 60 : 60
# ] : ]
# This : This
# purchase : purchase
# was : wa
# made : made
# in : in
# part : part
# to : to
# help : help
# Google : Google
# gain : gain
# Motorola : Motorola
# 's : 's
# considerable : considerable
# patent : patent
# portfolio : portfolio
# on : on
# mobile : mobile
# phones : phone
# and : and
# wireless : wireless
# technologies : technology
# , : ,
# to : to
# help : help
# protect : protect
# Google : Google
# in : in
# its : it
# ongoing : ongoing
# patent : patent
# disputes : dispute
# with : with
# other : other
# companies : company
# , : ,
# [ : [
# 61 : 61
# ] : ]
# mainly : mainly
# Apple : Apple
# and : and
# Microsoft : Microsoft
# , : ,
# [ : [
# 62 : 62
# ] : ]
# and : and
# to : to
# allow : allow
# it : it
# to : to
# continue : continue
# to : to
# freely : freely
# offer : offer
# Android : Android
# . : .
# [ : [
# 63 : 63
# ] : ]
# Motorola : Motorola
# Mobility : Mobility
# [ : [
# 59 : 59
# ] : ]
# [ : [
# 60 : 60
# ] : ]
# [ : [
# 61 : 61
# ] : ]
# Apple : Apple
# Microsoft : Microsoft
# [ : [
# 62 : 62
# ] : ]
# Android : Android
# [ : [
# 63 : 63
# ] : ]
# 2012 : 2012
# onward : onward
# 2012 : 2012
# onward : onward
# The : The
# year : year
# 2012 : 2012
# was : wa
# the : the
# first : first
# time : time
# that : that
# Google : Google
# generated : generated
# $ : $
# 50 : 50
# billion : billion
# in : in
# annual : annual
# revenue : revenue
# , : ,
# generating : generating
# $ : $
# 38 : 38
# billion : billion
# the : the
# previous : previous
# year : year
# . : .
# In : In
# January : January
# 2013 : 2013
# , : ,
# then-CEO : then-CEO
# Larry : Larry
# Page : Page
# commented : commented
# , : ,
# `` : ``
# We : We
# ended : ended
# 2012 : 2012
# with : with
# a : a
# strong : strong
# quarter : quarter
# ... : ...
# Revenues : Revenues
# were : were
# up : up
# 36 : 36
# % : %
# year-on-year : year-on-year
# , : ,
# and : and
# 8 : 8
# % : %
# quarter-on-quarter : quarter-on-quarter
# . : .
# And : And
# we : we
# hit : hit
# $ : $
# 50 : 50
# billion : billion
# in : in
# revenues : revenue
# for : for
# the : the
# first : first
# time : time
# last : last
# year : year
# – : –
# not : not
# a : a
# bad : bad
# achievement : achievement
# in : in
# just : just
# a : a
# decade : decade
# and : and
# a : a
# half : half
# . : .
# `` : ``
# [ : [
# 64 : 64
# ] : ]
# [ : [
# 64 : 64
# ] : ]
# In : In
# June : June
# 2013 : 2013
# , : ,
# Google : Google
# acquired : acquired
# Waze : Waze
# , : ,
# a : a
# $ : $
# 966 : 966
# million : million
# deal : deal
# . : .
# [ : [
# 65 : 65
# ] : ]
# While : While
# Waze : Waze
# would : would
# remain : remain
# an : an
# independent : independent
# entity : entity
# , : ,
# its : it
# social : social
# features : feature
# , : ,
# such : such
# as : a
# its : it
# crowdsourced : crowdsourced
# location : location
# platform : platform
# , : ,
# were : were
# reportedly : reportedly
# valuable : valuable
# integrations : integration
# between : between
# Waze : Waze
# and : and
# Google : Google
# Maps : Maps
# , : ,
# Google : Google
# 's : 's
# own : own
# mapping : mapping
# service : service
# . : .
# [ : [
# 66 : 66
# ] : ]
# Waze : Waze
# [ : [
# 65 : 65
# ] : ]
# Google : Google
# Maps : Maps
# [ : [
# 66 : 66
# ] : ]
# Google : Google
# announced : announced
# the : the
# launch : launch
# of : of
# a : a
# new : new
# company : company
# , : ,
# called : called
# Calico : Calico
# , : ,
# on : on
# September : September
# 19 : 19
# , : ,
# 2013 : 2013
# , : ,
# to : to
# be : be
# led : led
# by : by
# Apple : Apple
# , : ,
# Inc. : Inc.
# chairman : chairman
# Arthur : Arthur
# Levinson : Levinson
# . : .
# In : In
# the : the
# official : official
# public : public
# statement : statement
# , : ,
# Page : Page
# explained : explained
# that : that
# the : the
# `` : ``
# health : health
# and : and
# well-being : well-being
# '' : ''
# company : company
# would : would
# focus : focus
# on : on
# `` : ``
# the : the
# challenge : challenge
# of : of
# ageing : ageing
# and : and
# associated : associated
# diseases : disease
# '' : ''
# . : .
# [ : [
# 67 : 67
# ] : ]
# Calico : Calico
# Apple : Apple
# , : ,
# Inc. : Inc.
# Arthur : Arthur
# Levinson : Levinson
# [ : [
# 67 : 67
# ] : ]
# On : On
# January : January
# 26 : 26
# , : ,
# 2014 : 2014
# , : ,
# Google : Google
# announced : announced
# it : it
# had : had
# agreed : agreed
# to : to
# acquire : acquire
# DeepMind : DeepMind
# Technologies : Technologies
# , : ,
# a : a
# privately : privately
# held : held
# artificial : artificial
# intelligence : intelligence
# company : company
# from : from
# London : London
# . : .
# [ : [
# 68 : 68
# ] : ]
# Technology : Technology
# news : news
# website : website
# Recode : Recode
# reported : reported
# that : that
# the : the
# company : company
# was : wa
# purchased : purchased
# for : for
# $ : $
# 400 : 400
# million : million
# though : though
# it : it
# was : wa
# not : not
# disclosed : disclosed
# where : where
# the : the
# information : information
# came : came
# from : from
# . : .
# A : A
# Google : Google
# spokesman : spokesman
# would : would
# not : not
# comment : comment
# of : of
# the : the
# price : price
# . : .
# [ : [
# 69 : 69
# ] : ]
# [ : [
# 70 : 70
# ] : ]
# The : The
# purchase : purchase
# of : of
# DeepMind : DeepMind
# aids : aid
# in : in
# Google : Google
# 's : 's
# recent : recent
# growth : growth
# in : in
# the : the
# artificial : artificial
# intelligence : intelligence
# and : and
# robotics : robotics
# community : community
# . : .
# [ : [
# 71 : 71
# ] : ]
# DeepMind : DeepMind
# Technologies : Technologies
# London : London
# [ : [
# 68 : 68
# ] : ]
# Recode : Recode
# [ : [
# 69 : 69
# ] : ]
# [ : [
# 70 : 70
# ] : ]
# [ : [
# 71 : 71
# ] : ]
# According : According
# to : to
# Interbrand : Interbrand
# 's : 's
# annual : annual
# Best : Best
# Global : Global
# Brands : Brands
# report : report
# , : ,
# Google : Google
# has : ha
# been : been
# the : the
# second : second
# most : most
# valuable : valuable
# brand : brand
# in : in
# the : the
# world : world
# ( : (
# behind : behind
# Apple : Apple
# Inc. : Inc.
# ) : )
# in : in
# 2013 : 2013
# , : ,
# [ : [
# 72 : 72
# ] : ]
# 2014 : 2014
# , : ,
# [ : [
# 73 : 73
# ] : ]
# 2015 : 2015
# , : ,
# [ : [
# 74 : 74
# ] : ]
# and : and
# 2016 : 2016
# , : ,
# with : with
# a : a
# valuation : valuation
# of : of
# $ : $
# 133 : 133
# billion : billion
# . : .
# [ : [
# 75 : 75
# ] : ]
# Interbrand : Interbrand
# Apple : Apple
# Inc. : Inc.
# [ : [
# 72 : 72
# ] : ]
# [ : [
# 73 : 73
# ] : ]
# [ : [
# 74 : 74
# ] : ]
# [ : [
# 75 : 75
# ] : ]
# On : On
# August : August
# 10 : 10
# , : ,
# 2015 : 2015
# , : ,
# Google : Google
# announced : announced
# plans : plan
# to : to
# reorganize : reorganize
# its : it
# various : various
# interests : interest
# as : a
# a : a
# conglomerate : conglomerate
# called : called
# Alphabet : Alphabet
# . : .
# Google : Google
# became : became
# Alphabet : Alphabet
# 's : 's
# leading : leading
# subsidiary : subsidiary
# , : ,
# and : and
# will : will
# continue : continue
# to : to
# be : be
# the : the
# umbrella : umbrella
# company : company
# for : for
# Alphabet : Alphabet
# 's : 's
# Internet : Internet
# interests : interest
# . : .
# Upon : Upon
# completion : completion
# of : of
# the : the
# restructure : restructure
# , : ,
# Sundar : Sundar
# Pichai : Pichai
# became : became
# CEO : CEO
# of : of
# Google : Google
# , : ,
# replacing : replacing
# Larry : Larry
# Page : Page
# , : ,
# who : who
# became : became
# CEO : CEO
# of : of
# Alphabet : Alphabet
# . : .
# [ : [
# 76 : 76
# ] : ]
# [ : [
# 77 : 77
# ] : ]
# [ : [
# 78 : 78
# ] : ]
# conglomerate : conglomerate
# Alphabet : Alphabet
# Sundar : Sundar
# Pichai : Pichai
# Larry : Larry
# Page : Page
# [ : [
# 76 : 76
# ] : ]
# [ : [
# 77 : 77
# ] : ]
# [ : [
# 78 : 78
# ] : ]
# As : As
# of : of
# October : October
# 2016 : 2016
# , : ,
# [ : [
# update : update
# ] : ]
# Google : Google
# operates : operates
# 70 : 70
# offices : office
# in : in
# more : more
# than : than
# 40 : 40
# countries : country
# . : .
# [ : [
# 79 : 79
# ] : ]
# Alexa : Alexa
# , : ,
# a : a
# company : company
# that : that
# monitors : monitor
# commercial : commercial
# web : web
# traffic : traffic
# , : ,
# lists : list
# Google.com : Google.com
# as : a
# the : the
# most : most
# visited : visited
# website : website
# in : in
# the : the
# world : world
# . : .
# [ : [
# 9 : 9
# ] : ]
# Several : Several
# other : other
# Google : Google
# services : service
# also : also
# figure : figure
# in : in
# the : the
# top : top
# 100 : 100
# most : most
# visited : visited
# websites : website
# , : ,
# including : including
# YouTube : YouTube
# [ : [
# 80 : 80
# ] : ]
# and : and
# Blogger : Blogger
# . : .
# [ : [
# 81 : 81
# ] : ]
# [ : [
# update : update
# ] : ]
# [ : [
# 79 : 79
# ] : ]
# Alexa : Alexa
# [ : [
# 9 : 9
# ] : ]
# [ : [
# 80 : 80
# ] : ]
# [ : [
# 81 : 81
# ] : ]
# On : On
# August : August
# 8 : 8
# , : ,
# 2017 : 2017
# , : ,
# Google : Google
# fired : fired
# employee : employee
# James : James
# Damore : Damore
# after : after
# he : he
# distributed : distributed
# a : a
# memo : memo
# throughout : throughout
# the : the
# company : company
# which : which
# argued : argued
# that : that
# `` : ``
# Google : Google
# 's : 's
# ideological : ideological
# echo : echo
# chamber : chamber
# '' : ''
# and : and
# bias : bias
# clouded : clouded
# their : their
# thinking : thinking
# about : about
# diversity : diversity
# and : and
# inclusion : inclusion
# , : ,
# and : and
# that : that
# it : it
# is : is
# also : also
# biological : biological
# factors : factor
# , : ,
# not : not
# discrimination : discrimination
# alone : alone
# , : ,
# that : that
# cause : cause
# the : the
# average : average
# woman : woman
# to : to
# be : be
# less : le
# interested : interested
# than : than
# men : men
# in : in
# technical : technical
# positions : position
# . : .
# [ : [
# 82 : 82
# ] : ]
# Google : Google
# CEO : CEO
# Sundar : Sundar
# Pichai : Pichai
# accused : accused
# Damore : Damore
# in : in
# violating : violating
# company : company
# policy : policy
# by : by
# `` : ``
# advancing : advancing
# harmful : harmful
# gender : gender
# stereotypes : stereotype
# in : in
# our : our
# workplace : workplace
# '' : ''
# , : ,
# and : and
# he : he
# was : wa
# fired : fired
# on : on
# the : the
# same : same
# day : day
# . : .
# [ : [
# 83 : 83
# ] : ]
# [ : [
# 84 : 84
# ] : ]
# [ : [
# 85 : 85
# ] : ]
# New : New
# York : York
# Times : Times
# columnist : columnist
# David : David
# Brooks : Brooks
# argued : argued
# Pichai : Pichai
# had : had
# mishandled : mishandled
# the : the
# case : case
# , : ,
# and : and
# called : called
# for : for
# his : his
# resignation : resignation
# . : .
# [ : [
# 86 : 86
# ] : ]
# [ : [
# 87 : 87
# ] : ]
# Google : Google
# 's : 's
# ideological : ideological
# echo : echo
# chamber : chamber
# [ : [
# 82 : 82
# ] : ]
# [ : [
# 83 : 83
# ] : ]
# [ : [
# 84 : 84
# ] : ]
# [ : [
# 85 : 85
# ] : ]
# David : David
# Brooks : Brooks
# [ : [
# 86 : 86
# ] : ]
# [ : [
# 87 : 87
# ] : ]
# On : On
# October : October
# 25 : 25
# , : ,
# 2018 : 2018
# , : ,
# The : The
# New : New
# York : York
# Times : Times
# published : published
# the : the
# exposé : exposé
# , : ,
# `` : ``
# How : How
# Google : Google
# Protected : Protected
# Andy : Andy
# Rubin : Rubin
# , : ,
# the : the
# ‘ : ‘
# Father : Father
# of : of
# Android : Android
# ’ : ’
# '' : ''
# . : .
# The : The
# company : company
# subsequently : subsequently
# announced : announced
# that : that
# `` : ``
# 48 : 48
# employees : employee
# have : have
# been : been
# fired : fired
# over : over
# the : the
# last : last
# two : two
# years : year
# '' : ''
# for : for
# sexual : sexual
# misconduct : misconduct
# . : .
# [ : [
# 88 : 88
# ] : ]
# On : On
# November : November
# 1 : 1
# , : ,
# 2018 : 2018
# , : ,
# more : more
# than : than
# 20,000 : 20,000
# Google : Google
# employees : employee
# and : and
# contractors : contractor
# staged : staged
# a : a
# global : global
# walk-out : walk-out
# to : to
# protest : protest
# the : the
# company : company
# 's : 's
# handling : handling
# of : of
# sexual : sexual
# harassment : harassment
# complaints : complaint
# . : .
# [ : [
# 89 : 89
# ] : ]
# [ : [
# 90 : 90
# ] : ]
# The : The
# New : New
# York : York
# Times : Times
# Andy : Andy
# Rubin : Rubin
# [ : [
# 88 : 88
# ] : ]
# [ : [
# 89 : 89
# ] : ]
# [ : [
# 90 : 90
# ] : ]
# On : On
# March : March
# 19 : 19
# , : ,
# 2019 : 2019
# , : ,
# Google : Google
# announced : announced
# that : that
# it : it
# would : would
# enter : enter
# the : the
# video : video
# game : game
# market : market
# , : ,
# launching : launching
# a : a
# cloud : cloud
# gaming : gaming
# platform : platform
# called : called
# Google : Google
# Stadia : Stadia
# . : .
# [ : [
# 91 : 91
# ] : ]
# cloud : cloud
# gaming : gaming
# Google : Google
# Stadia : Stadia
# [ : [
# 91 : 91
# ] : ]
# On : On
# June : June
# 3 : 3
# , : ,
# 2019 : 2019
# , : ,
# the : the
# United : United
# States : States
# Department : Department
# of : of
# Justice : Justice
# reported : reported
# that : that
# it : it
# would : would
# investigate : investigate
# Google : Google
# for : for
# antitrust : antitrust
# violations : violation
# . : .
# [ : [
# 92 : 92
# ] : ]
# United : United
# States : States
# Department : Department
# of : of
# Justice : Justice
# antitrust : antitrust
# [ : [
# 92 : 92
# ] : ]
# Products : Products
# and : and
# services : service
# Products : Products
# and : and
# services : service
# List : List
# of : of
# Google : Google
# products : product
# Search : Search
# engine : engine
# Search : Search
# engine : engine
# Google : Google
# Search : Search
# Google : Google
# Images : Images
# [ : [
# update : update
# ] : ]
# Google : Google
# indexes : index
# billions : billion
# of : of
# web : web
# pages : page
# to : to
# allow : allow
# users : user
# to : to
# search : search
# for : for
# the : the
# information : information
# they : they
# desire : desire
# through : through
# the : the
# use : use
# of : of
# keywords : keywords
# and : and
# operators : operator
# . : .
# [ : [
# 93 : 93
# ] : ]
# According : According
# to : to
# comScore : comScore
# market : market
# research : research
# from : from
# November : November
# 2009 : 2009
# , : ,
# Google : Google
# Search : Search
# is : is
# the : the
# dominant : dominant
# search : search
# engine : engine
# in : in
# the : the
# United : United
# States : States
# market : market
# , : ,
# with : with
# a : a
# market : market
# share : share
# of : of
# 65.6 : 65.6
# % : %
# . : .
# [ : [
# 94 : 94
# ] : ]
# In : In
# May : May
# 2017 : 2017
# , : ,
# Google : Google
# enabled : enabled
# a : a
# new : new
# `` : ``
# Personal : Personal
# '' : ''
# tab : tab
# in : in
# Google : Google
# Search : Search
# , : ,
# letting : letting
# users : user
# search : search
# for : for
# content : content
# in : in
# their : their
# Google : Google
# accounts : account
# ' : '
# various : various
# services : service
# , : ,
# including : including
# email : email
# messages : message
# from : from
# Gmail : Gmail
# and : and
# photos : photo
# from : from
# Google : Google
# Photos : Photos
# . : .
# [ : [
# 95 : 95
# ] : ]
# [ : [
# 96 : 96
# ] : ]
# indexes : index
# operators : operator
# [ : [
# 93 : 93
# ] : ]
# comScore : comScore
# Google : Google
# Search : Search
# market : market
# share : share
# [ : [
# 94 : 94
# ] : ]
# Gmail : Gmail
# Google : Google
# Photos : Photos
# [ : [
# 95 : 95
# ] : ]
# [ : [
# 96 : 96
# ] : ]
# Google : Google
# launched : launched
# its : it
# Google : Google
# News : News
# service : service
# in : in
# 2002 : 2002
# , : ,
# an : an
# automated : automated
# service : service
# which : which
# summarizes : summarizes
# news : news
# articles : article
# from : from
# various : various
# websites : website
# . : .
# [ : [
# 97 : 97
# ] : ]
# Google : Google
# also : also
# hosts : host
# Google : Google
# Books : Books
# , : ,
# a : a
# service : service
# which : which
# searches : search
# the : the
# text : text
# found : found
# in : in
# books : book
# in : in
# its : it
# database : database
# and : and
# shows : show
# limited : limited
# previews : preview
# or : or
# and : and
# the : the
# full : full
# book : book
# where : where
# allowed : allowed
# . : .
# [ : [
# 98 : 98
# ] : ]
# Google : Google
# News : News
# [ : [
# 97 : 97
# ] : ]
# Google : Google
# Books : Books
# [ : [
# 98 : 98
# ] : ]
# Advertising : Advertising
# Advertising : Advertising
# As : As
# per : per
# its : it
# 2017 : 2017
# Annual : Annual
# report : report
# , : ,
# Google : Google
# generates : generates
# most : most
# of : of
# its : it
# revenues : revenue
# from : from
# advertising : advertising
# . : .
# This : This
# includes : includes
# sales : sale
# of : of
# apps : apps
# , : ,
# purchases : purchase
# made : made
# in-app : in-app
# , : ,
# digital : digital
# content : content
# products : product
# on : on
# google : google
# and : and
# YouTube : YouTube
# , : ,
# android : android
# and : and
# licensing : licensing
# and : and
# service : service
# fees : fee
# , : ,
# including : including
# fees : fee
# received : received
# for : for
# Google : Google
# Cloud : Cloud
# offerings : offering
# . : .
# 46 : 46
# % : %
# of : of
# this : this
# was : wa
# from : from
# clicks : click
# ( : (
# cost : cost
# per : per
# clicks : click
# ) : )
# , : ,
# amounting : amounting
# to : to
# US : US
# $ : $
# 109,652 : 109,652
# million : million
# in : in
# 2017 : 2017
# . : .
# This : This
# includes : includes
# three : three
# principal : principal
# methods : method
# , : ,
# namely : namely
# AdMob : AdMob
# , : ,
# AdSense : AdSense
# ( : (
# such : such
# as : a
# AdSense : AdSense
# for : for
# Content : Content
# , : ,
# AdSense : AdSense
# for : for
# Search : Search
# , : ,
# etc : etc
# . : .
# ) : )
# and : and
# DoubleClick : DoubleClick
# AdExchange : AdExchange
# . : .
# [ : [
# 99 : 99
# ] : ]
# AdMob : AdMob
# AdSense : AdSense
# AdSense : AdSense
# [ : [
# 99 : 99
# ] : ]
# For : For
# the : the
# 2006 : 2006
# ...
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# 2015All : 2015All
# articles : article
# containing : containing
# potentially : potentially
# dated : dated
# statementsArticles : statementsArticles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# December : December
# 2018Articles : 2018Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# 2017Articles : 2017Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# October : October
# 2016Articles : 2016Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# April : April
# 2019Articles : 2019Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# August : August
# 2015Articles : 2015Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# 1998Articles : 1998Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# June : June
# 2017Articles : 2017Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# 2007Articles : 2007Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# February : February
# 2009Portal : 2009Portal
# templates : template
# with : with
# redlinked : redlinked
# portalsCrunchbase : portalsCrunchbase
# template : template
# with : with
# organization : organization
# IDOpenCorporates : IDOpenCorporates
# groupingsWikipedia : groupingsWikipedia
# articles : article
# with : with
# BIBSYS : BIBSYS
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# BNF : BNF
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# GND : GND
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# ISNI : ISNI
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# LCCN : LCCN
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# NKC : NKC
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# NLA : NLA
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# SELIBR : SELIBR
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# SUDOC : SUDOC
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# VIAF : VIAF
# identifiersWikipedia : identifiersWikipedia
# articles : article
# with : with
# WorldCat-VIAF : WorldCat-VIAF
# identifiers : identifier
# Webarchive : Webarchive
# template : template
# wayback : wayback
# links : link
# Webarchive : Webarchive
# template : template
# webcite : webcite
# links : link
# CS1 : CS1
# maint : maint
# : : :
# Multiple : Multiple
# names : name
# : : :
# authors : author
# list : list
# CS1 : CS1
# maint : maint
# : : :
# Archived : Archived
# copy : copy
# as : a
# title : title
# CS1 : CS1
# maint : maint
# : : :
# BOT : BOT
# : : :
# original-url : original-url
# status : status
# unknown : unknown
# Webarchive : Webarchive
# template : template
# archiveis : archiveis
# links : link
# Pages : Pages
# containing : containing
# links : link
# to : to
# subscription-only : subscription-only
# content : content
# Wikipedia : Wikipedia
# indefinitely : indefinitely
# semi-protected : semi-protected
# pages : page
# Wikipedia : Wikipedia
# indefinitely : indefinitely
# move-protected : move-protected
# pages : page
# Articles : Articles
# with : with
# short : short
# description : description
# Use : Use
# American : American
# English : English
# from : from
# July : July
# 2018 : 2018
# All : All
# Wikipedia : Wikipedia
# articles : article
# written : written
# in : in
# American : American
# English : English
# Use : Use
# mdy : mdy
# dates : date
# from : from
# April : April
# 2019 : 2019
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# 2015 : 2015
# All : All
# articles : article
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# December : December
# 2018 : 2018
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# 2017 : 2017
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# October : October
# 2016 : 2016
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# April : April
# 2019 : 2019
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# August : August
# 2015 : 2015
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# 1998 : 1998
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# June : June
# 2017 : 2017
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# 2007 : 2007
# Articles : Articles
# containing : containing
# potentially : potentially
# dated : dated
# statements : statement
# from : from
# February : February
# 2009 : 2009
# Portal : Portal
# templates : template
# with : with
# redlinked : redlinked
# portals : portal
# Crunchbase : Crunchbase
# template : template
# with : with
# organization : organization
# ID : ID
# OpenCorporates : OpenCorporates
# groupings : grouping
# Wikipedia : Wikipedia
# articles : article
# with : with
# BIBSYS : BIBSYS
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# BNF : BNF
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# GND : GND
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# ISNI : ISNI
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# LCCN : LCCN
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# NKC : NKC
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# NLA : NLA
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# SELIBR : SELIBR
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# SUDOC : SUDOC
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# VIAF : VIAF
# identifiers : identifier
# Wikipedia : Wikipedia
# articles : article
# with : with
# WorldCat-VIAF : WorldCat-VIAF
# identifiers : identifier
# Navigation : Navigation
# menu : menu
# Personal : Personal
# tools : tool
# Not : Not
# logged : logged
# inTalkContributionsCreate : inTalkContributionsCreate
# accountLog : accountLog
# in : in
# Talk : Talk
# Contributions : Contributions
# Create : Create
# account : account
# Log : Log
# in : in
# Namespaces : Namespaces
# ArticleTalk : ArticleTalk
# Article : Article
# Article : Article
# Talk : Talk
# Talk : Talk
# Variants : Variants
# Variants : Variants
# Views : Views
# ReadView : ReadView
# sourceView : sourceView
# history : history
# Read : Read
# Read : Read
# View : View
# source : source
# View : View
# source : source
# View : View
# history : history
# View : View
# history : history
# More : More
# More : More
# Search : Search
# Navigation : Navigation
# Main : Main
# pageContentsFeatured : pageContentsFeatured
# contentCurrent : contentCurrent
# eventsRandom : eventsRandom
# articleDonate : articleDonate
# to : to
# WikipediaWikipedia : WikipediaWikipedia
# store : store
# Main : Main
# page : page
# Contents : Contents
# Featured : Featured
# content : content
# Current : Current
# events : event
# Random : Random
# article : article
# Donate : Donate
# to : to
# Wikipedia : Wikipedia
# Wikipedia : Wikipedia
# store : store
# Interaction : Interaction
# HelpAbout : HelpAbout
# WikipediaCommunity : WikipediaCommunity
# portalRecent : portalRecent
# changesContact : changesContact
# page : page
# Help : Help
# About : About
# Wikipedia : Wikipedia
# Community : Community
# portal : portal
# Recent : Recent
# changes : change
# Contact : Contact
# page : page
# Tools : Tools
# What : What
# links : link
# hereRelated : hereRelated
# changesUpload : changesUpload
# fileSpecial : fileSpecial
# pagesPermanent : pagesPermanent
# linkPage : linkPage
# informationWikidata : informationWikidata
# itemCite : itemCite
# this : this
# page : page
# What : What
# links : link
# here : here
# Related : Related
# changes : change
# Upload : Upload
# file : file
# Special : Special
# pages : page
# Permanent : Permanent
# link : link
# Page : Page
# information : information
# Wikidata : Wikidata
# item : item
# Cite : Cite
# this : this
# page : page
# In : In
# other : other
# projects : project
# Wikimedia : Wikimedia
# CommonsMeta-WikiWikiquoteWikiversity : CommonsMeta-WikiWikiquoteWikiversity
# Wikimedia : Wikimedia
# Commons : Commons
# Meta-Wiki : Meta-Wiki
# Wikiquote : Wikiquote
# Wikiversity : Wikiversity
# Print/export : Print/export
# Create : Create
# a : a
# bookDownload : bookDownload
# as : a
# PDFPrintable : PDFPrintable
# version : version
# Create : Create
# a : a
# book : book
# Download : Download
# as : a
# PDF : PDF
# Printable : Printable
# version : version
# Languages : Languages
# AfrikaansአማርኛÆngliscالعربيةঅসমীয়াAsturianuAzərbaycancaتۆرکجهBamanankanবাংলাBahasa : AfrikaansአማርኛÆngliscالعربيةঅসমীয়াAsturianuAzərbaycancaتۆرکجهBamanankanবাংলাBahasa
# BanjarBân-lâm-gúБеларускаяБеларуская : BanjarBân-lâm-gúБеларускаяБеларуская
# ( : (
# тарашкевіца : тарашкевіца
# ) : )
# ‎भोजपुरीБългарскиBoarischBosanskiBrezhonegCatalàЧӑвашлаCebuanoČeštinaCymraegDanskDeutschDolnoserbskiडोटेलीEestiΕλληνικάEspañolEsperantoEuskaraفارسیFøroysktFrançaisGaeilgeGalego贛語ગુજરાતી客家語/Hak-kâ-ngî한국어Հայերենहिन्दीHornjoserbsceHrvatskiBahasa : ‎भोजपुरीБългарскиBoarischBosanskiBrezhonegCatalàЧӑвашлаCebuanoČeštinaCymraegDanskDeutschDolnoserbskiडोटेलीEestiΕλληνικάEspañolEsperantoEuskaraفارسیFøroysktFrançaisGaeilgeGalego贛語ગુજરાતી客家語/Hak-kâ-ngî한국어Հայերենहिन्दीHornjoserbsceHrvatskiBahasa
# HulontaloIdoBahasa : HulontaloIdoBahasa
# Indonesiaᐃᓄᒃᑎᑐᑦ/inuktitutÍslenskaItalianoעבריתJawaKabɩyɛಕನ್ನಡქართულიҚазақшаKirundiKreyòl : Indonesiaᐃᓄᒃᑎᑐᑦ/inuktitutÍslenskaItalianoעבריתJawaKabɩyɛಕನ್ನಡქართულიҚазақшаKirundiKreyòl
# ayisyenKurdîКыргызчаລາວلۊری : ayisyenKurdîКыргызчаລາວلۊری
# شومالیLatinaLatviešuLietuviųMagyarमैथिलीМакедонскиMalagasyമലയാളംमराठीმარგალურიمصرىمازِرونیBahasa : شومالیLatinaLatviešuLietuviųMagyarमैथिलीМакедонскиMalagasyമലയാളംमराठीმარგალურიمصرىمازِرونیBahasa
# MelayuMìng-dĕ̤ng-ngṳ̄Монголမြန်မာဘာသာNāhuatlNederlandsनेपाली日本語NorskNorsk : MelayuMìng-dĕ̤ng-ngṳ̄Монголမြန်မာဘာသာNāhuatlNederlandsनेपाली日本語NorskNorsk
# nynorskOccitanଓଡ଼ିଆOʻzbekcha/ўзбекчаਪੰਜਾਬੀپنجابیپښتوភាសាខ្មែរPiemontèisPlattdüütschPolskiPortuguêsQaraqalpaqshaRomânăRuna : nynorskOccitanଓଡ଼ିଆOʻzbekcha/ўзбекчаਪੰਜਾਬੀپنجابیپښتوភាសាខ្មែរPiemontèisPlattdüütschPolskiPortuguêsQaraqalpaqshaRomânăRuna
# SimiРусскийСаха : SimiРусскийСаха
# тылаᱥᱟᱱᱛᱟᱲᱤScotsShqipSicilianuසිංහලSimple : тылаᱥᱟᱱᱛᱟᱲᱤScotsShqipSicilianuසිංහලSimple
# EnglishسنڌيSlovenčinaSlovenščinaSoomaaligaکوردیСрпски : EnglishسنڌيSlovenčinaSlovenščinaSoomaaligaکوردیСрпски
# / : /
# srpskiSrpskohrvatski : srpskiSrpskohrvatski
# / : /
# српскохрватскиBasa : српскохрватскиBasa
# SundaSuomiSvenskaTagalogதமிழ்Татарча/tatarçaతెలుగుTetunไทยТоҷикӣತುಳುTürkçeTürkmençeThuɔŋjäŋУкраїнськаاردوئۇيغۇرچە : SundaSuomiSvenskaTagalogதமிழ்Татарча/tatarçaతెలుగుTetunไทยТоҷикӣತುಳುTürkçeTürkmençeThuɔŋjäŋУкраїнськаاردوئۇيغۇرچە
# / : /
# UyghurcheVènetoTiếng : UyghurcheVènetoTiếng
# ViệtWalon文言West-VlamsWinaray吴语ייִדישYorùbá粵語ZazakiZeêuwsŽemaitėška中文 : ViệtWalon文言West-VlamsWinaray吴语ייִדישYorùbá粵語ZazakiZeêuwsŽemaitėška中文
# Afrikaans : Afrikaans
# አማርኛ : አማርኛ
# Ænglisc : Ænglisc
# العربية : العربية
# অসমীয়া : অসমীয়া
# Asturianu : Asturianu
# Azərbaycanca : Azərbaycanca
# تۆرکجه : تۆرکجه
# Bamanankan : Bamanankan
# বাংলা : বাংলা
# Bahasa : Bahasa
# Banjar : Banjar
# Bân-lâm-gú : Bân-lâm-gú
# Беларуская : Беларуская
# Беларуская : Беларуская
# ( : (
# тарашкевіца : тарашкевіца
# ) : )
# ‎ : ‎
# भोजपुरी : भोजपुरी
# Български : Български
# Boarisch : Boarisch
# Bosanski : Bosanski
# Brezhoneg : Brezhoneg
# Català : Català
# Чӑвашла : Чӑвашла
# Cebuano : Cebuano
# Čeština : Čeština
# Cymraeg : Cymraeg
# Dansk : Dansk
# Deutsch : Deutsch
# Dolnoserbski : Dolnoserbski
# डोटेली : डोटेली
# Eesti : Eesti
# Ελληνικά : Ελληνικά
# Español : Español
# Esperanto : Esperanto
# Euskara : Euskara
# فارسی : فارسی
# Føroyskt : Føroyskt
# Français : Français
# Gaeilge : Gaeilge
# Galego : Galego
# 贛語 : 贛語
# ગુજરાતી : ગુજરાતી
# 客家語/Hak-kâ-ngî : 客家語/Hak-kâ-ngî
# 한국어 : 한국어
# Հայերեն : Հայերեն
# हिन्दी : हिन्दी
# Hornjoserbsce : Hornjoserbsce
# Hrvatski : Hrvatski
# Bahasa : Bahasa
# Hulontalo : Hulontalo
# Ido : Ido
# Bahasa : Bahasa
# Indonesia : Indonesia
# ᐃᓄᒃᑎᑐᑦ/inuktitut : ᐃᓄᒃᑎᑐᑦ/inuktitut
# Íslenska : Íslenska
# Italiano : Italiano
# עברית : עברית
# Jawa : Jawa
# Kabɩyɛ : Kabɩyɛ
# ಕನ್ನಡ : ಕನ್ನಡ
# ქართული : ქართული
# Қазақша : Қазақша
# Kirundi : Kirundi
# Kreyòl : Kreyòl
# ayisyen : ayisyen
# Kurdî : Kurdî
# Кыргызча : Кыргызча
# ລາວ : ລາວ
# لۊری : لۊری
# شومالی : شومالی
# Latina : Latina
# Latviešu : Latviešu
# Lietuvių : Lietuvių
# Magyar : Magyar
# मैथिली : मैथिली
# Македонски : Македонски
# Malagasy : Malagasy
# മലയാളം : മലയാളം
# मराठी : मराठी
# მარგალური : მარგალური
# مصرى : مصرى
# مازِرونی : مازِرونی
# Bahasa : Bahasa
# Melayu : Melayu
# Mìng-dĕ̤ng-ngṳ̄ : Mìng-dĕ̤ng-ngṳ̄
# Монгол : Монгол
# မြန်မာဘာသာ : မြန်မာဘာသာ
# Nāhuatl : Nāhuatl
# Nederlands : Nederlands
# नेपाली : नेपाली
# 日本語 : 日本語
# Norsk : Norsk
# Norsk : Norsk
# nynorsk : nynorsk
# Occitan : Occitan
# ଓଡ଼ିଆ : ଓଡ଼ିଆ
# Oʻzbekcha/ўзбекча : Oʻzbekcha/ўзбекча
# ਪੰਜਾਬੀ : ਪੰਜਾਬੀ
# پنجابی : پنجابی
# پښتو : پښتو
# ភាសាខ្មែរ : ភាសាខ្មែរ
# Piemontèis : Piemontèis
# Plattdüütsch : Plattdüütsch
# Polski : Polski
# Português : Português
# Qaraqalpaqsha : Qaraqalpaqsha
# Română : Română
# Runa : Runa
# Simi : Simi
# Русский : Русский
# Саха : Саха
# тыла : тыла
# ᱥᱟᱱᱛᱟᱲᱤ : ᱥᱟᱱᱛᱟᱲᱤ
# Scots : Scots
# Shqip : Shqip
# Sicilianu : Sicilianu
# සිංහල : සිංහල
# Simple : Simple
# English : English
# سنڌي : سنڌي
# Slovenčina : Slovenčina
# Slovenščina : Slovenščina
# Soomaaliga : Soomaaliga
# کوردی : کوردی
# Српски : Српски
# / : /
# srpski : srpski
# Srpskohrvatski : Srpskohrvatski
# / : /
# српскохрватски : српскохрватски
# Basa : Basa
# Sunda : Sunda
# Suomi : Suomi
# Svenska : Svenska
# Tagalog : Tagalog
# தமிழ் : தமிழ்
# Татарча/tatarça : Татарча/tatarça
# తెలుగు : తెలుగు
# Tetun : Tetun
# ไทย : ไทย
# Тоҷикӣ : Тоҷикӣ
# ತುಳು : ತುಳು
# Türkçe : Türkçe
# Türkmençe : Türkmençe
# Thuɔŋjäŋ : Thuɔŋjäŋ
# Українська : Українська
# اردو : اردو
# ئۇيغۇرچە : ئۇيغۇرچە
# / : /
# Uyghurche : Uyghurche
# Vèneto : Vèneto
# Tiếng : Tiếng
# Việt : Việt
# Walon : Walon
# 文言 : 文言
# West-Vlams : West-Vlams
# Winaray : Winaray
# 吴语 : 吴语
# ייִדיש : ייִדיש
# Yorùbá : Yorùbá
# 粵語 : 粵語
# Zazaki : Zazaki
# Zeêuws : Zeêuws
# Žemaitėška : Žemaitėška
# 中文 : 中文
# Edit : Edit
# links : link
# Edit : Edit
# links : link
# This : This
# page : page
# was : wa
# last : last
# edited : edited
# on : on
# 16 : 16
# June : June
# 2019 : 2019
# , : ,
# at : at
# 18:31 : 18:31
# ( : (
# UTC : UTC
# ) : )
# . : .
# Text : Text
# is : is
# available : available
# under : under
# the : the
# Creative : Creative
# Commons : Commons
# Attribution-ShareAlike : Attribution-ShareAlike
# License : License
# ; : ;
# additional : additional
# terms : term
# may : may
# apply : apply
# . : .
# By : By
# using : using
# this : this
# site : site
# , : ,
# you : you
# agree : agree
# to : to
# the : the
# Terms : Terms
# of : of
# Use : Use
# and : and
# Privacy : Privacy
# Policy : Policy
# . : .
# Wikipedia® : Wikipedia®
# is : is
# a : a
# registered : registered
# trademark : trademark
# of : of
# the : the
# Wikimedia : Wikimedia
# Foundation : Foundation
# , : ,
# Inc. : Inc.
# , : ,
# a : a
# non-profit : non-profit
# organization : organization
# . : .
# ( : (
# UTC : UTC
# ) : )
# Creative : Creative
# Commons : Commons
# Attribution-ShareAlike : Attribution-ShareAlike
# License : License
# Terms : Terms
# of : of
# Use : Use
# Privacy : Privacy
# Policy : Policy
# Wikimedia : Wikimedia
# Foundation : Foundation
# , : ,
# Inc. : Inc.
# Privacy : Privacy
# policy : policy
# About : About
# Wikipedia : Wikipedia
# Disclaimers : Disclaimers
# Contact : Contact
# Wikipedia : Wikipedia
# Developers : Developers
# Cookie : Cookie
# statement : statement
# Mobile : Mobile
# view : view
# Privacy : Privacy
# policy : policy
# About : About
# Wikipedia : Wikipedia
# Disclaimers : Disclaimers
# Contact : Contact
# Wikipedia : Wikipedia
# Developers : Developers
# Cookie : Cookie
# statement : statement
# Mobile : Mobile
# view : view

# %%
from nltk import ngrams
trigram=ngrams(data.split(),3)
for gram in trigram:
    print(gram)
# Out:
# ('Google', 'Jump', 'to')
# ('Jump', 'to', 'navigation')
# ('to', 'navigation', 'Jump')
# ('navigation', 'Jump', 'to')
# ('Jump', 'to', 'search')
# ('to', 'search', 'Google')
# ('search', 'Google', 'Search')
# ('Google', 'Search', 'Google')
# ('Search', 'Google', '(disambiguation)')
# ('Google', '(disambiguation)', 'Googol')
# ('(disambiguation)', 'Googol', '[update]')
# ('Googol', '[update]', 'Googleplex')
# ('[update]', 'Googleplex', 'Type')
# ('Googleplex', 'Type', 'Subsidiary')
# ('Type', 'Subsidiary', 'InternetCloud')
# ('Subsidiary', 'InternetCloud', 'computingComputer')
# ('InternetCloud', 'computingComputer', 'softwareComputer')
# ('computingComputer', 'softwareComputer', 'hardwareArtificial')
# ('softwareComputer', 'hardwareArtificial', 'intelligenceAdvertising')
# ('hardwareArtificial', 'intelligenceAdvertising', 'Internet')
# ('intelligenceAdvertising', 'Internet', 'Cloud')
# ('Internet', 'Cloud', 'computing')
# ('Cloud', 'computing', 'Computer')
# ('computing', 'Computer', 'software')
# ('Computer', 'software', 'Computer')
# ('software', 'Computer', 'hardware')
# ('Computer', 'hardware', 'Artificial')
# ('hardware', 'Artificial', 'intelligence')
# ('Artificial', 'intelligence', 'Advertising')
# ('intelligence', 'Advertising', ';')
# ('Advertising', ';', '20')
# (';', '20', 'years')
# ('20', 'years', 'ago')
# ('years', 'ago', '(1998-09-04)')
# ('ago', '(1998-09-04)', '1998-09-04')
# ('(1998-09-04)', '1998-09-04', 'Menlo')
# ('1998-09-04', 'Menlo', 'Park')
# ('Menlo', 'Park', 'Larry')
# ('Park', 'Larry', 'PageSergey')
# ('Larry', 'PageSergey', 'Brin')
# ('PageSergey', 'Brin', 'Larry')
# ('Brin', 'Larry', 'Page')
# ('Larry', 'Page', 'Sergey')
# ('Page', 'Sergey', 'Brin')
# ('Sergey', 'Brin', 'Mountain')
# ('Brin', 'Mountain', 'View,')
# ('Mountain', 'View,', 'California')
# ('View,', 'California', 'Sundar')
# ('California', 'Sundar', 'Pichai')
# ('Sundar', 'Pichai', '(CEO)Ruth')
# ('Pichai', '(CEO)Ruth', 'Porat')
# ('(CEO)Ruth', 'Porat', '(CFO)')
# ('Porat', '(CFO)', 'Sundar')
# ('(CFO)', 'Sundar', 'Pichai')
# ('Sundar', 'Pichai', 'CEO')
# ('Pichai', 'CEO', 'Ruth')
# ('CEO', 'Ruth', 'Porat')
# ('Ruth', 'Porat', 'CFO')
# ('Porat', 'CFO', 'List')
# ('CFO', 'List', 'of')
# ('List', 'of', 'Google')
# ('of', 'Google', 'products')
# ('Google', 'products', '[update]')
# ('products', '[update]', 'Parent')
# ('[update]', 'Parent', 'Alphabet')
# ('Parent', 'Alphabet', 'Inc.')
# ('Alphabet', 'Inc.', 'Subsidiaries')
# ('Inc.', 'Subsidiaries', 'List')
# ('Subsidiaries', 'List', 'of')
# ('List', 'of', 'subsidiaries')
# ('of', 'subsidiaries', 'google.com')
# ('subsidiaries', 'google.com', 'google.com')
# ('google.com', 'google.com', '[1]')
# ('google.com', '[1]', '[2]')
# ('[1]', '[2]', '[3]')
# ('[2]', '[3]', '[4]')
# ('[3]', '[4]', 'Google')
# ('[4]', 'Google', 'LLC[5]')
# ('Google', 'LLC[5]', 'is')
# ('LLC[5]', 'is', 'an')
# ('is', 'an', 'American')
# ('an', 'American', 'multinational')
# ('American', 'multinational', 'technology')
# ('multinational', 'technology', 'company')
# ('technology', 'company', 'that')
# ('company', 'that', 'specializes')
# ('that', 'specializes', 'in')
# ('specializes', 'in', 'Internet-related')
# ('in', 'Internet-related', 'services')
# ('Internet-related', 'services', 'and')
# ('services', 'and', 'products,')
# ('and', 'products,', 'which')
# ('products,', 'which', 'include')
# ('which', 'include', 'online')
# ('include', 'online', 'advertising')
# ('online', 'advertising', 'technologies,')
# ('advertising', 'technologies,', 'search')
# ('technologies,', 'search', 'engine,')
# ('search', 'engine,', 'cloud')
# ('engine,', 'cloud', 'computing,')
# ('cloud', 'computing,', 'software,')
# ('computing,', 'software,', 'and')
# ('software,', 'and', 'hardware.')
# ('and', 'hardware.', 'It')
# ('hardware.', 'It', 'is')
# ('It', 'is', 'considered')
# ('is', 'considered', 'one')
# ('considered', 'one', 'of')
# ('one', 'of', 'the')
# ('of', 'the', 'Big')
# ('the', 'Big', 'Four')
# ('Big', 'Four', 'technology')
# ('Four', 'technology', 'companies,')
# ('technology', 'companies,', 'alongside')
# ('companies,', 'alongside', 'Amazon,')
# ('alongside', 'Amazon,', 'Apple')
# ('Amazon,', 'Apple', 'and')
# ('Apple', 'and', 'Facebook.[6][7]')
# ('and', 'Facebook.[6][7]', '[5]')
# ('Facebook.[6][7]', '[5]', 'online')
# ('[5]', 'online', 'advertising')
# ('online', 'advertising', 'technologies')
# ('advertising', 'technologies', 'search')
# ('technologies', 'search', 'engine')
# ('search', 'engine', 'cloud')
# ('engine', 'cloud', 'computing')
# ('cloud', 'computing', 'Big')
# ('computing', 'Big', 'Four')
# ('Big', 'Four', 'Amazon')
# ('Four', 'Amazon', 'Apple')
# ('Amazon', 'Apple', 'Facebook')
# ('Apple', 'Facebook', '[6]')
# ('Facebook', '[6]', '[7]')
# ('[6]', '[7]', 'Google')
# ('[7]', 'Google', 'was')
# ('Google', 'was', 'founded')
# ('was', 'founded', 'in')
# ('founded', 'in', '1998')
# ('in', '1998', 'by')
# ('1998', 'by', 'Larry')
# ('by', 'Larry', 'Page')
# ('Larry', 'Page', 'and')
# ('Page', 'and', 'Sergey')
# ('and', 'Sergey', 'Brin')
# ('Sergey', 'Brin', 'while')
# ('Brin', 'while', 'they')
# ('while', 'they', 'were')
# ('they', 'were', 'Ph.D.')
# ('were', 'Ph.D.', 'students')
# ('Ph.D.', 'students', 'at')
# ('students', 'at', 'Stanford')
# ('at', 'Stanford', 'University')
# ('Stanford', 'University', 'in')
# ('University', 'in', 'California.')
# ('in', 'California.', 'Together')
# ('California.', 'Together', 'they')
# ('Together', 'they', 'own')
# ('they', 'own', 'about')
# ('own', 'about', '14')
# ('about', '14', 'percent')
# ('14', 'percent', 'of')
# ('percent', 'of', 'its')
# ('of', 'its', 'shares')
# ('its', 'shares', 'and')
# ('shares', 'and', 'control')
# ('and', 'control', '56')
# ('control', '56', 'percent')
# ('56', 'percent', 'of')
# ('percent', 'of', 'the')
# ('of', 'the', 'stockholder')
# ('the', 'stockholder', 'voting')
# ('stockholder', 'voting', 'power')
# ('voting', 'power', 'through')
# ('power', 'through', 'supervoting')
# ('through', 'supervoting', 'stock.')
# ('supervoting', 'stock.', 'They')
# ('stock.', 'They', 'incorporated')
# ('They', 'incorporated', 'Google')
# ('incorporated', 'Google', 'as')
# ('Google', 'as', 'a')
# ('as', 'a', 'privately')
# ('a', 'privately', 'held')
# ('privately', 'held', 'company')
# ('held', 'company', 'on')
# ('company', 'on', 'September')
# ('on', 'September', '4,')
# ('September', '4,', '1998.')
# ('4,', '1998.', 'An')
# ('1998.', 'An', 'initial')
# ('An', 'initial', 'public')
# ('initial', 'public', 'offering')
# ('public', 'offering', '(IPO)')
# ('offering', '(IPO)', 'took')
# ('(IPO)', 'took', 'place')
# ('took', 'place', 'on')
# ('place', 'on', 'August')
# ('on', 'August', '19,')
# ('August', '19,', '2004,')
# ('19,', '2004,', 'and')
# ('2004,', 'and', 'Google')
# ('and', 'Google', 'moved')
# ('Google', 'moved', 'to')
# ('moved', 'to', 'its')
# ('to', 'its', 'headquarters')
# ('its', 'headquarters', 'in')
# ('headquarters', 'in', 'Mountain')
# ('in', 'Mountain', 'View,')
# ('Mountain', 'View,', 'California,')
# ('View,', 'California,', 'nicknamed')
# ('California,', 'nicknamed', 'the')
# ('nicknamed', 'the', 'Googleplex.')
# ('the', 'Googleplex.', 'In')
# ('Googleplex.', 'In', 'August')
# ('In', 'August', '2015,')
# ('August', '2015,', 'Google')
# ('2015,', 'Google', 'announced')
# ('Google', 'announced', 'plans')
# ('announced', 'plans', 'to')
# ('plans', 'to', 'reorganize')
# ('to', 'reorganize', 'its')
# ('reorganize', 'its', 'various')
# ('its', 'various', 'interests')
# ('various', 'interests', 'as')
# ('interests', 'as', 'a')
# ('as', 'a', 'conglomerate')
# ('a', 'conglomerate', 'called')
# ('conglomerate', 'called', 'Alphabet')
# ('called', 'Alphabet', 'Inc.')
# ('Alphabet', 'Inc.', 'Google')
# ('Inc.', 'Google', 'is')
# ('Google', 'is', "Alphabet's")
# ('is', "Alphabet's", 'leading')
# ("Alphabet's", 'leading', 'subsidiary')
# ('leading', 'subsidiary', 'and')
# ('subsidiary', 'and', 'will')
# ('and', 'will', 'continue')
# ('will', 'continue', 'to')
# ('continue', 'to', 'be')
# ('to', 'be', 'the')
# ('be', 'the', 'umbrella')
# ('the', 'umbrella', 'company')
# ('umbrella', 'company', 'for')
# ('company', 'for', "Alphabet's")
# ('for', "Alphabet's", 'Internet')
# ("Alphabet's", 'Internet', 'interests.')
# ('Internet', 'interests.', 'Sundar')
# ('interests.', 'Sundar', 'Pichai')
# ('Sundar', 'Pichai', 'was')
# ('Pichai', 'was', 'appointed')
# ('was', 'appointed', 'CEO')
# ('appointed', 'CEO', 'of')
# ('CEO', 'of', 'Google,')
# ('of', 'Google,', 'replacing')
# ('Google,', 'replacing', 'Larry')
# ('replacing', 'Larry', 'Page')
# ('Larry', 'Page', 'who')
# ('Page', 'who', 'became')
# ('who', 'became', 'the')
# ('became', 'the', 'CEO')
# ('the', 'CEO', 'of')
# ('CEO', 'of', 'Alphabet.')
# ('of', 'Alphabet.', 'Larry')
# ('Alphabet.', 'Larry', 'Page')
# ('Larry', 'Page', 'Sergey')
# ('Page', 'Sergey', 'Brin')
# ('Sergey', 'Brin', 'Stanford')
# ('Brin', 'Stanford', 'University')
# ('Stanford', 'University', 'California')
# ('University', 'California', 'supervoting')
# ('California', 'supervoting', 'Googleplex')
# ('supervoting', 'Googleplex', 'Alphabet')
# ('Googleplex', 'Alphabet', 'Inc.')
# ('Alphabet', 'Inc.', 'Sundar')
# ('Inc.', 'Sundar', 'Pichai')
# ('Sundar', 'Pichai', 'The')
# ('Pichai', 'The', "company's")
# ('The', "company's", 'rapid')
# ("company's", 'rapid', 'growth')
# ('rapid', 'growth', 'since')
# ('growth', 'since', 'incorporation')
# ('since', 'incorporation', 'has')
# ('incorporation', 'has', 'triggered')
# ('has', 'triggered', 'a')
# ('triggered', 'a', 'chain')
# ('a', 'chain', 'of')
# ('chain', 'of', 'products,')
# ('of', 'products,', 'acquisitions,')
# ('products,', 'acquisitions,', 'and')
# ('acquisitions,', 'and', 'partnerships')
# ('and', 'partnerships', 'beyond')
# ('partnerships', 'beyond', "Google's")
# ('beyond', "Google's", 'core')
# ("Google's", 'core', 'search')
# ('core', 'search', 'engine')
# ('search', 'engine', '(Google')
# ('engine', '(Google', 'Search).')
# ('(Google', 'Search).', 'It')
# ('Search).', 'It', 'offers')
# ('It', 'offers', 'services')
# ('offers', 'services', 'designed')
# ('services', 'designed', 'for')
# ('designed', 'for', 'work')
# ('for', 'work', 'and')
# ('work', 'and', 'productivity')
# ('and', 'productivity', '(Google')
# ('productivity', '(Google', 'Docs,')
# ('(Google', 'Docs,', 'Google')
# ('Docs,', 'Google', 'Sheets,')
# ('Google', 'Sheets,', 'and')
# ('Sheets,', 'and', 'Google')
# ('and', 'Google', 'Slides),')
# ('Google', 'Slides),', 'email')
# ('Slides),', 'email', '(Gmail/Inbox),')
# ('email', '(Gmail/Inbox),', 'scheduling')
# ('(Gmail/Inbox),', 'scheduling', 'and')
# ('scheduling', 'and', 'time')
# ('and', 'time', 'management')
# ('time', 'management', '(Google')
# ('management', '(Google', 'Calendar),')
# ('(Google', 'Calendar),', 'cloud')
# ('Calendar),', 'cloud', 'storage')
# ('cloud', 'storage', '(Google')
# ('storage', '(Google', 'Drive),')
# ('(Google', 'Drive),', 'instant')
# ('Drive),', 'instant', 'messaging')
# ('instant', 'messaging', 'and')
# ('messaging', 'and', 'video')
# ('and', 'video', 'chat')
# ('video', 'chat', '(Google')
# ('chat', '(Google', 'Allo,')
# ('(Google', 'Allo,', 'Duo,')
# ('Allo,', 'Duo,', 'Hangouts),')
# ('Duo,', 'Hangouts),', 'language')
# ('Hangouts),', 'language', 'translation')
# ('language', 'translation', '(Google')
# ('translation', '(Google', 'Translate),')
# ('(Google', 'Translate),', 'mapping')
# ('Translate),', 'mapping', 'and')
# ('mapping', 'and', 'navigation')
# ('and', 'navigation', '(Google')
# ('navigation', '(Google', 'Maps,')
# ('(Google', 'Maps,', 'Waze,')
# ('Maps,', 'Waze,', 'Google')
# ('Waze,', 'Google', 'Earth,')
# ('Google', 'Earth,', 'Street')
# ('Earth,', 'Street', 'View),')
# ('Street', 'View),', 'video')
# ('View),', 'video', 'sharing')
# ('video', 'sharing', '(YouTube),')
# ('sharing', '(YouTube),', 'note-taking')
# ('(YouTube),', 'note-taking', '(Google')
# ('note-taking', '(Google', 'Keep),')
# ('(Google', 'Keep),', 'and')
# ('Keep),', 'and', 'photo')
# ('and', 'photo', 'organizing')
# ('photo', 'organizing', 'and')
# ('organizing', 'and', 'editing')
# ('and', 'editing', '(Google')
# ('editing', '(Google', 'Photos).')
# ('(Google', 'Photos).', 'The')
# ('Photos).', 'The', 'company')
# ('The', 'company', 'leads')
# ('company', 'leads', 'the')
# ('leads', 'the', 'development')
# ('the', 'development', 'of')
# ('development', 'of', 'the')
# ('of', 'the', 'Android')
# ('the', 'Android', 'mobile')
# ('Android', 'mobile', 'operating')
# ('mobile', 'operating', 'system,')
# ('operating', 'system,', 'the')
# ('system,', 'the', 'Google')
# ('the', 'Google', 'Chrome')
# ('Google', 'Chrome', 'web')
# ('Chrome', 'web', 'browser,')
# ('web', 'browser,', 'and')
# ('browser,', 'and', 'Chrome')
# ('and', 'Chrome', 'OS,')
# ('Chrome', 'OS,', 'a')
# ('OS,', 'a', 'lightweight')
# ('a', 'lightweight', 'operating')
# ('lightweight', 'operating', 'system')
# ('operating', 'system', 'based')
# ('system', 'based', 'on')
# ('based', 'on', 'the')
# ('on', 'the', 'Chrome')
# ('the', 'Chrome', 'browser.')
# ('Chrome', 'browser.', 'Google')
# ('browser.', 'Google', 'has')
# ('Google', 'has', 'moved')
# ('has', 'moved', 'increasingly')
# ('moved', 'increasingly', 'into')
# ('increasingly', 'into', 'hardware;')
# ('into', 'hardware;', 'from')
# ('hardware;', 'from', '2010')
# ('from', '2010', 'to')
# ('2010', 'to', '2015,')
# ('to', '2015,', 'it')
# ('2015,', 'it', 'partnered')
# ('it', 'partnered', 'with')
# ('partnered', 'with', 'major')
# ('with', 'major', 'electronics')
# ('major', 'electronics', 'manufacturers')
# ('electronics', 'manufacturers', 'in')
# ('manufacturers', 'in', 'the')
# ('in', 'the', 'production')
# ('the', 'production', 'of')
# ('production', 'of', 'its')
# ('of', 'its', 'Nexus')
# ('its', 'Nexus', 'devices,')
# ('Nexus', 'devices,', 'and')
# ('devices,', 'and', 'it')
# ('and', 'it', 'released')
# ('it', 'released', 'multiple')
# ('released', 'multiple', 'hardware')
# ('multiple', 'hardware', 'products')
# ('hardware', 'products', 'in')
# ('products', 'in', 'October')
# ('in', 'October', '2016,')
# ('October', '2016,', 'including')
# ('2016,', 'including', 'the')
# ('including', 'the', 'Google')
# ('the', 'Google', 'Pixel')
# ('Google', 'Pixel', 'smartphone,')
# ('Pixel', 'smartphone,', 'Google')
# ('smartphone,', 'Google', 'Home')
# ('Google', 'Home', 'smart')
# ('Home', 'smart', 'speaker,')
# ('smart', 'speaker,', 'Google')
# ('speaker,', 'Google', 'Wifi')
# ('Google', 'Wifi', 'mesh')
# ('Wifi', 'mesh', 'wireless')
# ('mesh', 'wireless', 'router,')
# ('wireless', 'router,', 'and')
# ('router,', 'and', 'Google')
# ('and', 'Google', 'Daydream')
# ('Google', 'Daydream', 'virtual')
# ('Daydream', 'virtual', 'reality')
# ('virtual', 'reality', 'headset.')
# ('reality', 'headset.', 'Google')
# ('headset.', 'Google', 'has')
# ('Google', 'has', 'also')
# ('has', 'also', 'experimented')
# ('also', 'experimented', 'with')
# ('experimented', 'with', 'becoming')
# ('with', 'becoming', 'an')
# ('becoming', 'an', 'Internet')
# ('an', 'Internet', 'carrier')
# ('Internet', 'carrier', '(Google')
# ('carrier', '(Google', 'Fiber,')
# ('(Google', 'Fiber,', 'Google')
# ('Fiber,', 'Google', 'Fi,')
# ('Google', 'Fi,', 'and')
# ('Fi,', 'and', 'Google')
# ('and', 'Google', 'Station).[8]')
# ('Google', 'Station).[8]', 'Google')
# ('Station).[8]', 'Google', 'Search')
# ('Google', 'Search', 'Google')
# ('Search', 'Google', 'Docs')
# ('Google', 'Docs', 'Google')
# ('Docs', 'Google', 'Sheets')
# ('Google', 'Sheets', 'Google')
# ('Sheets', 'Google', 'Slides')
# ('Google', 'Slides', 'Gmail')
# ('Slides', 'Gmail', 'Inbox')
# ('Gmail', 'Inbox', 'Google')
# ('Inbox', 'Google', 'Calendar')
# ('Google', 'Calendar', 'Google')
# ('Calendar', 'Google', 'Drive')
# ('Google', 'Drive', 'Google')
# ('Drive', 'Google', 'Allo')
# ('Google', 'Allo', 'Duo')
# ('Allo', 'Duo', 'Hangouts')
# ('Duo', 'Hangouts', 'Google')
# ('Hangouts', 'Google', 'Translate')
# ('Google', 'Translate', 'Google')
# ('Translate', 'Google', 'Maps')
# ('Google', 'Maps', 'Waze')
# ('Maps', 'Waze', 'Google')
# ('Waze', 'Google', 'Earth')
# ('Google', 'Earth', 'Street')
# ('Earth', 'Street', 'View')
# ('Street', 'View', 'YouTube')
# ('View', 'YouTube', 'Google')
# ('YouTube', 'Google', 'Keep')
# ('Google', 'Keep', 'Google')
# ('Keep', 'Google', 'Photos')
# ('Google', 'Photos', 'Android')
# ('Photos', 'Android', 'Google')
# ('Android', 'Google', 'Chrome')
# ('Google', 'Chrome', 'Chrome')
# ('Chrome', 'Chrome', 'OS')
# ('Chrome', 'OS', 'Nexus')
# ('OS', 'Nexus', 'Google')
# ('Nexus', 'Google', 'Pixel')
# ('Google', 'Pixel', 'Google')
# ('Pixel', 'Google', 'Home')
# ('Google', 'Home', 'Google')
# ('Home', 'Google', 'Wifi')
# ('Google', 'Wifi', 'Google')
# ('Wifi', 'Google', 'Daydream')
# ('Google', 'Daydream', 'Google')
# ('Daydream', 'Google', 'Fiber')
# ('Google', 'Fiber', 'Google')
# ('Fiber', 'Google', 'Fi')
# ('Google', 'Fi', 'Google')
# ('Fi', 'Google', 'Station')
# ('Google', 'Station', '[8]')
# ('Station', '[8]', 'Google.com')
# ('[8]', 'Google.com', 'is')
# ('Google.com', 'is', 'the')
# ('is', 'the', 'most')
# ('the', 'most', 'visited')
# ('most', 'visited', 'website')
# ('visited', 'website', 'in')
# ('website', 'in', 'the')
# ('in', 'the', 'world.[9]')
# ('the', 'world.[9]', 'Several')
# ('world.[9]', 'Several', 'other')
# ('Several', 'other', 'Google')
# ('other', 'Google', 'services')
# ('Google', 'services', 'also')
# ('services', 'also', 'figure')
# ('also', 'figure', 'in')
# ('figure', 'in', 'the')
# ('in', 'the', 'top')
# ('the', 'top', '100')
# ('top', '100', 'most')
# ('100', 'most', 'visited')
# ('most', 'visited', 'websites,')
# ('visited', 'websites,', 'including')
# ('websites,', 'including', 'YouTube')
# ('including', 'YouTube', 'and')
# ('YouTube', 'and', 'Blogger.')
# ('and', 'Blogger.', 'Google')
# ('Blogger.', 'Google', 'was')
# ('Google', 'was', 'the')
# ('was', 'the', 'most')
# ('the', 'most', 'valuable')
# ('most', 'valuable', 'brand')
# ('valuable', 'brand', 'in')
# ('brand', 'in', 'the')
# ('in', 'the', 'world')
# ('the', 'world', 'as')
# ('world', 'as', 'of')
# ('as', 'of', '2017,[update][10]')
# ('of', '2017,[update][10]', 'but')
# ('2017,[update][10]', 'but', 'has')
# ('but', 'has', 'received')
# ('has', 'received', 'significant')
# ('received', 'significant', 'criticism')
# ('significant', 'criticism', 'involving')
# ('criticism', 'involving', 'issues')
# ('involving', 'issues', 'such')
# ('issues', 'such', 'as')
# ('such', 'as', 'privacy')
# ('as', 'privacy', 'concerns,')
# ('privacy', 'concerns,', 'tax')
# ('concerns,', 'tax', 'avoidance,')
# ('tax', 'avoidance,', 'antitrust,')
# ('avoidance,', 'antitrust,', 'censorship,')
# ('antitrust,', 'censorship,', 'and')
# ('censorship,', 'and', 'search')
# ('and', 'search', 'neutrality.')
# ('search', 'neutrality.', "Google's")
# ('neutrality.', "Google's", 'mission')
# ("Google's", 'mission', 'statement')
# ('mission', 'statement', 'is')
# ('statement', 'is', '"to')
# ('is', '"to', 'organize')
# ('"to', 'organize', 'the')
# ('organize', 'the', "world's")
# ('the', "world's", 'information')
# ("world's", 'information', 'and')
# ('information', 'and', 'make')
# ('and', 'make', 'it')
# ('make', 'it', 'universally')
# ('it', 'universally', 'accessible')
# ('universally', 'accessible', 'and')
# ('accessible', 'and', 'useful".')
# ('and', 'useful".', 'The')
# ('useful".', 'The', "company's")
# ('The', "company's", 'unofficial')
# ("company's", 'unofficial', 'slogan')
# ('unofficial', 'slogan', '"Don\'t')
# ('slogan', '"Don\'t', 'be')
# ('"Don\'t', 'be', 'evil"')
# ('be', 'evil"', 'was')
# ('evil"', 'was', 'removed')
# ('was', 'removed', 'from')
# ('removed', 'from', 'the')
# ('from', 'the', "company's")
# ('the', "company's", 'code')
# ("company's", 'code', 'of')
# ('code', 'of', 'conduct')
# ('of', 'conduct', 'around')
# ('conduct', 'around', 'May')
# ('around', 'May', '2018,')
# ('May', '2018,', 'but')
# ('2018,', 'but', 'reinstated')
# ('but', 'reinstated', 'by')
# ('reinstated', 'by', 'July')
# ('by', 'July', '31,')
# ('July', '31,', '2018.[11][12]')
# ('31,', '2018.[11][12]', '[9]')
# ('2018.[11][12]', '[9]', 'YouTube')
# ('[9]', 'YouTube', 'Blogger')
# ('YouTube', 'Blogger', '[update]')
# ('Blogger', '[update]', '[10]')
# ('[update]', '[10]', 'criticism')
# ('[10]', 'criticism', 'privacy')
# ('criticism', 'privacy', 'concerns')
# ('privacy', 'concerns', 'censorship')
# ('concerns', 'censorship', 'mission')
# ('censorship', 'mission', 'statement')
# ('mission', 'statement', '[11]')
# ('statement', '[11]', '[12]')
# ('[11]', '[12]', 'Contents')
# ('[12]', 'Contents', '1')
# ('Contents', '1', 'History')
# ('1', 'History', '1.1')
# ('History', '1.1', 'Early')
# ('1.1', 'Early', 'years')
# ('Early', 'years', '1.2')
# ('years', '1.2', 'Growth')
# ('1.2', 'Growth', '1.3')
# ('Growth', '1.3', 'Initial')
# ('1.3', 'Initial', 'public')
# ('Initial', 'public', 'offering')
# ('public', 'offering', '1.4')
# ('offering', '1.4', '2012')
# ('1.4', '2012', 'onward')
# ('2012', 'onward', '2')
# ('onward', '2', 'Products')
# ('2', 'Products', 'and')
# ('Products', 'and', 'services')
# ('and', 'services', '2.1')
# ('services', '2.1', 'Search')
# ('2.1', 'Search', 'engine')
# ('Search', 'engine', '2.2')
# ('engine', '2.2', 'Advertising')
# ('2.2', 'Advertising', '2.3')
# ('Advertising', '2.3', 'Consumer')
# ('2.3', 'Consumer', 'services')
# ('Consumer', 'services', '2.3.1')
# ('services', '2.3.1', 'Web-based')
# ('2.3.1', 'Web-based', 'services')
# ('Web-based', 'services', '2.3.2')
# ('services', '2.3.2', 'Software')
# ('2.3.2', 'Software', '2.3.3')
# ('Software', '2.3.3', 'Hardware')
# ('2.3.3', 'Hardware', '2.4')
# ('Hardware', '2.4', 'Enterprise')
# ('2.4', 'Enterprise', 'services')
# ('Enterprise', 'services', '2.5')
# ('services', '2.5', 'Internet')
# ('2.5', 'Internet', 'services')
# ('Internet', 'services', '2.6')
# ('services', '2.6', 'Other')
# ('2.6', 'Other', 'products')
# ('Other', 'products', '3')
# ('products', '3', 'Corporate')
# ('3', 'Corporate', 'affairs')
# ('Corporate', 'affairs', '3.1')
# ('affairs', '3.1', 'Finance')
# ('3.1', 'Finance', '3.2')
# ('Finance', '3.2', 'Corporate')
# ('3.2', 'Corporate', 'identity')
# ('Corporate', 'identity', '3.3')
# ('identity', '3.3', 'Workplace')
# ('3.3', 'Workplace', 'culture')
# ('Workplace', 'culture', '3.4')
# ('culture', '3.4', 'Office')
# ('3.4', 'Office', 'locations')
# ('Office', 'locations', '3.5')
# ('locations', '3.5', 'Infrastructure')
# ('3.5', 'Infrastructure', '3.6')
# ('Infrastructure', '3.6', 'Environment')
# ('3.6', 'Environment', '3.7')
# ('Environment', '3.7', 'Philanthropy')
# ('3.7', 'Philanthropy', '4')
# ('Philanthropy', '4', 'Criticism')
# ('4', 'Criticism', 'and')
# ('Criticism', 'and', 'controversy')
# ('and', 'controversy', '4.1')
# ('controversy', '4.1', 'Litigation')
# ('4.1', 'Litigation', '5')
# ('Litigation', '5', 'See')
# ('5', 'See', 'also')
# ('See', 'also', '6')
# ('also', '6', 'References')
# ('6', 'References', '7')
# ('References', '7', 'Further')
# ('7', 'Further', 'reading')
# ('Further', 'reading', '8')
# ('reading', '8', 'External')
# ('8', 'External', 'links')
# ('External', 'links', '1')
# ('links', '1', 'History')
# ('1', 'History', '1')
# ('History', '1', 'History')
# ('1', 'History', '1.1')
# ('History', '1.1', 'Early')
# ('1.1', 'Early', 'years')
# ('Early', 'years', '1.2')
# ('years', '1.2', 'Growth')
# ('1.2', 'Growth', '1.3')
# ('Growth', '1.3', 'Initial')
# ('1.3', 'Initial', 'public')
# ('Initial', 'public', 'offering')
# ('public', 'offering', '1.4')
# ('offering', '1.4', '2012')
# ('1.4', '2012', 'onward')
# ('2012', 'onward', '1.1')
# ('onward', '1.1', 'Early')
# ('1.1', 'Early', 'years')
# ('Early', 'years', '1.1')
# ('years', '1.1', 'Early')
# ('1.1', 'Early', 'years')
# ('Early', 'years', '1.2')
# ('years', '1.2', 'Growth')
# ('1.2', 'Growth', '1.2')
# ('Growth', '1.2', 'Growth')
# ('1.2', 'Growth', '1.3')
# ('Growth', '1.3', 'Initial')
# ('1.3', 'Initial', 'public')
# ('Initial', 'public', 'offering')
# ('public', 'offering', '1.3')
# ('offering', '1.3', 'Initial')
# ('1.3', 'Initial', 'public')
# ('Initial', 'public', 'offering')
# ('public', 'offering', '1.4')
# ('offering', '1.4', '2012')
# ('1.4', '2012', 'onward')
# ('2012', 'onward', '1.4')
# ('onward', '1.4', '2012')
# ('1.4', '2012', 'onward')
# ('2012', 'onward', '2')
# ('onward', '2', 'Products')
# ('2', 'Products', 'and')
# ('Products', 'and', 'services')
# ('and', 'services', '2')
# ('services', '2', 'Products')
# ('2', 'Products', 'and')
# ('Products', 'and', 'services')
# ('and', 'services', '2.1')
# ('services', '2.1', 'Search')
# ('2.1', 'Search', 'engine')
# ('Search', 'engine', '2.2')
# ('engine', '2.2', 'Advertising')
# ('2.2', 'Advertising', '2.3')
# ('Advertising', '2.3', 'Consumer')
# ('2.3', 'Consumer', 'services')
# ('Consumer', 'services', '2.3.1')
# ('services', '2.3.1', 'Web-based')
# ('2.3.1', 'Web-based', 'services')
# ('Web-based', 'services', '2.3.2')
# ('services', '2.3.2', 'Software')
# ('2.3.2', 'Software', '2.3.3')
# ('Software', '2.3.3', 'Hardware')
# ('2.3.3', 'Hardware', '2.4')
# ('Hardware', '2.4', 'Enterprise')
# ('2.4', 'Enterprise', 'services')
# ('Enterprise', 'services', '2.5')
# ('services', '2.5', 'Internet')
# ('2.5', 'Internet', 'services')
# ('Internet', 'services', '2.6')
# ('services', '2.6', 'Other')
# ('2.6', 'Other', 'products')
# ('Other', 'products', '2.1')
# ('products', '2.1', 'Search')
# ('2.1', 'Search', 'engine')
# ('Search', 'engine', '2.1')
# ('engine', '2.1', 'Search')
# ('2.1', 'Search', 'engine')
# ('Search', 'engine', '2.2')
# ('engine', '2.2', 'Advertising')
# ('2.2', 'Advertising', '2.2')
# ('Advertising', '2.2', 'Advertising')
# ('2.2', 'Advertising', '2.3')
# ('Advertising', '2.3', 'Consumer')
# ('2.3', 'Consumer', 'services')
# ('Consumer', 'services', '2.3')
# ('services', '2.3', 'Consumer')
# ('2.3', 'Consumer', 'services')
# ('Consumer', 'services', '2.3.1')
# ('services', '2.3.1', 'Web-based')
# ('2.3.1', 'Web-based', 'services')
# ('Web-based', 'services', '2.3.2')
# ('services', '2.3.2', 'Software')
# ('2.3.2', 'Software', '2.3.3')
# ('Software', '2.3.3', 'Hardware')
# ('2.3.3', 'Hardware', '2.3.1')
# ('Hardware', '2.3.1', 'Web-based')
# ('2.3.1', 'Web-based', 'services')
# ('Web-based', 'services', '2.3.1')
# ('services', '2.3.1', 'Web-based')
# ('2.3.1', 'Web-based', 'services')
# ('Web-based', 'services', '2.3.2')
# ('services', '2.3.2', 'Software')
# ('2.3.2', 'Software', '2.3.2')
# ('Software', '2.3.2', 'Software')
# ('2.3.2', 'Software', '2.3.3')
# ('Software', '2.3.3', 'Hardware')
# ('2.3.3', 'Hardware', '2.3.3')
# ('Hardware', '2.3.3', 'Hardware')
# ('2.3.3', 'Hardware', '2.4')
# ('Hardware', '2.4', 'Enterprise')
# ('2.4', 'Enterprise', 'services')
# ('Enterprise', 'services', '2.4')
# ('services', '2.4', 'Enterprise')
# ('2.4', 'Enterprise', 'services')
# ('Enterprise', 'services', '2.5')
# ('services', '2.5', 'Internet')
# ('2.5', 'Internet', 'services')
# ('Internet', 'services', '2.5')
# ('services', '2.5', 'Internet')
# ('2.5', 'Internet', 'services')
# ('Internet', 'services', '2.6')
# ('services', '2.6', 'Other')
# ('2.6', 'Other', 'products')
# ('Other', 'products', '2.6')
# ('products', '2.6', 'Other')
# ('2.6', 'Other', 'products')
# ('Other', 'products', '3')
# ('products', '3', 'Corporate')
# ('3', 'Corporate', 'affairs')
# ('Corporate', 'affairs', '3')
# ('affairs', '3', 'Corporate')
# ('3', 'Corporate', 'affairs')
# ('Corporate', 'affairs', '3.1')
# ('affairs', '3.1', 'Finance')
# ('3.1', 'Finance', '3.2')
# ('Finance', '3.2', 'Corporate')
# ('3.2', 'Corporate', 'identity')
# ('Corporate', 'identity', '3.3')
# ('identity', '3.3', 'Workplace')
# ('3.3', 'Workplace', 'culture')
# ('Workplace', 'culture', '3.4')
# ('culture', '3.4', 'Office')
# ('3.4', 'Office', 'locations')
# ('Office', 'locations', '3.5')
# ('locations', '3.5', 'Infrastructure')
# ('3.5', 'Infrastructure', '3.6')
# ('Infrastructure', '3.6', 'Environment')
# ('3.6', 'Environment', '3.7')
# ('Environment', '3.7', 'Philanthropy')
# ('3.7', 'Philanthropy', '3.1')
# ('Philanthropy', '3.1', 'Finance')
# ('3.1', 'Finance', '3.1')
# ('Finance', '3.1', 'Finance')
# ('3.1', 'Finance', '3.2')
# ('Finance', '3.2', 'Corporate')
# ('3.2', 'Corporate', 'identity')
# ('Corporate', 'identity', '3.2')
# ('identity', '3.2', 'Corporate')
# ('3.2', 'Corporate', 'identity')
# ('Corporate', 'identity', '3.3')
# ('identity', '3.3', 'Workplace')
# ('3.3', 'Workplace', 'culture')
# ('Workplace', 'culture', '3.3')
# ('culture', '3.3', 'Workplace')
# ('3.3', 'Workplace', 'culture')
# ('Workplace', 'culture', '3.4')
# ('culture', '3.4', 'Office')
# ('3.4', 'Office', 'locations')
# ('Office', 'locations', '3.4')
# ('locations', '3.4', 'Office')
# ('3.4', 'Office', 'locations')
# ('Office', 'locations', '3.5')
# ('locations', '3.5', 'Infrastructure')
# ('3.5', 'Infrastructure', '3.5')
# ('Infrastructure', '3.5', 'Infrastructure')
# ('3.5', 'Infrastructure', '3.6')
# ('Infrastructure', '3.6', 'Environment')
# ('3.6', 'Environment', '3.6')
# ('Environment', '3.6', 'Environment')
# ('3.6', 'Environment', '3.7')
# ('Environment', '3.7', 'Philanthropy')
# ('3.7', 'Philanthropy', '3.7')
# ('Philanthropy', '3.7', 'Philanthropy')
# ('3.7', 'Philanthropy', '4')
# ('Philanthropy', '4', 'Criticism')
# ('4', 'Criticism', 'and')
# ('Criticism', 'and', 'controversy')
# ('and', 'controversy', '4')
# ('controversy', '4', 'Criticism')
# ('4', 'Criticism', 'and')
# ('Criticism', 'and', 'controversy')
# ('and', 'controversy', '4.1')
# ('controversy', '4.1', 'Litigation')
# ('4.1', 'Litigation', '4.1')
# ('Litigation', '4.1', 'Litigation')
# ('4.1', 'Litigation', '4.1')
# ('Litigation', '4.1', 'Litigation')
# ('4.1', 'Litigation', '5')
# ('Litigation', '5', 'See')
# ('5', 'See', 'also')
# ('See', 'also', '5')
# ('also', '5', 'See')
# ('5', 'See', 'also')
# ('See', 'also', '6')
# ('also', '6', 'References')
# ('6', 'References', '6')
# ('References', '6', 'References')
# ('6', 'References', '7')
# ('References', '7', 'Further')
# ('7', 'Further', 'reading')
# ('Further', 'reading', '7')
# ('reading', '7', 'Further')
# ('7', 'Further', 'reading')
# ('Further', 'reading', '8')
# ('reading', '8', 'External')
# ('8', 'External', 'links')
# ('External', 'links', '8')
# ('links', '8', 'External')
# ('8', 'External', 'links')
# ('External', 'links', 'History')
# ('links', 'History', 'History')
# ('History', 'History', 'History')
# ('History', 'History', 'of')
# ('History', 'of', 'Google')
# ('of', 'Google', 'List')
# ('Google', 'List', 'of')
# ('List', 'of', 'mergers')
# ('of', 'mergers', 'and')
# ('mergers', 'and', 'acquisitions')
# ('and', 'acquisitions', 'by')
# ('acquisitions', 'by', 'Alphabet')
# ('by', 'Alphabet', 'Alphabet')
# ('Alphabet', 'Alphabet', 'Inc.')
# ('Alphabet', 'Inc.', 'Early')
# ('Inc.', 'Early', 'years')
# ('Early', 'years', 'Early')
# ('years', 'Early', 'years')
# ('Early', 'years', 'Larry')
# ('years', 'Larry', 'Page')
# ('Larry', 'Page', 'Sergey')
# ('Page', 'Sergey', 'Brin')
# ('Sergey', 'Brin', 'Google')
# ('Brin', 'Google', 'began')
# ('Google', 'began', 'in')
# ('began', 'in', 'January')
# ('in', 'January', '1996')
# ('January', '1996', 'as')
# ('1996', 'as', 'a')
# ('as', 'a', 'research')
# ('a', 'research', 'project')
# ('research', 'project', 'by')
# ('project', 'by', 'Larry')
# ('by', 'Larry', 'Page')
# ('Larry', 'Page', 'and')
# ('Page', 'and', 'Sergey')
# ('and', 'Sergey', 'Brin')
# ('Sergey', 'Brin', 'when')
# ('Brin', 'when', 'they')
# ('when', 'they', 'were')
# ('they', 'were', 'both')
# ('were', 'both', 'PhD')
# ('both', 'PhD', 'students')
# ('PhD', 'students', 'at')
# ('students', 'at', 'Stanford')
# ('at', 'Stanford', 'University')
# ('Stanford', 'University', 'in')
# ('University', 'in', 'Stanford,')
# ('in', 'Stanford,', 'California.[13]')
# ('Stanford,', 'California.[13]', 'Larry')
# ('California.[13]', 'Larry', 'Page')
# ('Larry', 'Page', 'Sergey')
# ('Page', 'Sergey', 'Brin')
# ('Sergey', 'Brin', 'Stanford')
# ('Brin', 'Stanford', 'University')
# ('Stanford', 'University', 'Stanford,')
# ('University', 'Stanford,', 'California')
# ('Stanford,', 'California', '[13]')
# ('California', '[13]', 'While')
# ('[13]', 'While', 'conventional')
# ('While', 'conventional', 'search')
# ('conventional', 'search', 'engines')
# ('search', 'engines', 'ranked')
# ('engines', 'ranked', 'results')
# ('ranked', 'results', 'by')
# ('results', 'by', 'counting')
# ('by', 'counting', 'how')
# ('counting', 'how', 'many')
# ('how', 'many', 'times')
# ('many', 'times', 'the')
# ('times', 'the', 'search')
# ('the', 'search', 'terms')
# ('search', 'terms', 'appeared')
# ('terms', 'appeared', 'on')
# ('appeared', 'on', 'the')
# ('on', 'the', 'page,')
# ('the', 'page,', 'the')
# ('page,', 'the', 'two')
# ('the', 'two', 'theorized')
# ('two', 'theorized', 'about')
# ('theorized', 'about', 'a')
# ('about', 'a', 'better')
# ('a', 'better', 'system')
# ('better', 'system', 'that')
# ('system', 'that', 'analyzed')
# ('that', 'analyzed', 'the')
# ('analyzed', 'the', 'relationships')
# ('the', 'relationships', 'among')
# ('relationships', 'among', 'websites.[14]')
# ('among', 'websites.[14]', 'They')
# ('websites.[14]', 'They', 'called')
# ('They', 'called', 'this')
# ('called', 'this', 'algorithm')
# ('this', 'algorithm', 'PageRank;')
# ('algorithm', 'PageRank;', 'it')
# ('PageRank;', 'it', 'determined')
# ('it', 'determined', 'a')
# ('determined', 'a', "website's")
# ('a', "website's", 'relevance')
# ("website's", 'relevance', 'by')
# ('relevance', 'by', 'the')
# ('by', 'the', 'number')
# ('the', 'number', 'of')
# ('number', 'of', 'pages,')
# ('of', 'pages,', 'and')
# ('pages,', 'and', 'the')
# ('and', 'the', 'importance')
# ('the', 'importance', 'of')
# ('importance', 'of', 'those')
# ('of', 'those', 'pages')
# ('those', 'pages', 'that')
# ('pages', 'that', 'linked')
# ('that', 'linked', 'back')
# ('linked', 'back', 'to')
# ('back', 'to', 'the')
# ('to', 'the', 'original')
# ('the', 'original', 'site.[15][16]')
# ('original', 'site.[15][16]', 'PageRank')
# ('site.[15][16]', 'PageRank', 'was')
# ('PageRank', 'was', 'influenced')
# ('was', 'influenced', 'by')
# ('influenced', 'by', 'a')
# ('by', 'a', 'similar')
# ('a', 'similar', 'page-ranking')
# ('similar', 'page-ranking', 'and')
# ('page-ranking', 'and', 'site-scoring')
# ('and', 'site-scoring', 'algorithm')
# ('site-scoring', 'algorithm', 'earlier')
# ('algorithm', 'earlier', 'used')
# ('earlier', 'used', 'for')
# ('used', 'for', 'RankDex,')
# ('for', 'RankDex,', 'developed')
# ('RankDex,', 'developed', 'by')
# ('developed', 'by', 'Robin')
# ('by', 'Robin', 'Li')
# ('Robin', 'Li', 'in')
# ('Li', 'in', '1996,')
# ('in', '1996,', 'with')
# ('1996,', 'with', 'Larry')
# ('with', 'Larry', "Page's")
# ('Larry', "Page's", 'PageRank')
# ("Page's", 'PageRank', 'patent')
# ('PageRank', 'patent', 'including')
# ('patent', 'including', 'a')
# ('including', 'a', 'citation')
# ('a', 'citation', 'to')
# ('citation', 'to', "Li's")
# ('to', "Li's", 'earlier')
# ("Li's", 'earlier', 'RankDex')
# ('earlier', 'RankDex', 'patent;')
# ('RankDex', 'patent;', 'Li')
# ('patent;', 'Li', 'later')
# ('Li', 'later', 'went')
# ('later', 'went', 'on')
# ('went', 'on', 'to')
# ('on', 'to', 'create')
# ('to', 'create', 'the')
# ('create', 'the', 'Chinese')
# ('the', 'Chinese', 'search')
# ('Chinese', 'search', 'engine')
# ('search', 'engine', 'Baidu.[17][18][19]')
# ('engine', 'Baidu.[17][18][19]', '[14]')
# ('Baidu.[17][18][19]', '[14]', 'PageRank')
# ('[14]', 'PageRank', 'relevance')
# ('PageRank', 'relevance', '[15]')
# ('relevance', '[15]', '[16]')
# ('[15]', '[16]', 'RankDex')
# ('[16]', 'RankDex', 'Robin')
# ('RankDex', 'Robin', 'Li')
# ('Robin', 'Li', 'Baidu')
# ('Li', 'Baidu', '[17]')
# ('Baidu', '[17]', '[18]')
# ('[17]', '[18]', '[19]')
# ('[18]', '[19]', 'Page')
# ('[19]', 'Page', 'and')
# ('Page', 'and', 'Brin')
# ('and', 'Brin', 'originally')
# ('Brin', 'originally', 'nicknamed')
# ('originally', 'nicknamed', 'their')
# ('nicknamed', 'their', 'new')
# ('their', 'new', 'search')
# ('new', 'search', 'engine')
# ('search', 'engine', '"BackRub",')
# ('engine', '"BackRub",', 'because')
# ('"BackRub",', 'because', 'the')
# ('because', 'the', 'system')
# ('the', 'system', 'checked')
# ('system', 'checked', 'backlinks')
# ('checked', 'backlinks', 'to')
# ('backlinks', 'to', 'estimate')
# ('to', 'estimate', 'the')
# ('estimate', 'the', 'importance')
# ('the', 'importance', 'of')
# ('importance', 'of', 'a')
# ('of', 'a', 'site.[20][21][22]')
# ('a', 'site.[20][21][22]', 'Eventually,')
# ('site.[20][21][22]', 'Eventually,', 'they')
# ('Eventually,', 'they', 'changed')
# ('they', 'changed', 'the')
# ('changed', 'the', 'name')
# ('the', 'name', 'to')
# ('name', 'to', 'Google;')
# ('to', 'Google;', 'the')
# ('Google;', 'the', 'name')
# ('the', 'name', 'of')
# ('name', 'of', 'the')
# ('of', 'the', 'search')
# ('the', 'search', 'engine')
# ('search', 'engine', 'originated')
# ('engine', 'originated', 'from')
# ('originated', 'from', 'a')
# ('from', 'a', 'misspelling')
# ('a', 'misspelling', 'of')
# ('misspelling', 'of', 'the')
# ('of', 'the', 'word')
# ('the', 'word', '"googol",[23][24]')
# ('word', '"googol",[23][24]', 'the')
# ('"googol",[23][24]', 'the', 'number')
# ('the', 'number', '1')
# ('number', '1', 'followed')
# ('1', 'followed', 'by')
# ('followed', 'by', '100')
# ('by', '100', 'zeros,')
# ('100', 'zeros,', 'which')
# ('zeros,', 'which', 'was')
# ('which', 'was', 'picked')
# ('was', 'picked', 'to')
# ('picked', 'to', 'signify')
# ('to', 'signify', 'that')
# ('signify', 'that', 'the')
# ('that', 'the', 'search')
# ('the', 'search', 'engine')
# ('search', 'engine', 'was')
# ('engine', 'was', 'intended')
# ('was', 'intended', 'to')
# ('intended', 'to', 'provide')
# ('to', 'provide', 'large')
# ('provide', 'large', 'quantities')
# ('large', 'quantities', 'of')
# ('quantities', 'of', 'information.[25]')
# ('of', 'information.[25]', '[20]')
# ('information.[25]', '[20]', '[21]')
# ('[20]', '[21]', '[22]')
# ('[21]', '[22]', 'googol')
# ('[22]', 'googol', '[23]')
# ('googol', '[23]', '[24]')
# ('[23]', '[24]', '[25]')
# ('[24]', '[25]', 'HTML')
# ('[25]', 'HTML', 'markup')
# ('HTML', 'markup', 'language')
# ('markup', 'language', '[26]')
# ('language', '[26]', 'The')
# ('[26]', 'The', 'domain')
# ('The', 'domain', 'name')
# ('domain', 'name', 'for')
# ('name', 'for', 'Google')
# ('for', 'Google', 'was')
# ('Google', 'was', 'registered')
# ('was', 'registered', 'on')
# ('registered', 'on', 'September')
# ('on', 'September', '15,')
# ('September', '15,', '1997,[27]')
# ('15,', '1997,[27]', 'and')
# ('1997,[27]', 'and', 'the')
# ('and', 'the', 'company')
# ('the', 'company', 'was')
# ('company', 'was', 'incorporated')
# ('was', 'incorporated', 'on')
# ('incorporated', 'on', 'September')
# ('on', 'September', '4,')
# ('September', '4,', '1998.')
# ('4,', '1998.', 'It')
# ('1998.', 'It', 'was')
# ('It', 'was', 'based')
# ('was', 'based', 'in')
# ('based', 'in', 'the')
# ('in', 'the', 'garage')
# ('the', 'garage', 'of')
# ('garage', 'of', 'a')
# ('of', 'a', 'friend')
# ('a', 'friend', '(Susan')
# ('friend', '(Susan', 'Wojcicki[13])')
# ('(Susan', 'Wojcicki[13])', 'in')
# ('Wojcicki[13])', 'in', 'Menlo')
# ('in', 'Menlo', 'Park,')
# ('Menlo', 'Park,', 'California.')
# ('Park,', 'California.', 'Craig')
# ('California.', 'Craig', 'Silverstein,')
# ('Craig', 'Silverstein,', 'a')
# ('Silverstein,', 'a', 'fellow')
# ('a', 'fellow', 'PhD')
# ('fellow', 'PhD', 'student')
# ('PhD', 'student', 'at')
# ('student', 'at', 'Stanford,')
# ('at', 'Stanford,', 'was')
# ('Stanford,', 'was', 'hired')
# ('was', 'hired', 'as')
# ('hired', 'as', 'the')
# ('as', 'the', 'first')
# ('the', 'first', 'employee.[13][28][29]')
# ('first', 'employee.[13][28][29]', '[27]')
# ('employee.[13][28][29]', '[27]', 'Susan')
# ('[27]', 'Susan', 'Wojcicki')
# ('Susan', 'Wojcicki', '[13]')
# ('Wojcicki', '[13]', 'Menlo')
# ('[13]', 'Menlo', 'Park,')
# ('Menlo', 'Park,', 'California')
# ('Park,', 'California', 'Craig')
# ('California', 'Craig', 'Silverstein')
# ('Craig', 'Silverstein', '[13]')
# ('Silverstein', '[13]', '[28]')
# ('[13]', '[28]', '[29]')
# ('[28]', '[29]', 'Google')
# ('[29]', 'Google', 'was')
# ('Google', 'was', 'initially')
# ('was', 'initially', 'funded')
# ('initially', 'funded', 'by')
# ('funded', 'by', 'an')
# ('by', 'an', 'August')
# ('an', 'August', '1998')
# ('August', '1998', 'contribution')
# ('1998', 'contribution', 'of')
# ('contribution', 'of', '$100,000')
# ('of', '$100,000', 'from')
# ('$100,000', 'from', 'Andy')
# ('from', 'Andy', 'Bechtolsheim,')
# ('Andy', 'Bechtolsheim,', 'co-founder')
# ('Bechtolsheim,', 'co-founder', 'of')
# ('co-founder', 'of', 'Sun')
# ('of', 'Sun', 'Microsystems;')
# ('Sun', 'Microsystems;', 'the')
# ('Microsystems;', 'the', 'money')
# ('the', 'money', 'was')
# ('money', 'was', 'given')
# ('was', 'given', 'before')
# ('given', 'before', 'Google')
# ('before', 'Google', 'was')
# ('Google', 'was', 'incorporated.[30]')
# ('was', 'incorporated.[30]', 'Google')
# ('incorporated.[30]', 'Google', 'received')
# ('Google', 'received', 'money')
# ('received', 'money', 'from')
# ('money', 'from', 'three')
# ('from', 'three', 'other')
# ('three', 'other', 'angel')
# ('other', 'angel', 'investors')
# ('angel', 'investors', 'in')
# ('investors', 'in', '1998:')
# ('in', '1998:', 'Amazon.com')
# ('1998:', 'Amazon.com', 'founder')
# ('Amazon.com', 'founder', 'Jeff')
# ('founder', 'Jeff', 'Bezos,')
# ('Jeff', 'Bezos,', 'Stanford')
# ('Bezos,', 'Stanford', 'University')
# ('Stanford', 'University', 'computer')
# ('University', 'computer', 'science')
# ('computer', 'science', 'professor')
# ('science', 'professor', 'David')
# ('professor', 'David', 'Cheriton,')
# ('David', 'Cheriton,', 'and')
# ('Cheriton,', 'and', 'entrepreneur')
# ('and', 'entrepreneur', 'Ram')
# ('entrepreneur', 'Ram', 'Shriram.[31]')
# ('Ram', 'Shriram.[31]', 'Between')
# ('Shriram.[31]', 'Between', 'these')
# ('Between', 'these', 'initial')
# ('these', 'initial', 'investors,')
# ('initial', 'investors,', 'friends,')
# ('investors,', 'friends,', 'and')
# ('friends,', 'and', 'family')
# ('and', 'family', 'Google')
# ('family', 'Google', 'raised')
# ('Google', 'raised', 'around')
# ('raised', 'around', '1')
# ('around', '1', 'million')
# ('1', 'million', 'dollars,')
# ('million', 'dollars,', 'which')
# ('dollars,', 'which', 'is')
# ('which', 'is', 'what')
# ('is', 'what', 'allowed')
# ('what', 'allowed', 'them')
# ('allowed', 'them', 'to')
# ('them', 'to', 'open')
# ('to', 'open', 'up')
# ('open', 'up', 'their')
# ('up', 'their', 'original')
# ('their', 'original', 'shop')
# ('original', 'shop', 'in')
# ('shop', 'in', 'Menlo')
# ('in', 'Menlo', 'Park,')
# ('Menlo', 'Park,', 'California')
# ('Park,', 'California', '[32]')
# ('California', '[32]', 'Andy')
# ('[32]', 'Andy', 'Bechtolsheim')
# ('Andy', 'Bechtolsheim', 'Sun')
# ('Bechtolsheim', 'Sun', 'Microsystems')
# ('Sun', 'Microsystems', '[30]')
# ('Microsystems', '[30]', 'angel')
# ('[30]', 'angel', 'investors')
# ('angel', 'investors', 'Amazon.com')
# ('investors', 'Amazon.com', 'Jeff')
# ('Amazon.com', 'Jeff', 'Bezos')
# ('Jeff', 'Bezos', 'David')
# ('Bezos', 'David', 'Cheriton')
# ('David', 'Cheriton', 'Ram')
# ('Cheriton', 'Ram', 'Shriram')
# ('Ram', 'Shriram', '[31]')
# ('Shriram', '[31]', 'Menlo')
# ('[31]', 'Menlo', 'Park,')
# ('Menlo', 'Park,', 'California')
# ('Park,', 'California', '[32]')
# ('California', '[32]', 'After')
# ('[32]', 'After', 'some')
# ('After', 'some', 'additional,')
# ('some', 'additional,', 'small')
# ('additional,', 'small', 'investments')
# ('small', 'investments', 'through')
# ('investments', 'through', 'the')
# ('through', 'the', 'end')
# ('the', 'end', 'of')
# ('end', 'of', '1998')
# ('of', '1998', 'to')
# ('1998', 'to', 'early')
# ('to', 'early', '1999,[31]')
# ('early', '1999,[31]', 'a')
# ('1999,[31]', 'a', 'new')
# ('a', 'new', '$25')
# ('new', '$25', 'million')
# ('$25', 'million', 'round')
# ('million', 'round', 'of')
# ('round', 'of', 'funding')
# ('of', 'funding', 'was')
# ('funding', 'was', 'announced')
# ('was', 'announced', 'on')
# ('announced', 'on', 'June')
# ('on', 'June', '7,')
# ('June', '7,', '1999,[33]')
# ('7,', '1999,[33]', 'with')
# ('1999,[33]', 'with', 'major')
# ('with', 'major', 'investors')
# ('major', 'investors', 'including')
# ('investors', 'including', 'the')
# ('including', 'the', 'venture')
# ('the', 'venture', 'capital')
# ('venture', 'capital', 'firms')
# ('capital', 'firms', 'Kleiner')
# ('firms', 'Kleiner', 'Perkins')
# ('Kleiner', 'Perkins', 'and')
# ('Perkins', 'and', 'Sequoia')
# ('and', 'Sequoia', 'Capital.[30]')
# ('Sequoia', 'Capital.[30]', '[31]')
# ('Capital.[30]', '[31]', '[33]')
# ('[31]', '[33]', 'venture')
# ('[33]', 'venture', 'capital')
# ('venture', 'capital', 'Kleiner')
# ('capital', 'Kleiner', 'Perkins')
# ('Kleiner', 'Perkins', 'Sequoia')
# ('Perkins', 'Sequoia', 'Capital')
# ('Sequoia', 'Capital', '[30]')
# ('Capital', '[30]', 'Growth')
# ('[30]', 'Growth', 'Growth')
# ('Growth', 'Growth', 'In')
# ('Growth', 'In', 'March')
# ('In', 'March', '1999,')
# ('March', '1999,', 'the')
# ('1999,', 'the', 'company')
# ('the', 'company', 'moved')
# ('company', 'moved', 'its')
# ('moved', 'its', 'offices')
# ('its', 'offices', 'to')
# ('offices', 'to', 'Palo')
# ('to', 'Palo', 'Alto,')
# ('Palo', 'Alto,', 'California,[34]')
# ('Alto,', 'California,[34]', 'which')
# ('California,[34]', 'which', 'is')
# ('which', 'is', 'home')
# ('is', 'home', 'to')
# ('home', 'to', 'several')
# ('to', 'several', 'prominent')
# ('several', 'prominent', 'Silicon')
# ('prominent', 'Silicon', 'Valley')
# ('Silicon', 'Valley', 'technology')
# ('Valley', 'technology', 'start-ups.[35]')
# ('technology', 'start-ups.[35]', 'The')
# ('start-ups.[35]', 'The', 'next')
# ('The', 'next', 'year,')
# ('next', 'year,', 'Google')
# ('year,', 'Google', 'began')
# ('Google', 'began', 'selling')
# ('began', 'selling', 'advertisements')
# ('selling', 'advertisements', 'associated')
# ('advertisements', 'associated', 'with')
# ('associated', 'with', 'search')
# ('with', 'search', 'keywords')
# ('search', 'keywords', 'against')
# ('keywords', 'against', 'Page')
# ('against', 'Page', 'and')
# ('Page', 'and', "Brin's")
# ('and', "Brin's", 'initial')
# ("Brin's", 'initial', 'opposition')
# ('initial', 'opposition', 'toward')
# ('opposition', 'toward', 'an')
# ('toward', 'an', 'advertising-funded')
# ('an', 'advertising-funded', 'search')
# ('advertising-funded', 'search', 'engine.[36][13]')
# ('search', 'engine.[36][13]', 'To')
# ('engine.[36][13]', 'To', 'maintain')
# ('To', 'maintain', 'an')
# ('maintain', 'an', 'uncluttered')
# ('an', 'uncluttered', 'page')
# ('uncluttered', 'page', 'design,')
# ('page', 'design,', 'advertisements')
# ('design,', 'advertisements', 'were')
# ('advertisements', 'were', 'solely')
# ('were', 'solely', 'text-based.[37]')
# ('solely', 'text-based.[37]', 'In')
# ('text-based.[37]', 'In', 'June')
# ('In', 'June', '2000,')
# ('June', '2000,', 'it')
# ('2000,', 'it', 'was')
# ('it', 'was', 'announced')
# ('was', 'announced', 'that')
# ('announced', 'that', 'Google')
# ('that', 'Google', 'would')
# ('Google', 'would', 'become')
# ('would', 'become', 'the')
# ('become', 'the', 'default')
# ('the', 'default', 'search')
# ('default', 'search', 'engine')
# ('search', 'engine', 'provider')
# ('engine', 'provider', 'for')
# ('provider', 'for', 'Yahoo!,')
# ('for', 'Yahoo!,', 'one')
# ('Yahoo!,', 'one', 'of')
# ('one', 'of', 'the')
# ('of', 'the', 'most')
# ('the', 'most', 'popular')
# ('most', 'popular', 'websites')
# ('popular', 'websites', 'at')
# ('websites', 'at', 'the')
# ('at', 'the', 'time,')
# ('the', 'time,', 'replacing')
# ('time,', 'replacing', 'Inktomi.[38][39]')
# ('replacing', 'Inktomi.[38][39]', 'Palo')
# ('Inktomi.[38][39]', 'Palo', 'Alto,')
# ('Palo', 'Alto,', 'California')
# ('Alto,', 'California', '[34]')
# ('California', '[34]', 'Silicon')
# ('[34]', 'Silicon', 'Valley')
# ('Silicon', 'Valley', '[35]')
# ('Valley', '[35]', '[36]')
# ('[35]', '[36]', '[13]')
# ('[36]', '[13]', '[37]')
# ('[13]', '[37]', 'Yahoo!')
# ('[37]', 'Yahoo!', 'Inktomi')
# ('Yahoo!', 'Inktomi', '[38]')
# ('Inktomi', '[38]', '[39]')
# ('[38]', '[39]', '[40]')
# ('[39]', '[40]', 'In')
# ('[40]', 'In', '2003,')
# ('In', '2003,', 'after')
# ('2003,', 'after', 'outgrowing')
# ('after', 'outgrowing', 'two')
# ('outgrowing', 'two', 'other')
# ('two', 'other', 'locations,')
# ('other', 'locations,', 'the')
# ('locations,', 'the', 'company')
# ('the', 'company', 'leased')
# ('company', 'leased', 'an')
# ('leased', 'an', 'office')
# ('an', 'office', 'complex')
# ('office', 'complex', 'from')
# ('complex', 'from', 'Silicon')
# ('from', 'Silicon', 'Graphics,')
# ('Silicon', 'Graphics,', 'at')
# ('Graphics,', 'at', '1600')
# ('at', '1600', 'Amphitheatre')
# ('1600', 'Amphitheatre', 'Parkway')
# ('Amphitheatre', 'Parkway', 'in')
# ('Parkway', 'in', 'Mountain')
# ('in', 'Mountain', 'View,')
# ('Mountain', 'View,', 'California.[41]')
# ('View,', 'California.[41]', 'The')
# ('California.[41]', 'The', 'complex')
# ('The', 'complex', 'became')
# ('complex', 'became', 'known')
# ('became', 'known', 'as')
# ('known', 'as', 'the')
# ('as', 'the', 'Googleplex,')
# ('the', 'Googleplex,', 'a')
# ('Googleplex,', 'a', 'play')
# ('a', 'play', 'on')
# ('play', 'on', 'the')
# ('on', 'the', 'word')
# ('the', 'word', 'googolplex,')
# ('word', 'googolplex,', 'the')
# ('googolplex,', 'the', 'number')
# ('the', 'number', 'one')
# ('number', 'one', 'followed')
# ('one', 'followed', 'by')
# ('followed', 'by', 'a')
# ('by', 'a', 'googol')
# ('a', 'googol', 'zeroes.')
# ('googol', 'zeroes.', 'Three')
# ('zeroes.', 'Three', 'years')
# ('Three', 'years', 'later,')
# ('years', 'later,', 'Google')
# ('later,', 'Google', 'bought')
# ('Google', 'bought', 'the')
# ('bought', 'the', 'property')
# ('the', 'property', 'from')
# ('property', 'from', 'SGI')
# ('from', 'SGI', 'for')
# ('SGI', 'for', '$319')
# ('for', '$319', 'million.[42]')
# ('$319', 'million.[42]', 'By')
# ('million.[42]', 'By', 'that')
# ('By', 'that', 'time,')
# ('that', 'time,', 'the')
# ('time,', 'the', 'name')
# ('the', 'name', '"Google"')
# ('name', '"Google"', 'had')
# ('"Google"', 'had', 'found')
# ('had', 'found', 'its')
# ('found', 'its', 'way')
# ('its', 'way', 'into')
# ('way', 'into', 'everyday')
# ('into', 'everyday', 'language,')
# ('everyday', 'language,', 'causing')
# ('language,', 'causing', 'the')
# ('causing', 'the', 'verb')
# ('the', 'verb', '"google"')
# ('verb', '"google"', 'to')
# ('"google"', 'to', 'be')
# ('to', 'be', 'added')
# ('be', 'added', 'to')
# ('added', 'to', 'the')
# ('to', 'the', 'Merriam-Webster')
# ('the', 'Merriam-Webster', 'Collegiate')
# ('Merriam-Webster', 'Collegiate', 'Dictionary')
# ('Collegiate', 'Dictionary', 'and')
# ('Dictionary', 'and', 'the')
# ('and', 'the', 'Oxford')
# ('the', 'Oxford', 'English')
# ('Oxford', 'English', 'Dictionary,')
# ('English', 'Dictionary,', 'denoted')
# ('Dictionary,', 'denoted', 'as:')
# ('denoted', 'as:', '"to')
# ('as:', '"to', 'use')
# ('"to', 'use', 'the')
# ('use', 'the', 'Google')
# ('the', 'Google', 'search')
# ('Google', 'search', 'engine')
# ('search', 'engine', 'to')
# ('engine', 'to', 'obtain')
# ...
# ('history', 'Read', 'Read')
# ('Read', 'Read', 'View')
# ('Read', 'View', 'source')
# ('View', 'source', 'View')
# ('source', 'View', 'source')
# ('View', 'source', 'View')
# ('source', 'View', 'history')
# ('View', 'history', 'View')
# ('history', 'View', 'history')
# ('View', 'history', 'More')
# ('history', 'More', 'More')
# ('More', 'More', 'Search')
# ('More', 'Search', 'Navigation')
# ('Search', 'Navigation', 'Main')
# ('Navigation', 'Main', 'pageContentsFeatured')
# ('Main', 'pageContentsFeatured', 'contentCurrent')
# ('pageContentsFeatured', 'contentCurrent', 'eventsRandom')
# ('contentCurrent', 'eventsRandom', 'articleDonate')
# ('eventsRandom', 'articleDonate', 'to')
# ('articleDonate', 'to', 'WikipediaWikipedia')
# ('to', 'WikipediaWikipedia', 'store')
# ('WikipediaWikipedia', 'store', 'Main')
# ('store', 'Main', 'page')
# ('Main', 'page', 'Contents')
# ('page', 'Contents', 'Featured')
# ('Contents', 'Featured', 'content')
# ('Featured', 'content', 'Current')
# ('content', 'Current', 'events')
# ('Current', 'events', 'Random')
# ('events', 'Random', 'article')
# ('Random', 'article', 'Donate')
# ('article', 'Donate', 'to')
# ('Donate', 'to', 'Wikipedia')
# ('to', 'Wikipedia', 'Wikipedia')
# ('Wikipedia', 'Wikipedia', 'store')
# ('Wikipedia', 'store', 'Interaction')
# ('store', 'Interaction', 'HelpAbout')
# ('Interaction', 'HelpAbout', 'WikipediaCommunity')
# ('HelpAbout', 'WikipediaCommunity', 'portalRecent')
# ('WikipediaCommunity', 'portalRecent', 'changesContact')
# ('portalRecent', 'changesContact', 'page')
# ('changesContact', 'page', 'Help')
# ('page', 'Help', 'About')
# ('Help', 'About', 'Wikipedia')
# ('About', 'Wikipedia', 'Community')
# ('Wikipedia', 'Community', 'portal')
# ('Community', 'portal', 'Recent')
# ('portal', 'Recent', 'changes')
# ('Recent', 'changes', 'Contact')
# ('changes', 'Contact', 'page')
# ('Contact', 'page', 'Tools')
# ('page', 'Tools', 'What')
# ('Tools', 'What', 'links')
# ('What', 'links', 'hereRelated')
# ('links', 'hereRelated', 'changesUpload')
# ('hereRelated', 'changesUpload', 'fileSpecial')
# ('changesUpload', 'fileSpecial', 'pagesPermanent')
# ('fileSpecial', 'pagesPermanent', 'linkPage')
# ('pagesPermanent', 'linkPage', 'informationWikidata')
# ('linkPage', 'informationWikidata', 'itemCite')
# ('informationWikidata', 'itemCite', 'this')
# ('itemCite', 'this', 'page')
# ('this', 'page', 'What')
# ('page', 'What', 'links')
# ('What', 'links', 'here')
# ('links', 'here', 'Related')
# ('here', 'Related', 'changes')
# ('Related', 'changes', 'Upload')
# ('changes', 'Upload', 'file')
# ('Upload', 'file', 'Special')
# ('file', 'Special', 'pages')
# ('Special', 'pages', 'Permanent')
# ('pages', 'Permanent', 'link')
# ('Permanent', 'link', 'Page')
# ('link', 'Page', 'information')
# ('Page', 'information', 'Wikidata')
# ('information', 'Wikidata', 'item')
# ('Wikidata', 'item', 'Cite')
# ('item', 'Cite', 'this')
# ('Cite', 'this', 'page')
# ('this', 'page', 'In')
# ('page', 'In', 'other')
# ('In', 'other', 'projects')
# ('other', 'projects', 'Wikimedia')
# ('projects', 'Wikimedia', 'CommonsMeta-WikiWikiquoteWikiversity')
# ('Wikimedia', 'CommonsMeta-WikiWikiquoteWikiversity', 'Wikimedia')
# ('CommonsMeta-WikiWikiquoteWikiversity', 'Wikimedia', 'Commons')
# ('Wikimedia', 'Commons', 'Meta-Wiki')
# ('Commons', 'Meta-Wiki', 'Wikiquote')
# ('Meta-Wiki', 'Wikiquote', 'Wikiversity')
# ('Wikiquote', 'Wikiversity', 'Print/export')
# ('Wikiversity', 'Print/export', 'Create')
# ('Print/export', 'Create', 'a')
# ('Create', 'a', 'bookDownload')
# ('a', 'bookDownload', 'as')
# ('bookDownload', 'as', 'PDFPrintable')
# ('as', 'PDFPrintable', 'version')
# ('PDFPrintable', 'version', 'Create')
# ('version', 'Create', 'a')
# ('Create', 'a', 'book')
# ('a', 'book', 'Download')
# ('book', 'Download', 'as')
# ('Download', 'as', 'PDF')
# ('as', 'PDF', 'Printable')
# ('PDF', 'Printable', 'version')
# ('Printable', 'version', 'Languages')
# ('version', 'Languages', 'AfrikaansአማርኛÆngliscالعربيةঅসমীয়াAsturianuAzərbaycancaتۆرکجهBamanankanবাংলাBahasa')
# ('Languages', 'AfrikaansአማርኛÆngliscالعربيةঅসমীয়াAsturianuAzərbaycancaتۆرکجهBamanankanবাংলাBahasa', 'BanjarBân-lâm-gúБеларускаяБеларуская')
# ('AfrikaansአማርኛÆngliscالعربيةঅসমীয়াAsturianuAzərbaycancaتۆرکجهBamanankanবাংলাBahasa', 'BanjarBân-lâm-gúБеларускаяБеларуская', '(тарашкевіца)\u200eभोजपुरीБългарскиBoarischBosanskiBrezhonegCatalàЧӑвашлаCebuanoČeštinaCymraegDanskDeutschDolnoserbskiडोटेलीEestiΕλληνικάEspañolEsperantoEuskaraفارسیFøroysktFrançaisGaeilgeGalego贛語ગુજરાતી客家語/Hak-kâ-ngî한국어Հայերենहिन्दीHornjoserbsceHrvatskiBahasa')
# ('BanjarBân-lâm-gúБеларускаяБеларуская', '(тарашкевіца)\u200eभोजपुरीБългарскиBoarischBosanskiBrezhonegCatalàЧӑвашлаCebuanoČeštinaCymraegDanskDeutschDolnoserbskiडोटेलीEestiΕλληνικάEspañolEsperantoEuskaraفارسیFøroysktFrançaisGaeilgeGalego贛語ગુજરાતી客家語/Hak-kâ-ngî한국어Հայերենहिन्दीHornjoserbsceHrvatskiBahasa', 'HulontaloIdoBahasa')
# ('(тарашкевіца)\u200eभोजपुरीБългарскиBoarischBosanskiBrezhonegCatalàЧӑвашлаCebuanoČeštinaCymraegDanskDeutschDolnoserbskiडोटेलीEestiΕλληνικάEspañolEsperantoEuskaraفارسیFøroysktFrançaisGaeilgeGalego贛語ગુજરાતી客家語/Hak-kâ-ngî한국어Հայերենहिन्दीHornjoserbsceHrvatskiBahasa', 'HulontaloIdoBahasa', 'Indonesiaᐃᓄᒃᑎᑐᑦ/inuktitutÍslenskaItalianoעבריתJawaKabɩyɛಕನ್ನಡქართულიҚазақшаKirundiKreyòl')
# ('HulontaloIdoBahasa', 'Indonesiaᐃᓄᒃᑎᑐᑦ/inuktitutÍslenskaItalianoעבריתJawaKabɩyɛಕನ್ನಡქართულიҚазақшаKirundiKreyòl', 'ayisyenKurdîКыргызчаລາວلۊری')
# ('Indonesiaᐃᓄᒃᑎᑐᑦ/inuktitutÍslenskaItalianoעבריתJawaKabɩyɛಕನ್ನಡქართულიҚазақшаKirundiKreyòl', 'ayisyenKurdîКыргызчаລາວلۊری', 'شومالیLatinaLatviešuLietuviųMagyarमैथिलीМакедонскиMalagasyമലയാളംमराठीმარგალურიمصرىمازِرونیBahasa')
# ('ayisyenKurdîКыргызчаລາວلۊری', 'شومالیLatinaLatviešuLietuviųMagyarमैथिलीМакедонскиMalagasyമലയാളംमराठीმარგალურიمصرىمازِرونیBahasa', 'MelayuMìng-dĕ̤ng-ngṳ̄Монголမြန်မာဘာသာNāhuatlNederlandsनेपाली日本語NorskNorsk')
# ('شومالیLatinaLatviešuLietuviųMagyarमैथिलीМакедонскиMalagasyമലയാളംमराठीმარგალურიمصرىمازِرونیBahasa', 'MelayuMìng-dĕ̤ng-ngṳ̄Монголမြန်မာဘာသာNāhuatlNederlandsनेपाली日本語NorskNorsk', 'nynorskOccitanଓଡ଼ିଆOʻzbekcha/ўзбекчаਪੰਜਾਬੀپنجابیپښتوភាសាខ្មែរPiemontèisPlattdüütschPolskiPortuguêsQaraqalpaqshaRomânăRuna')
# ('MelayuMìng-dĕ̤ng-ngṳ̄Монголမြန်မာဘာသာNāhuatlNederlandsनेपाली日本語NorskNorsk', 'nynorskOccitanଓଡ଼ିଆOʻzbekcha/ўзбекчаਪੰਜਾਬੀپنجابیپښتوភាសាខ្មែរPiemontèisPlattdüütschPolskiPortuguêsQaraqalpaqshaRomânăRuna', 'SimiРусскийСаха')
# ('nynorskOccitanଓଡ଼ିଆOʻzbekcha/ўзбекчаਪੰਜਾਬੀپنجابیپښتوភាសាខ្មែរPiemontèisPlattdüütschPolskiPortuguêsQaraqalpaqshaRomânăRuna', 'SimiРусскийСаха', 'тылаᱥᱟᱱᱛᱟᱲᱤScotsShqipSicilianuසිංහලSimple')
# ('SimiРусскийСаха', 'тылаᱥᱟᱱᱛᱟᱲᱤScotsShqipSicilianuසිංහලSimple', 'EnglishسنڌيSlovenčinaSlovenščinaSoomaaligaکوردیСрпски')
# ('тылаᱥᱟᱱᱛᱟᱲᱤScotsShqipSicilianuසිංහලSimple', 'EnglishسنڌيSlovenčinaSlovenščinaSoomaaligaکوردیСрпски', '/')
# ('EnglishسنڌيSlovenčinaSlovenščinaSoomaaligaکوردیСрпски', '/', 'srpskiSrpskohrvatski')
# ('/', 'srpskiSrpskohrvatski', '/')
# ('srpskiSrpskohrvatski', '/', 'српскохрватскиBasa')
# ('/', 'српскохрватскиBasa', 'SundaSuomiSvenskaTagalogதமிழ்Татарча/tatarçaతెలుగుTetunไทยТоҷикӣತುಳುTürkçeTürkmençeThuɔŋjäŋУкраїнськаاردوئۇيغۇرچە')
# ('српскохрватскиBasa', 'SundaSuomiSvenskaTagalogதமிழ்Татарча/tatarçaతెలుగుTetunไทยТоҷикӣತುಳುTürkçeTürkmençeThuɔŋjäŋУкраїнськаاردوئۇيغۇرچە', '/')
# ('SundaSuomiSvenskaTagalogதமிழ்Татарча/tatarçaతెలుగుTetunไทยТоҷикӣತುಳುTürkçeTürkmençeThuɔŋjäŋУкраїнськаاردوئۇيغۇرچە', '/', 'UyghurcheVènetoTiếng')
# ('/', 'UyghurcheVènetoTiếng', 'ViệtWalon文言West-VlamsWinaray吴语ייִדישYorùbá粵語ZazakiZeêuwsŽemaitėška中文')
# ('UyghurcheVènetoTiếng', 'ViệtWalon文言West-VlamsWinaray吴语ייִדישYorùbá粵語ZazakiZeêuwsŽemaitėška中文', 'Afrikaans')
# ('ViệtWalon文言West-VlamsWinaray吴语ייִדישYorùbá粵語ZazakiZeêuwsŽemaitėška中文', 'Afrikaans', 'አማርኛ')
# ('Afrikaans', 'አማርኛ', 'Ænglisc')
# ('አማርኛ', 'Ænglisc', 'العربية')
# ('Ænglisc', 'العربية', 'অসমীয়া')
# ('العربية', 'অসমীয়া', 'Asturianu')
# ('অসমীয়া', 'Asturianu', 'Azərbaycanca')
# ('Asturianu', 'Azərbaycanca', 'تۆرکجه')
# ('Azərbaycanca', 'تۆرکجه', 'Bamanankan')
# ('تۆرکجه', 'Bamanankan', 'বাংলা')
# ('Bamanankan', 'বাংলা', 'Bahasa')
# ('বাংলা', 'Bahasa', 'Banjar')
# ('Bahasa', 'Banjar', 'Bân-lâm-gú')
# ('Banjar', 'Bân-lâm-gú', 'Беларуская')
# ('Bân-lâm-gú', 'Беларуская', 'Беларуская')
# ('Беларуская', 'Беларуская', '(тарашкевіца)\u200e')
# ('Беларуская', '(тарашкевіца)\u200e', 'भोजपुरी')
# ('(тарашкевіца)\u200e', 'भोजपुरी', 'Български')
# ('भोजपुरी', 'Български', 'Boarisch')
# ('Български', 'Boarisch', 'Bosanski')
# ('Boarisch', 'Bosanski', 'Brezhoneg')
# ('Bosanski', 'Brezhoneg', 'Català')
# ('Brezhoneg', 'Català', 'Чӑвашла')
# ('Català', 'Чӑвашла', 'Cebuano')
# ('Чӑвашла', 'Cebuano', 'Čeština')
# ('Cebuano', 'Čeština', 'Cymraeg')
# ('Čeština', 'Cymraeg', 'Dansk')
# ('Cymraeg', 'Dansk', 'Deutsch')
# ('Dansk', 'Deutsch', 'Dolnoserbski')
# ('Deutsch', 'Dolnoserbski', 'डोटेली')
# ('Dolnoserbski', 'डोटेली', 'Eesti')
# ('डोटेली', 'Eesti', 'Ελληνικά')
# ('Eesti', 'Ελληνικά', 'Español')
# ('Ελληνικά', 'Español', 'Esperanto')
# ('Español', 'Esperanto', 'Euskara')
# ('Esperanto', 'Euskara', 'فارسی')
# ('Euskara', 'فارسی', 'Føroyskt')
# ('فارسی', 'Føroyskt', 'Français')
# ('Føroyskt', 'Français', 'Gaeilge')
# ('Français', 'Gaeilge', 'Galego')
# ('Gaeilge', 'Galego', '贛語')
# ('Galego', '贛語', 'ગુજરાતી')
# ('贛語', 'ગુજરાતી', '客家語/Hak-kâ-ngî')
# ('ગુજરાતી', '客家語/Hak-kâ-ngî', '한국어')
# ('客家語/Hak-kâ-ngî', '한국어', 'Հայերեն')
# ('한국어', 'Հայերեն', 'हिन्दी')
# ('Հայերեն', 'हिन्दी', 'Hornjoserbsce')
# ('हिन्दी', 'Hornjoserbsce', 'Hrvatski')
# ('Hornjoserbsce', 'Hrvatski', 'Bahasa')
# ('Hrvatski', 'Bahasa', 'Hulontalo')
# ('Bahasa', 'Hulontalo', 'Ido')
# ('Hulontalo', 'Ido', 'Bahasa')
# ('Ido', 'Bahasa', 'Indonesia')
# ('Bahasa', 'Indonesia', 'ᐃᓄᒃᑎᑐᑦ/inuktitut')
# ('Indonesia', 'ᐃᓄᒃᑎᑐᑦ/inuktitut', 'Íslenska')
# ('ᐃᓄᒃᑎᑐᑦ/inuktitut', 'Íslenska', 'Italiano')
# ('Íslenska', 'Italiano', 'עברית')
# ('Italiano', 'עברית', 'Jawa')
# ('עברית', 'Jawa', 'Kabɩyɛ')
# ('Jawa', 'Kabɩyɛ', 'ಕನ್ನಡ')
# ('Kabɩyɛ', 'ಕನ್ನಡ', 'ქართული')
# ('ಕನ್ನಡ', 'ქართული', 'Қазақша')
# ('ქართული', 'Қазақша', 'Kirundi')
# ('Қазақша', 'Kirundi', 'Kreyòl')
# ('Kirundi', 'Kreyòl', 'ayisyen')
# ('Kreyòl', 'ayisyen', 'Kurdî')
# ('ayisyen', 'Kurdî', 'Кыргызча')
# ('Kurdî', 'Кыргызча', 'ລາວ')
# ('Кыргызча', 'ລາວ', 'لۊری')
# ('ລາວ', 'لۊری', 'شومالی')
# ('لۊری', 'شومالی', 'Latina')
# ('شومالی', 'Latina', 'Latviešu')
# ('Latina', 'Latviešu', 'Lietuvių')
# ('Latviešu', 'Lietuvių', 'Magyar')
# ('Lietuvių', 'Magyar', 'मैथिली')
# ('Magyar', 'मैथिली', 'Македонски')
# ('मैथिली', 'Македонски', 'Malagasy')
# ('Македонски', 'Malagasy', 'മലയാളം')
# ('Malagasy', 'മലയാളം', 'मराठी')
# ('മലയാളം', 'मराठी', 'მარგალური')
# ('मराठी', 'მარგალური', 'مصرى')
# ('მარგალური', 'مصرى', 'مازِرونی')
# ('مصرى', 'مازِرونی', 'Bahasa')
# ('مازِرونی', 'Bahasa', 'Melayu')
# ('Bahasa', 'Melayu', 'Mìng-dĕ̤ng-ngṳ̄')
# ('Melayu', 'Mìng-dĕ̤ng-ngṳ̄', 'Монгол')
# ('Mìng-dĕ̤ng-ngṳ̄', 'Монгол', 'မြန်မာဘာသာ')
# ('Монгол', 'မြန်မာဘာသာ', 'Nāhuatl')
# ('မြန်မာဘာသာ', 'Nāhuatl', 'Nederlands')
# ('Nāhuatl', 'Nederlands', 'नेपाली')
# ('Nederlands', 'नेपाली', '日本語')
# ('नेपाली', '日本語', 'Norsk')
# ('日本語', 'Norsk', 'Norsk')
# ('Norsk', 'Norsk', 'nynorsk')
# ('Norsk', 'nynorsk', 'Occitan')
# ('nynorsk', 'Occitan', 'ଓଡ଼ିଆ')
# ('Occitan', 'ଓଡ଼ିଆ', 'Oʻzbekcha/ўзбекча')
# ('ଓଡ଼ିଆ', 'Oʻzbekcha/ўзбекча', 'ਪੰਜਾਬੀ')
# ('Oʻzbekcha/ўзбекча', 'ਪੰਜਾਬੀ', 'پنجابی')
# ('ਪੰਜਾਬੀ', 'پنجابی', 'پښتو')
# ('پنجابی', 'پښتو', 'ភាសាខ្មែរ')
# ('پښتو', 'ភាសាខ្មែរ', 'Piemontèis')
# ('ភាសាខ្មែរ', 'Piemontèis', 'Plattdüütsch')
# ('Piemontèis', 'Plattdüütsch', 'Polski')
# ('Plattdüütsch', 'Polski', 'Português')
# ('Polski', 'Português', 'Qaraqalpaqsha')
# ('Português', 'Qaraqalpaqsha', 'Română')
# ('Qaraqalpaqsha', 'Română', 'Runa')
# ('Română', 'Runa', 'Simi')
# ('Runa', 'Simi', 'Русский')
# ('Simi', 'Русский', 'Саха')
# ('Русский', 'Саха', 'тыла')
# ('Саха', 'тыла', 'ᱥᱟᱱᱛᱟᱲᱤ')
# ('тыла', 'ᱥᱟᱱᱛᱟᱲᱤ', 'Scots')
# ('ᱥᱟᱱᱛᱟᱲᱤ', 'Scots', 'Shqip')
# ('Scots', 'Shqip', 'Sicilianu')
# ('Shqip', 'Sicilianu', 'සිංහල')
# ('Sicilianu', 'සිංහල', 'Simple')
# ('සිංහල', 'Simple', 'English')
# ('Simple', 'English', 'سنڌي')
# ('English', 'سنڌي', 'Slovenčina')
# ('سنڌي', 'Slovenčina', 'Slovenščina')
# ('Slovenčina', 'Slovenščina', 'Soomaaliga')
# ('Slovenščina', 'Soomaaliga', 'کوردی')
# ('Soomaaliga', 'کوردی', 'Српски')
# ('کوردی', 'Српски', '/')
# ('Српски', '/', 'srpski')
# ('/', 'srpski', 'Srpskohrvatski')
# ('srpski', 'Srpskohrvatski', '/')
# ('Srpskohrvatski', '/', 'српскохрватски')
# ('/', 'српскохрватски', 'Basa')
# ('српскохрватски', 'Basa', 'Sunda')
# ('Basa', 'Sunda', 'Suomi')
# ('Sunda', 'Suomi', 'Svenska')
# ('Suomi', 'Svenska', 'Tagalog')
# ('Svenska', 'Tagalog', 'தமிழ்')
# ('Tagalog', 'தமிழ்', 'Татарча/tatarça')
# ('தமிழ்', 'Татарча/tatarça', 'తెలుగు')
# ('Татарча/tatarça', 'తెలుగు', 'Tetun')
# ('తెలుగు', 'Tetun', 'ไทย')
# ('Tetun', 'ไทย', 'Тоҷикӣ')
# ('ไทย', 'Тоҷикӣ', 'ತುಳು')
# ('Тоҷикӣ', 'ತುಳು', 'Türkçe')
# ('ತುಳು', 'Türkçe', 'Türkmençe')
# ('Türkçe', 'Türkmençe', 'Thuɔŋjäŋ')
# ('Türkmençe', 'Thuɔŋjäŋ', 'Українська')
# ('Thuɔŋjäŋ', 'Українська', 'اردو')
# ('Українська', 'اردو', 'ئۇيغۇرچە')
# ('اردو', 'ئۇيغۇرچە', '/')
# ('ئۇيغۇرچە', '/', 'Uyghurche')
# ('/', 'Uyghurche', 'Vèneto')
# ('Uyghurche', 'Vèneto', 'Tiếng')
# ('Vèneto', 'Tiếng', 'Việt')
# ('Tiếng', 'Việt', 'Walon')
# ('Việt', 'Walon', '文言')
# ('Walon', '文言', 'West-Vlams')
# ('文言', 'West-Vlams', 'Winaray')
# ('West-Vlams', 'Winaray', '吴语')
# ('Winaray', '吴语', 'ייִדיש')
# ('吴语', 'ייִדיש', 'Yorùbá')
# ('ייִדיש', 'Yorùbá', '粵語')
# ('Yorùbá', '粵語', 'Zazaki')
# ('粵語', 'Zazaki', 'Zeêuws')
# ('Zazaki', 'Zeêuws', 'Žemaitėška')
# ('Zeêuws', 'Žemaitėška', '中文')
# ('Žemaitėška', '中文', 'Edit')
# ('中文', 'Edit', 'links')
# ('Edit', 'links', 'Edit')
# ('links', 'Edit', 'links')
# ('Edit', 'links', 'This')
# ('links', 'This', 'page')
# ('This', 'page', 'was')
# ('page', 'was', 'last')
# ('was', 'last', 'edited')
# ('last', 'edited', 'on')
# ('edited', 'on', '16')
# ('on', '16', 'June')
# ('16', 'June', '2019,')
# ('June', '2019,', 'at')
# ('2019,', 'at', '18:31')
# ('at', '18:31', '(UTC).')
# ('18:31', '(UTC).', 'Text')
# ('(UTC).', 'Text', 'is')
# ('Text', 'is', 'available')
# ('is', 'available', 'under')
# ('available', 'under', 'the')
# ('under', 'the', 'Creative')
# ('the', 'Creative', 'Commons')
# ('Creative', 'Commons', 'Attribution-ShareAlike')
# ('Commons', 'Attribution-ShareAlike', 'License;')
# ('Attribution-ShareAlike', 'License;', 'additional')
# ('License;', 'additional', 'terms')
# ('additional', 'terms', 'may')
# ('terms', 'may', 'apply.')
# ('may', 'apply.', 'By')
# ('apply.', 'By', 'using')
# ('By', 'using', 'this')
# ('using', 'this', 'site,')
# ('this', 'site,', 'you')
# ('site,', 'you', 'agree')
# ('you', 'agree', 'to')
# ('agree', 'to', 'the')
# ('to', 'the', 'Terms')
# ('the', 'Terms', 'of')
# ('Terms', 'of', 'Use')
# ('of', 'Use', 'and')
# ('Use', 'and', 'Privacy')
# ('and', 'Privacy', 'Policy.')
# ('Privacy', 'Policy.', 'Wikipedia®')
# ('Policy.', 'Wikipedia®', 'is')
# ('Wikipedia®', 'is', 'a')
# ('is', 'a', 'registered')
# ('a', 'registered', 'trademark')
# ('registered', 'trademark', 'of')
# ('trademark', 'of', 'the')
# ('of', 'the', 'Wikimedia')
# ('the', 'Wikimedia', 'Foundation,')
# ('Wikimedia', 'Foundation,', 'Inc.,')
# ('Foundation,', 'Inc.,', 'a')
# ('Inc.,', 'a', 'non-profit')
# ('a', 'non-profit', 'organization.')
# ('non-profit', 'organization.', '(UTC)')
# ('organization.', '(UTC)', 'Creative')
# ('(UTC)', 'Creative', 'Commons')
# ('Creative', 'Commons', 'Attribution-ShareAlike')
# ('Commons', 'Attribution-ShareAlike', 'License')
# ('Attribution-ShareAlike', 'License', 'Terms')
# ('License', 'Terms', 'of')
# ('Terms', 'of', 'Use')
# ('of', 'Use', 'Privacy')
# ('Use', 'Privacy', 'Policy')
# ('Privacy', 'Policy', 'Wikimedia')
# ('Policy', 'Wikimedia', 'Foundation,')
# ('Wikimedia', 'Foundation,', 'Inc.')
# ('Foundation,', 'Inc.', 'Privacy')
# ('Inc.', 'Privacy', 'policy')
# ('Privacy', 'policy', 'About')
# ('policy', 'About', 'Wikipedia')
# ('About', 'Wikipedia', 'Disclaimers')
# ('Wikipedia', 'Disclaimers', 'Contact')
# ('Disclaimers', 'Contact', 'Wikipedia')
# ('Contact', 'Wikipedia', 'Developers')
# ('Wikipedia', 'Developers', 'Cookie')
# ('Developers', 'Cookie', 'statement')
# ('Cookie', 'statement', 'Mobile')
# ('statement', 'Mobile', 'view')
# ('Mobile', 'view', 'Privacy')
# ('view', 'Privacy', 'policy')
# ('Privacy', 'policy', 'About')
# ('policy', 'About', 'Wikipedia')
# ('About', 'Wikipedia', 'Disclaimers')
# ('Wikipedia', 'Disclaimers', 'Contact')
# ('Disclaimers', 'Contact', 'Wikipedia')
# ('Contact', 'Wikipedia', 'Developers')
# ('Wikipedia', 'Developers', 'Cookie')
# ('Developers', 'Cookie', 'statement')
# ('Cookie', 'statement', 'Mobile')
# ('statement', 'Mobile', 'view')

# %%
from nltk import wordpunct_tokenize, pos_tag, ne_chunk
print(ne_chunk(pos_tag(wordpunct_tokenize(data))))
# Out:
# (S
#   (PERSON Google/NNP)
#   (ORGANIZATION Jump/NNP)
#   to/TO
#   navigation/VB
#   (PERSON Jump/NNP)
#   to/TO
#   search/VB
#   (PERSON Google/NNP Search/NNP Google/NNP)
#   (/(
#   disambiguation/NN
#   )/)
#   (PERSON Googol/NNP)
#   [/NNP
#   update/JJ
#   ]/NNP
#   Googleplex/NNP
#   Type/NNP
#   Subsidiary/NNP
#   InternetCloud/NNP
#   computingComputer/NN
#   softwareComputer/NN
#   (ORGANIZATION hardwareArtificial/JJ)
#   (ORGANIZATION intelligenceAdvertising/NN)
#   Internet/NNP
#   Cloud/NNP
#   computing/VBG
#   (ORGANIZATION Computer/NNP)
#   software/NN
#   (ORGANIZATION Computer/NNP)
#   hardware/NN
#   Artificial/NNP
#   intelligence/NN
#   Advertising/NNP
#   ;/:
#   20/CD
#   years/NNS
#   ago/RB
#   (/(
#   1998/CD
#   -/:
#   09/CD
#   -/:
#   04/CD
#   )/)
#   1998/CD
#   -/:
#   09/CD
#   -/:
#   04/CD
#   (PERSON Menlo/NNP Park/NNP Larry/NNP)
#   (ORGANIZATION
#     PageSergey/NNP
#     Brin/NNP
#     Larry/NNP
#     Page/NNP
#     Sergey/NNP
#     Brin/NNP
#     Mountain/NNP
#     View/NNP)
#   ,/,
#   (GPE California/NNP)
#   Sundar/NNP
#   (GPE Pichai/NNP)
#   (/(
#   (ORGANIZATION CEO/NNP)
#   )/)
#   (PERSON Ruth/NNP Porat/NNP)
#   (/(
#   (ORGANIZATION CFO/NNP)
#   )/)
#   (ORGANIZATION Sundar/NNP Pichai/NNP)
#   CEO/NNP
#   Ruth/NNP
#   Porat/NNP
#   CFO/NNP
#   List/NNP
#   of/IN
#   (GPE Google/NNP)
#   products/NNS
#   [/NNP
#   update/NN
#   ]/NNP
#   Parent/NNP
#   Alphabet/NNP
#   Inc/NNP
#   ./.
#   Subsidiaries/NNS
#   List/NNP
#   of/IN
#   subsidiaries/NNS
#   google/VBP
#   ./.
#   com/NN
#   google/NN
#   ./.
#   com/NN
#   [/VBD
#   1/CD
#   ]/NNP
#   [/VBD
#   2/CD
#   ]/NNP
#   [/VBD
#   3/CD
#   ]/NNP
#   [/VBD
#   4/CD
#   ]/NNP
#   Google/NNP
#   LLC/NNP
#   [/VBD
#   5/CD
#   ]/NN
#   is/VBZ
#   an/DT
#   (GPE American/JJ)
#   multinational/NN
#   technology/NN
#   company/NN
#   that/WDT
#   specializes/VBZ
#   in/IN
#   (GPE Internet/NNP)
#   -/:
#   related/JJ
#   services/NNS
#   and/CC
#   products/NNS
#   ,/,
#   which/WDT
#   include/VBP
#   online/JJ
#   advertising/NN
#   technologies/NNS
#   ,/,
#   search/NN
#   engine/NN
#   ,/,
#   cloud/NN
#   computing/NN
#   ,/,
#   software/NN
#   ,/,
#   and/CC
#   hardware/NN
#   ./.
#   It/PRP
#   is/VBZ
#   considered/VBN
#   one/CD
#   of/IN
#   the/DT
#   Big/NNP
#   Four/NNP
#   technology/NN
#   companies/NNS
#   ,/,
#   alongside/RB
#   (PERSON Amazon/NNP)
#   ,/,
#   (PERSON Apple/NNP)
#   and/CC
#   (PERSON Facebook/NNP)
#   .[/NNP
#   6/CD
#   ][/VBD
#   7/CD
#   ]/NNP
#   [/VBD
#   5/CD
#   ]/NNP
#   online/JJ
#   advertising/NN
#   technologies/NNS
#   search/VBP
#   engine/NN
#   cloud/NN
#   computing/VBG
#   Big/NNP
#   Four/CD
#   (ORGANIZATION Amazon/NNP Apple/NNP Facebook/NNP)
#   [/NNP
#   6/CD
#   ]/NNP
#   [/VBD
#   7/CD
#   ]/NNP
#   (PERSON Google/NNP)
#   was/VBD
#   founded/VBN
#   in/IN
#   1998/CD
#   by/IN
#   (PERSON Larry/NNP Page/NNP)
#   and/CC
#   (PERSON Sergey/NNP Brin/NNP)
#   while/IN
#   they/PRP
#   were/VBD
#   Ph/NNP
#   ./.
#   D/NNP
#   ./.
#   students/NNS
#   at/IN
#   (ORGANIZATION Stanford/NNP University/NNP)
#   in/IN
#   (GPE California/NNP)
#   ./.
#   Together/RB
#   they/PRP
#   own/VBP
#   about/IN
#   14/CD
#   percent/NN
#   of/IN
#   its/PRP$
#   shares/NNS
#   and/CC
#   control/VB
#   56/CD
#   percent/NN
#   of/IN
#   the/DT
#   stockholder/NN
#   voting/NN
#   power/NN
#   through/IN
#   supervoting/VBG
#   stock/NN
#   ./.
#   They/PRP
#   incorporated/VBD
#   (PERSON Google/NNP)
#   as/IN
#   a/DT
#   privately/RB
#   held/VBN
#   company/NN
#   on/IN
#   September/NNP
#   4/CD
#   ,/,
#   1998/CD
#   ./.
#   An/DT
#   initial/JJ
#   public/JJ
#   offering/NN
#   (/(
#   (ORGANIZATION IPO/NNP)
#   )/)
#   took/VBD
#   place/NN
#   on/IN
#   August/NNP
#   19/CD
#   ,/,
#   2004/CD
#   ,/,
#   and/CC
#   (PERSON Google/NNP)
#   moved/VBD
#   to/TO
#   its/PRP$
#   headquarters/NNS
#   in/IN
#   (GPE Mountain/NNP View/NNP)
#   ,/,
#   (GPE California/NNP)
#   ,/,
#   nicknamed/VBD
#   the/DT
#   (ORGANIZATION Googleplex/NNP)
#   ./.
#   In/IN
#   August/NNP
#   2015/CD
#   ,/,
#   (PERSON Google/NNP)
#   announced/VBD
#   plans/NNS
#   to/TO
#   reorganize/VB
#   its/PRP$
#   various/JJ
#   interests/NNS
#   as/IN
#   a/DT
#   conglomerate/NN
#   called/VBN
#   (ORGANIZATION Alphabet/NNP Inc/NNP)
#   ./.
#   (PERSON Google/NNP)
#   is/VBZ
#   (PERSON Alphabet/NNP)
#   '/POS
#   s/JJ
#   leading/VBG
#   subsidiary/NN
#   and/CC
#   will/MD
#   continue/VB
#   to/TO
#   be/VB
#   the/DT
#   umbrella/JJ
#   company/NN
#   for/IN
#   (ORGANIZATION Alphabet/NNP)
#   '/POS
#   s/JJ
#   Internet/NNP
#   interests/NNS
#   ./.
#   (PERSON Sundar/NNP Pichai/NNP)
#   was/VBD
#   appointed/VBN
#   (ORGANIZATION CEO/NNP)
#   of/IN
#   (GPE Google/NNP)
#   ,/,
#   replacing/VBG
#   (PERSON Larry/NNP Page/NNP)
#   who/WP
#   became/VBD
#   the/DT
#   (ORGANIZATION CEO/NN of/IN Alphabet/NNP)
#   ./.
#   (PERSON
#     Larry/NNP
#     Page/NNP
#     Sergey/NNP
#     Brin/NNP
#     Stanford/NNP
#     University/NNP
#     California/NNP)
#   supervoting/VBG
#   (PERSON Googleplex/NNP Alphabet/NNP Inc/NNP)
#   ./.
#   (PERSON Sundar/NNP)
#   Pichai/VBD
#   The/DT
#   company/NN
#   '/POS
#   s/NN
#   rapid/JJ
#   growth/NN
#   since/IN
#   incorporation/NN
#   has/VBZ
#   triggered/VBN
#   a/DT
#   chain/NN
#   of/IN
#   products/NNS
#   ,/,
#   acquisitions/NNS
#   ,/,
#   and/CC
#   partnerships/NNS
#   beyond/IN
#   (PERSON Google/NNP)
#   '/POS
#   s/NN
#   core/NN
#   search/NN
#   engine/NN
#   (/(
#   (ORGANIZATION Google/NNP Search/NNP)
#   )./VBD
#   It/PRP
#   offers/VBZ
#   services/NNS
#   designed/VBN
#   for/IN
#   work/NN
#   and/CC
#   productivity/NN
#   (/(
#   (ORGANIZATION Google/NNP Docs/NNP)
#   ,/,
#   (PERSON Google/NNP Sheets/NNP)
#   ,/,
#   and/CC
#   (PERSON Google/NNP Slides/NNP)
#   ),/NNP
#   email/NN
#   (/(
#   (PERSON Gmail/NNP)
#   //NNP
#   Inbox/NNP
#   ),/NNP
#   scheduling/NN
#   and/CC
#   time/NN
#   management/NN
#   (/(
#   (ORGANIZATION Google/NNP Calendar/NNP)
#   ),/NNP
#   cloud/NN
#   storage/NN
#   (/(
#   (ORGANIZATION Google/NNP Drive/NNP)
#   ),/NNP
#   instant/JJ
#   messaging/NN
#   and/CC
#   video/NN
#   chat/NN
#   (/(
#   (ORGANIZATION Google/NNP Allo/NNP)
#   ,/,
#   (PERSON Duo/NNP)
#   ,/,
#   (PERSON Hangouts/NNP)
#   ),/NNP
#   language/NN
#   translation/NN
#   (/(
#   (ORGANIZATION Google/NNP)
#   Translate/NNP
#   ),/NNP
#   mapping/NN
#   and/CC
#   navigation/NN
#   (/(
#   (ORGANIZATION Google/NNP Maps/NNP)
#   ,/,
#   (PERSON Waze/NNP)
#   ,/,
#   (PERSON Google/NNP Earth/NNP)
#   ,/,
#   (PERSON Street/NNP View/NNP)
#   ),/NNP
#   video/NN
#   sharing/NN
#   (/(
#   (ORGANIZATION YouTube/NNP)
#   ),/NNP
#   note/VBP
#   -/:
#   taking/NN
#   (/(
#   (ORGANIZATION Google/NNP Keep/NNP)
#   ),/NNP
#   and/CC
#   photo/NN
#   organizing/NN
#   and/CC
#   editing/NN
#   (/(
#   (ORGANIZATION Google/NNP Photos/NNP)
#   )./VBD
#   The/DT
#   company/NN
#   leads/VBZ
#   the/DT
#   development/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Android/NNP)
#   mobile/NN
#   operating/VBG
#   system/NN
#   ,/,
#   the/DT
#   (ORGANIZATION Google/NNP Chrome/NNP)
#   web/NN
#   browser/NN
#   ,/,
#   and/CC
#   (PERSON Chrome/NNP OS/NNP)
#   ,/,
#   a/DT
#   lightweight/NN
#   operating/VBG
#   system/NN
#   based/VBN
#   on/IN
#   the/DT
#   (ORGANIZATION Chrome/NNP)
#   browser/NN
#   ./.
#   (PERSON Google/NNP)
#   has/VBZ
#   moved/VBN
#   increasingly/RB
#   into/IN
#   hardware/NN
#   ;/:
#   from/IN
#   2010/CD
#   to/TO
#   2015/CD
#   ,/,
#   it/PRP
#   partnered/VBD
#   with/IN
#   major/JJ
#   electronics/NNS
#   manufacturers/NNS
#   in/IN
#   the/DT
#   production/NN
#   of/IN
#   its/PRP$
#   Nexus/NNP
#   devices/NNS
#   ,/,
#   and/CC
#   it/PRP
#   released/VBD
#   multiple/JJ
#   hardware/NN
#   products/NNS
#   in/IN
#   October/NNP
#   2016/CD
#   ,/,
#   including/VBG
#   the/DT
#   (ORGANIZATION Google/NNP Pixel/NNP)
#   smartphone/NN
#   ,/,
#   (PERSON Google/NNP Home/NNP)
#   smart/NN
#   speaker/NN
#   ,/,
#   (PERSON Google/NNP Wifi/NNP)
#   mesh/JJ
#   wireless/NN
#   router/NN
#   ,/,
#   and/CC
#   (PERSON Google/NNP Daydream/NNP)
#   virtual/JJ
#   reality/NN
#   headset/NN
#   ./.
#   (PERSON Google/NNP)
#   has/VBZ
#   also/RB
#   experimented/VBN
#   with/IN
#   becoming/VBG
#   an/DT
#   Internet/NNP
#   carrier/NN
#   (/(
#   (ORGANIZATION Google/NNP Fiber/NNP)
#   ,/,
#   (PERSON Google/NNP Fi/NNP)
#   ,/,
#   and/CC
#   (PERSON Google/NNP Station/NNP)
#   ).[/VBD
#   8/CD
#   ]/NNP
#   Google/NNP
#   Search/NNP
#   Google/NNP
#   Docs/NNP
#   Google/NNP
#   Sheets/NNP
#   Google/NNP
#   Slides/NNP
#   Gmail/NNP
#   Inbox/NNP
#   Google/NNP
#   (PERSON
#     Calendar/NNP
#     Google/NNP
#     Drive/NNP
#     Google/NNP
#     Allo/NNP
#     Duo/NNP
#     Hangouts/NNP
#     Google/NNP
#     Translate/NNP
#     Google/NNP
#     Maps/NNP
#     Waze/NNP
#     Google/NNP
#     Earth/NNP
#     Street/NNP
#     View/NNP)
#   YouTube/NNP
#   Google/NNP
#   Keep/NNP
#   Google/NNP
#   (PERSON
#     Photos/NNP
#     Android/NNP
#     Google/NNP
#     Chrome/NNP
#     Chrome/NNP
#     OS/NNP
#     Nexus/NNP
#     Google/NNP
#     Pixel/NNP
#     Google/NNP
#     Home/NNP
#     Google/NNP
#     Wifi/NNP
#     Google/NNP
#     Daydream/NNP
#     Google/NNP)
#   Fiber/NNP
#   Google/NNP
#   Fi/NNP
#   Google/NNP
#   Station/NNP
#   [/VBD
#   8/CD
#   ]/JJ
#   Google/NNP
#   ./.
#   com/NN
#   is/VBZ
#   the/DT
#   most/RBS
#   visited/JJ
#   website/NN
#   in/IN
#   the/DT
#   world/NN
#   .[/VBZ
#   9/CD
#   ]/JJ
#   Several/NNP
#   other/JJ
#   Google/NNP
#   services/NNS
#   also/RB
#   figure/VBP
#   in/IN
#   the/DT
#   top/JJ
#   100/CD
#   most/JJS
#   visited/JJ
#   websites/NNS
#   ,/,
#   including/VBG
#   (ORGANIZATION YouTube/NNP)
#   and/CC
#   (PERSON Blogger/NNP)
#   ./.
#   (PERSON Google/NNP)
#   was/VBD
#   the/DT
#   most/RBS
#   valuable/JJ
#   brand/NN
#   in/IN
#   the/DT
#   world/NN
#   as/IN
#   of/IN
#   2017/CD
#   ,[/JJ
#   update/JJ
#   ][/NN
#   10/CD
#   ]/NN
#   but/CC
#   has/VBZ
#   received/VBN
#   significant/JJ
#   criticism/NN
#   involving/VBG
#   issues/NNS
#   such/JJ
#   as/IN
#   privacy/NN
#   concerns/NNS
#   ,/,
#   tax/NN
#   avoidance/NN
#   ,/,
#   antitrust/JJ
#   ,/,
#   censorship/NN
#   ,/,
#   and/CC
#   search/NN
#   neutrality/NN
#   ./.
#   (PERSON Google/NNP)
#   '/POS
#   s/JJ
#   mission/NN
#   statement/NN
#   is/VBZ
#   "/JJ
#   to/TO
#   organize/VB
#   the/DT
#   world/NN
#   '/POS
#   s/JJ
#   information/NN
#   and/CC
#   make/VB
#   it/PRP
#   universally/RB
#   accessible/JJ
#   and/CC
#   useful/JJ
#   "./FW
#   The/DT
#   company/NN
#   '/POS
#   s/JJ
#   unofficial/JJ
#   slogan/NN
#   "/NNP
#   (PERSON Don/NNP)
#   '/POS
#   t/NN
#   be/VB
#   evil/JJ
#   "/NN
#   was/VBD
#   removed/VBN
#   from/IN
#   the/DT
#   company/NN
#   '/POS
#   s/JJ
#   code/NN
#   of/IN
#   conduct/NN
#   around/IN
#   May/NNP
#   2018/CD
#   ,/,
#   but/CC
#   reinstated/VBN
#   by/IN
#   July/NNP
#   31/CD
#   ,/,
#   2018/CD
#   .[/VBD
#   11/CD
#   ][/JJ
#   12/CD
#   ]/JJ
#   [/$
#   9/CD
#   ]/NNP
#   YouTube/NNP
#   (PERSON Blogger/NNP)
#   [/NNP
#   update/JJ
#   ]/NNP
#   [/NNP
#   10/CD
#   ]/NNP
#   criticism/NN
#   privacy/NN
#   concerns/NNS
#   censorship/JJ
#   mission/NN
#   statement/NN
#   [/VBD
#   11/CD
#   ]/NNP
#   [/VBD
#   12/CD
#   ]/JJ
#   Contents/NNS
#   1/CD
#   History/NNP
#   1/CD
#   ./.
#   1/CD
#   Early/JJ
#   years/NNS
#   1/CD
#   ./.
#   2/CD
#   Growth/NNP
#   1/CD
#   ./.
#   3/CD
#   Initial/JJ
#   public/JJ
#   offering/NN
#   1/CD
#   ./.
#   4/CD
#   2012/CD
#   onward/RB
#   2/CD
#   Products/NNPS
#   and/CC
#   services/NNS
#   2/CD
#   ./.
#   1/CD
#   Search/NNP
#   engine/NN
#   2/CD
#   ./.
#   2/CD
#   Advertising/NN
#   2/CD
#   ./.
#   3/CD
#   Consumer/NNP
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   ./.
#   1/CD
#   Web/NNP
#   -/:
#   based/VBN
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   ./.
#   2/CD
#   Software/NNP
#   2/CD
#   ./.
#   3/CD
#   ./.
#   3/CD
#   Hardware/NNP
#   2/CD
#   ./.
#   4/CD
#   Enterprise/NNP
#   services/NNS
#   2/CD
#   ./.
#   5/CD
#   Internet/NNP
#   services/NNS
#   2/CD
#   ./.
#   6/CD
#   Other/JJ
#   products/NNS
#   3/CD
#   (ORGANIZATION Corporate/NNP)
#   affairs/NNS
#   3/CD
#   ./.
#   1/CD
#   Finance/NN
#   3/CD
#   ./.
#   2/CD
#   (ORGANIZATION Corporate/NNP)
#   identity/NN
#   3/CD
#   ./.
#   3/CD
#   Workplace/JJ
#   culture/NN
#   3/CD
#   ./.
#   4/CD
#   Office/NNP
#   locations/NNS
#   3/CD
#   ./.
#   5/CD
#   Infrastructure/NN
#   3/CD
#   ./.
#   6/CD
#   Environment/JJ
#   3/CD
#   ./.
#   7/CD
#   Philanthropy/NNP
#   4/CD
#   Criticism/NNP
#   and/CC
#   controversy/NN
#   4/CD
#   ./.
#   1/CD
#   Litigation/NN
#   5/CD
#   See/NNP
#   also/RB
#   6/CD
#   References/NNS
#   7/CD
#   Further/NNP
#   reading/VBG
#   8/CD
#   External/JJ
#   links/NNS
#   1/CD
#   History/JJ
#   1/CD
#   History/NN
#   1/CD
#   ./.
#   1/CD
#   Early/JJ
#   years/NNS
#   1/CD
#   ./.
#   2/CD
#   Growth/NNP
#   1/CD
#   ./.
#   3/CD
#   Initial/JJ
#   public/JJ
#   offering/NN
#   1/CD
#   ./.
#   4/CD
#   2012/CD
#   onward/NN
#   1/CD
#   ./.
#   1/CD
#   Early/JJ
#   years/NNS
#   1/CD
#   ./.
#   1/CD
#   Early/JJ
#   years/NNS
#   1/CD
#   ./.
#   2/CD
#   Growth/NNP
#   1/CD
#   ./.
#   2/CD
#   Growth/NNP
#   1/CD
#   ./.
#   3/CD
#   Initial/JJ
#   public/JJ
#   offering/NN
#   1/CD
#   ./.
#   3/CD
#   Initial/JJ
#   public/JJ
#   offering/NN
#   1/CD
#   ./.
#   4/CD
#   2012/CD
#   onward/NN
#   1/CD
#   ./.
#   4/CD
#   2012/CD
#   onward/RB
#   2/CD
#   Products/NNPS
#   and/CC
#   services/NNS
#   2/CD
#   Products/NNPS
#   and/CC
#   services/NNS
#   2/CD
#   ./.
#   1/CD
#   Search/NNP
#   engine/NN
#   2/CD
#   ./.
#   2/CD
#   Advertising/NN
#   2/CD
#   ./.
#   3/CD
#   Consumer/NNP
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   ./.
#   1/CD
#   Web/NNP
#   -/:
#   based/VBN
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   ./.
#   2/CD
#   Software/NNP
#   2/CD
#   ./.
#   3/CD
#   ./.
#   3/CD
#   Hardware/NNP
#   2/CD
#   ./.
#   4/CD
#   Enterprise/NNP
#   services/NNS
#   2/CD
#   ./.
#   5/CD
#   Internet/NNP
#   services/NNS
#   2/CD
#   ./.
#   6/CD
#   Other/JJ
#   products/NNS
#   2/CD
#   ./.
#   1/CD
#   Search/NNP
#   engine/NN
#   2/CD
#   ./.
#   1/CD
#   Search/NNP
#   engine/NN
#   2/CD
#   ./.
#   2/CD
#   Advertising/NN
#   2/CD
#   ./.
#   2/CD
#   Advertising/NN
#   2/CD
#   ./.
#   3/CD
#   Consumer/NNP
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   Consumer/NNP
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   ./.
#   1/CD
#   Web/NNP
#   -/:
#   based/VBN
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   ./.
#   2/CD
#   Software/NNP
#   2/CD
#   ./.
#   3/CD
#   ./.
#   3/CD
#   Hardware/NNP
#   2/CD
#   ./.
#   3/CD
#   ./.
#   1/CD
#   Web/NNP
#   -/:
#   based/VBN
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   ./.
#   1/CD
#   Web/NNP
#   -/:
#   based/VBN
#   services/NNS
#   2/CD
#   ./.
#   3/CD
#   ./.
#   2/CD
#   Software/NNP
#   2/CD
#   ./.
#   3/CD
#   ./.
#   2/CD
#   Software/NNP
#   2/CD
#   ./.
#   3/CD
#   ./.
#   3/CD
#   Hardware/NNP
#   2/CD
#   ./.
#   3/CD
#   ./.
#   3/CD
#   Hardware/NNP
#   2/CD
#   ./.
#   4/CD
#   Enterprise/NNP
#   services/NNS
#   2/CD
#   ./.
#   4/CD
#   Enterprise/NNP
#   services/NNS
#   2/CD
#   ./.
#   5/CD
#   Internet/NNP
#   services/NNS
#   2/CD
#   ./.
#   5/CD
#   Internet/NNP
#   services/NNS
#   2/CD
#   ./.
#   6/CD
#   Other/JJ
#   products/NNS
#   2/CD
#   ./.
#   6/CD
#   Other/JJ
#   products/NNS
#   3/CD
#   (ORGANIZATION Corporate/NNP)
#   affairs/NNS
#   3/CD
#   (ORGANIZATION Corporate/NNP)
#   affairs/NNS
#   3/CD
#   ./.
#   1/CD
#   Finance/NN
#   3/CD
#   ./.
#   2/CD
#   (ORGANIZATION Corporate/NNP)
#   identity/NN
#   3/CD
#   ./.
#   3/CD
#   Workplace/JJ
#   culture/NN
#   3/CD
#   ./.
#   4/CD
#   Office/NNP
#   locations/NNS
#   3/CD
#   ./.
#   5/CD
#   Infrastructure/NN
#   3/CD
#   ./.
#   6/CD
#   Environment/JJ
#   3/CD
#   ./.
#   7/CD
#   Philanthropy/NNP
#   3/CD
#   ./.
#   1/CD
#   Finance/NN
#   3/CD
#   ./.
#   1/CD
#   Finance/NN
#   3/CD
#   ./.
#   2/CD
#   (ORGANIZATION Corporate/NNP)
#   identity/NN
#   3/CD
#   ./.
#   2/CD
#   (ORGANIZATION Corporate/NNP)
#   identity/NN
#   3/CD
#   ./.
#   3/CD
#   Workplace/JJ
#   culture/NN
#   3/CD
#   ./.
#   3/CD
#   Workplace/JJ
#   culture/NN
#   3/CD
#   ./.
#   4/CD
#   Office/NNP
#   locations/NNS
#   3/CD
#   ./.
#   4/CD
#   Office/NNP
#   locations/NNS
#   3/CD
#   ./.
#   5/CD
#   Infrastructure/NN
#   3/CD
#   ./.
#   5/CD
#   Infrastructure/NN
#   3/CD
#   ./.
#   6/CD
#   Environment/JJ
#   3/CD
#   ./.
#   6/CD
#   Environment/JJ
#   3/CD
#   ./.
#   7/CD
#   Philanthropy/NNP
#   3/CD
#   ./.
#   7/CD
#   Philanthropy/NNP
#   4/CD
#   Criticism/NNP
#   and/CC
#   controversy/NN
#   4/CD
#   Criticism/NN
#   and/CC
#   controversy/NN
#   4/CD
#   ./.
#   1/CD
#   Litigation/NN
#   4/CD
#   ./.
#   1/CD
#   Litigation/NN
#   4/CD
#   ./.
#   1/CD
#   Litigation/NN
#   5/CD
#   See/NNP
#   also/RB
#   5/CD
#   See/NNP
#   also/RB
#   6/CD
#   References/NNS
#   6/CD
#   References/NNS
#   7/CD
#   Further/NNP
#   reading/VBG
#   7/CD
#   Further/NNP
#   reading/VBG
#   8/CD
#   External/JJ
#   links/NNS
#   8/CD
#   External/JJ
#   links/NNS
#   (PERSON History/JJ History/NNP History/NNP)
#   of/IN
#   (PERSON Google/NNP List/NNP)
#   of/IN
#   mergers/NNS
#   and/CC
#   acquisitions/NNS
#   by/IN
#   (PERSON Alphabet/NNP Alphabet/NNP Inc/NNP)
#   ./.
#   Early/JJ
#   years/NNS
#   Early/RB
#   years/NNS
#   (PERSON Larry/NNP Page/NNP Sergey/NNP Brin/NNP Google/NNP)
#   began/VBD
#   in/IN
#   January/NNP
#   1996/CD
#   as/IN
#   a/DT
#   research/NN
#   project/NN
#   by/IN
#   (PERSON Larry/NNP Page/NNP)
#   and/CC
#   (PERSON Sergey/NNP Brin/NNP)
#   when/WRB
#   they/PRP
#   were/VBD
#   both/DT
#   (ORGANIZATION PhD/NNP)
#   students/NNS
#   at/IN
#   (ORGANIZATION Stanford/NNP University/NNP)
#   in/IN
#   (GPE Stanford/NNP)
#   ,/,
#   (GPE California/NNP)
#   .[/VBZ
#   13/CD
#   ]/NN
#   (PERSON
#     Larry/NNP
#     Page/NNP
#     Sergey/NNP
#     Brin/NNP
#     Stanford/NNP
#     University/NNP
#     Stanford/NNP)
#   ,/,
#   (GPE California/NNP)
#   [/VBZ
#   13/CD
#   ]/NN
#   While/IN
#   conventional/JJ
#   search/NN
#   engines/NNS
#   ranked/VBD
#   results/NNS
#   by/IN
#   counting/VBG
#   how/WRB
#   many/JJ
#   times/NNS
#   the/DT
#   search/NN
#   terms/NNS
#   appeared/VBD
#   on/IN
#   the/DT
#   page/NN
#   ,/,
#   the/DT
#   two/CD
#   theorized/VBD
#   about/IN
#   a/DT
#   better/JJR
#   system/NN
#   that/WDT
#   analyzed/VBD
#   the/DT
#   relationships/NNS
#   among/IN
#   websites/NNS
#   .[/VBP
#   14/CD
#   ]/NN
#   They/PRP
#   called/VBD
#   this/DT
#   algorithm/NN
#   (ORGANIZATION PageRank/NNP)
#   ;/:
#   it/PRP
#   determined/VBD
#   a/DT
#   website/NN
#   '/POS
#   s/JJ
#   relevance/NN
#   by/IN
#   the/DT
#   number/NN
#   of/IN
#   pages/NNS
#   ,/,
#   and/CC
#   the/DT
#   importance/NN
#   of/IN
#   those/DT
#   pages/NNS
#   that/WDT
#   linked/VBD
#   back/RB
#   to/TO
#   the/DT
#   original/JJ
#   site/NN
#   .[/$
#   15/CD
#   ][/$
#   16/CD
#   ]/NNP
#   (ORGANIZATION PageRank/NNP)
#   was/VBD
#   influenced/VBN
#   by/IN
#   a/DT
#   similar/JJ
#   page/NN
#   -/:
#   ranking/NN
#   and/CC
#   site/NN
#   -/:
#   scoring/NN
#   algorithm/NN
#   earlier/RBR
#   used/VBN
#   for/IN
#   (ORGANIZATION RankDex/NNP)
#   ,/,
#   developed/VBN
#   by/IN
#   (PERSON Robin/NNP Li/NNP)
#   in/IN
#   1996/CD
#   ,/,
#   with/IN
#   (PERSON Larry/NNP Page/NNP)
#   '/POS
#   s/NN
#   (ORGANIZATION PageRank/NNP)
#   patent/NN
#   including/VBG
#   a/DT
#   citation/NN
#   to/TO
#   (PERSON Li/NNP)
#   '/POS
#   s/NN
#   earlier/RBR
#   (ORGANIZATION RankDex/NNP)
#   patent/NN
#   ;/:
#   Li/NNP
#   later/RB
#   went/VBD
#   on/IN
#   to/TO
#   create/VB
#   the/DT
#   (GPE Chinese/JJ)
#   search/NN
#   engine/NN
#   (PERSON Baidu/NNP)
#   .[/VBZ
#   17/CD
#   ][/NN
#   18/CD
#   ][/NN
#   19/CD
#   ]/NNP
#   [/VBD
#   14/CD
#   ]/NNP
#   (ORGANIZATION PageRank/NNP)
#   relevance/NN
#   [/VBD
#   15/CD
#   ]/NNP
#   [/VBD
#   16/CD
#   ]/NNP
#   (ORGANIZATION RankDex/NNP Robin/NNP Li/NNP Baidu/NNP)
#   [/VBD
#   17/CD
#   ]/NNP
#   [/VBD
#   18/CD
#   ]/NNP
#   [/VBD
#   19/CD
#   ]/JJ
#   Page/NN
#   and/CC
#   (GPE Brin/NNP)
#   originally/RB
#   nicknamed/VBD
#   their/PRP$
#   new/JJ
#   search/NN
#   engine/NN
#   "/NNP
#   BackRub/NNP
#   ",/NNP
#   because/IN
#   the/DT
#   system/NN
#   checked/VBD
#   backlinks/NNS
#   to/TO
#   estimate/VB
#   the/DT
#   importance/NN
#   of/IN
#   a/DT
#   site/NN
#   .[/JJ
#   20/CD
#   ][/JJ
#   21/CD
#   ][/JJ
#   22/CD
#   ]/NNP
#   Eventually/RB
#   ,/,
#   they/PRP
#   changed/VBD
#   the/DT
#   name/NN
#   to/TO
#   (GPE Google/NNP)
#   ;/:
#   the/DT
#   name/NN
#   of/IN
#   the/DT
#   search/NN
#   engine/NN
#   originated/VBN
#   from/IN
#   a/DT
#   misspelling/NN
#   of/IN
#   the/DT
#   word/NN
#   "/NNP
#   googol/NN
#   ",[/VBD
#   23/CD
#   ][/JJ
#   24/CD
#   ]/IN
#   the/DT
#   number/NN
#   1/CD
#   followed/VBN
#   by/IN
#   100/CD
#   zeros/NNS
#   ,/,
#   which/WDT
#   was/VBD
#   picked/VBN
#   to/TO
#   signify/VB
#   that/IN
#   the/DT
#   search/NN
#   engine/NN
#   was/VBD
#   intended/VBN
#   to/TO
#   provide/VB
#   large/JJ
#   quantities/NNS
#   of/IN
#   information/NN
#   .[/FW
#   25/CD
#   ]/NNP
#   [/VBD
#   20/CD
#   ]/NNP
#   [/VBD
#   21/CD
#   ]/NNP
#   [/VBD
#   22/CD
#   ]/NNP
#   googol/NN
#   [/VBD
#   23/CD
#   ]/NNP
#   [/VBD
#   24/CD
#   ]/NNP
#   [/VBD
#   25/CD
#   ]/NNP
#   HTML/NNP
#   markup/NN
#   language/NN
#   [/VBD
#   26/CD
#   ]/IN
#   The/DT
#   domain/NN
#   name/NN
#   for/IN
#   (PERSON Google/NNP)
#   was/VBD
#   registered/VBN
#   on/IN
#   September/NNP
#   15/CD
#   ,/,
#   1997/CD
#   ,[/NN
#   27/CD
#   ]/NN
#   and/CC
#   the/DT
#   company/NN
#   was/VBD
#   incorporated/VBN
#   on/IN
#   September/NNP
#   4/CD
#   ,/,
#   1998/CD
#   ./.
#   It/PRP
#   was/VBD
#   based/VBN
#   in/IN
#   the/DT
#   garage/NN
#   of/IN
#   a/DT
#   friend/NN
#   (/(
#   (PERSON Susan/NNP Wojcicki/NNP)
#   [/VBD
#   13/CD
#   ])/NN
#   in/IN
#   (GPE Menlo/NNP Park/NNP)
#   ,/,
#   (GPE California/NNP)
#   ./.
#   (PERSON Craig/NNP Silverstein/NNP)
#   ,/,
#   a/DT
#   fellow/JJ
#   (ORGANIZATION PhD/NNP)
#   student/NN
#   at/IN
#   (ORGANIZATION Stanford/NNP)
#   ,/,
#   was/VBD
#   hired/VBN
#   as/IN
#   the/DT
#   first/JJ
#   employee/NN
#   .[/$
#   13/CD
#   ][/$
#   28/CD
#   ][/$
#   29/CD
#   ]/NNP
#   [/VBD
#   27/CD
#   ]/NNP
#   (PERSON Susan/NNP Wojcicki/NNP)
#   [/VBD
#   13/CD
#   ]/NNP
#   (PERSON Menlo/NNP Park/NNP)
#   ,/,
#   (GPE California/NNP)
#   Craig/NNP
#   (PERSON Silverstein/NNP)
#   [/VBD
#   13/CD
#   ]/NNP
#   [/VBD
#   28/CD
#   ]/NNP
#   [/VBD
#   29/CD
#   ]/NNP
#   (PERSON Google/NNP)
#   was/VBD
#   initially/RB
#   funded/VBN
#   by/IN
#   an/DT
#   August/NNP
#   1998/CD
#   contribution/NN
#   of/IN
#   $/$
#   100/CD
#   ,/,
#   000/CD
#   from/IN
#   (PERSON Andy/NNP Bechtolsheim/NNP)
#   ,/,
#   co/SYM
#   -/:
#   founder/NN
#   of/IN
#   (ORGANIZATION Sun/NNP Microsystems/NNPS)
#   ;/:
#   the/DT
#   money/NN
#   was/VBD
#   given/VBN
#   before/IN
#   (PERSON Google/NNP)
#   was/VBD
#   incorporated/VBN
#   .[/RB
#   30/CD
#   ]/JJ
#   (PERSON Google/NNP)
#   received/VBD
#   money/NN
#   from/IN
#   three/CD
#   other/JJ
#   angel/JJ
#   investors/NNS
#   in/IN
#   1998/CD
#   :/:
#   (PERSON Amazon/NNP)
#   ./.
#   com/NN
#   founder/NN
#   (PERSON Jeff/NNP Bezos/NNP)
#   ,/,
#   (ORGANIZATION Stanford/NNP University/NNP)
#   computer/NN
#   science/NN
#   professor/NN
#   (PERSON David/NNP Cheriton/NNP)
#   ,/,
#   and/CC
#   entrepreneur/NN
#   (PERSON Ram/NNP Shriram/NNP)
#   .[/VBZ
#   31/CD
#   ]/NN
#   Between/NNP
#   these/DT
#   initial/JJ
#   investors/NNS
#   ,/,
#   friends/NNS
#   ,/,
#   and/CC
#   family/NN
#   (PERSON Google/NNP)
#   raised/VBD
#   around/IN
#   1/CD
#   million/CD
#   dollars/NNS
#   ,/,
#   which/WDT
#   is/VBZ
#   what/WP
#   allowed/VBD
#   them/PRP
#   to/TO
#   open/VB
#   up/RP
#   their/PRP$
#   original/JJ
#   shop/NN
#   in/IN
#   (GPE Menlo/NNP Park/NNP)
#   ,/,
#   (GPE California/NNP)
#   [/VBZ
#   32/CD
#   ]/NN
#   (PERSON Andy/NNP Bechtolsheim/NNP Sun/NNP Microsystems/NNPS)
#   [/VBD
#   30/CD
#   ]/NNP
#   angel/JJ
#   investors/NNS
#   (PERSON Amazon/NNP)
#   ./.
#   com/NN
#   (PERSON Jeff/NNP Bezos/NNP)
#   (PERSON David/NNP Cheriton/NNP Ram/NNP Shriram/NNP)
#   [/VBZ
#   31/CD
#   ]/NN
#   (PERSON Menlo/NNP Park/NNP)
#   ,/,
#   (GPE California/NNP)
#   [/VBZ
#   32/CD
#   ]/NN
#   After/IN
#   some/DT
#   additional/JJ
#   ,/,
#   small/JJ
#   investments/NNS
#   through/IN
#   the/DT
#   end/NN
#   of/IN
#   1998/CD
#   to/TO
#   early/JJ
#   1999/CD
#   ,[/$
#   31/CD
#   ]/NNP
#   a/DT
#   new/JJ
#   $/$
#   25/CD
#   million/CD
#   round/NN
#   of/IN
#   funding/NN
#   was/VBD
#   announced/VBN
#   on/IN
#   June/NNP
#   7/CD
#   ,/,
#   1999/CD
#   ,[/NN
#   33/CD
#   ]/NN
#   with/IN
#   major/JJ
#   investors/NNS
#   including/VBG
#   the/DT
#   venture/NN
#   capital/NN
#   firms/NNS
#   (PERSON Kleiner/NNP Perkins/NNP)
#   and/CC
#   (PERSON Sequoia/NNP Capital/NNP)
#   .[/VBD
#   30/CD
#   ]/NNP
#   [/VBD
#   31/CD
#   ]/NNP
#   [/VBD
#   33/CD
#   ]/JJ
#   venture/NN
#   capital/NN
#   (PERSON Kleiner/NNP Perkins/NNP Sequoia/NNP Capital/NNP)
#   [/VBD
#   30/CD
#   ]/JJ
#   (PERSON Growth/NNP Growth/NNP)
#   In/IN
#   March/NNP
#   1999/CD
#   ,/,
#   the/DT
#   company/NN
#   moved/VBD
#   its/PRP$
#   offices/NNS
#   to/TO
#   (GPE Palo/NNP Alto/NNP)
#   ,/,
#   (GPE California/NNP)
#   ,[/VBZ
#   34/CD
#   ]/NN
#   which/WDT
#   is/VBZ
#   home/NN
#   to/TO
#   several/JJ
#   prominent/JJ
#   (PERSON Silicon/NNP Valley/NNP)
#   technology/NN
#   start/NN
#   -/:
#   ups/JJ
#   .[/JJ
#   35/CD
#   ]/IN
#   The/DT
#   next/JJ
#   year/NN
#   ,/,
#   (PERSON Google/NNP)
#   began/VBD
#   selling/VBG
#   advertisements/NNS
#   associated/VBN
#   with/IN
#   search/NN
#   keywords/NNS
#   against/IN
#   (PERSON Page/NNP)
#   and/CC
#   (PERSON Brin/NNP)
#   '/POS
#   s/JJ
#   initial/JJ
#   opposition/NN
#   toward/IN
#   an/DT
#   advertising/NN
#   -/:
#   funded/VBN
#   search/NN
#   engine/NN
#   .[/$
#   36/CD
#   ][/$
#   13/CD
#   ]/NN
#   To/TO
#   maintain/VB
#   an/DT
#   uncluttered/JJ
#   page/NN
#   design/NN
#   ,/,
#   advertisements/NNS
#   were/VBD
#   solely/RB
#   text/JJ
#   -/:
#   based/VBN
#   .[/$
#   37/CD
#   ]/NN
#   In/IN
#   June/NNP
#   2000/CD
#   ,/,
#   it/PRP
#   was/VBD
#   announced/VBN
#   that/IN
#   (PERSON Google/NNP)
#   would/MD
#   become/VB
#   the/DT
#   default/NN
#   search/NN
#   engine/NN
#   provider/NN
#   for/IN
#   (ORGANIZATION Yahoo/NNP)
#   !,/NNP
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   popular/JJ
#   websites/NNS
#   at/IN
#   the/DT
#   time/NN
#   ,/,
#   replacing/VBG
#   (PERSON Inktomi/NNP)
#   .[/$
#   38/CD
#   ][/$
#   39/CD
#   ]/NNP
#   Palo/NNP
#   Alto/NNP
#   ,/,
#   (GPE California/NNP)
#   [/VBZ
#   34/CD
#   ]/JJ
#   (PERSON Silicon/NNP Valley/NNP)
#   [/VBD
#   35/CD
#   ]/NNP
#   [/VBD
#   36/CD
#   ]/NNP
#   [/VBD
#   13/CD
#   ]/NNP
#   [/VBD
#   37/CD
#   ]/JJ
#   Yahoo/NN
#   !/.
#   (PERSON Inktomi/NNP)
#   [/VBD
#   38/CD
#   ]/NNP
#   [/VBD
#   39/CD
#   ]/NNP
#   [/VBD
#   40/CD
#   ]/NN
#   In/IN
#   2003/CD
#   ,/,
#   after/IN
#   outgrowing/VBG
#   two/CD
#   other/JJ
#   locations/NNS
#   ,/,
#   the/DT
#   company/NN
#   leased/VBD
#   an/DT
#   office/NN
#   complex/NN
#   from/IN
#   (PERSON Silicon/NNP Graphics/NNP)
#   ,/,
#   at/IN
#   1600/CD
#   Amphitheatre/NNP
#   Parkway/NNP
#   in/IN
#   (GPE Mountain/NNP View/NNP)
#   ,/,
#   (GPE California/NNP)
#   .[/VBZ
#   41/CD
#   ]/IN
#   The/DT
#   complex/JJ
#   became/VBD
#   known/VBN
#   as/IN
#   the/DT
#   (ORGANIZATION Googleplex/NNP)
#   ,/,
#   a/DT
#   play/NN
#   on/IN
#   the/DT
#   word/NN
#   googolplex/NN
#   ,/,
#   the/DT
#   number/NN
#   one/CD
#   followed/VBN
#   by/IN
#   a/DT
#   googol/NN
#   zeroes/NN
#   ./.
#   Three/CD
#   years/NNS
#   later/RB
#   ,/,
#   (PERSON Google/NNP)
#   bought/VBD
#   the/DT
#   property/NN
#   from/IN
#   (ORGANIZATION SGI/NNP)
#   for/IN
#   $/$
#   319/CD
#   million/CD
#   .[/JJ
#   42/CD
#   ]/NN
#   By/IN
#   that/DT
#   time/NN
#   ,/,
#   the/DT
#   name/NN
#   "/NNP
#   Google/NNP
#   "/NNP
#   had/VBD
#   found/VBN
#   its/PRP$
#   way/NN
#   into/IN
#   everyday/JJ
#   language/NN
#   ,/,
#   causing/VBG
#   the/DT
#   verb/NN
#   "/NNP
#   google/NN
#   "/NN
#   to/TO
#   be/VB
#   added/VBN
#   to/TO
#   the/DT
#   (ORGANIZATION Merriam/NNP)
#   -/:
#   (PERSON Webster/NN Collegiate/NNP Dictionary/NNP)
#   and/CC
#   the/DT
#   (ORGANIZATION Oxford/NNP English/NNP Dictionary/NNP)
#   ,/,
#   denoted/VBD
#   as/IN
#   :/:
#   "/NN
#   to/TO
#   use/VB
#   the/DT
#   (ORGANIZATION Google/NNP)
#   search/NN
#   engine/NN
#   to/TO
#   obtain/VB
#   information/NN
#   on/IN
#   the/DT
#   Internet/NNP
#   ".[/VBD
#   43/CD
#   ][/JJ
#   44/CD
#   ]/NNP
#   Additionally/NNP
#   ,/,
#   in/IN
#   2001/CD
#   Google/NNP
#   '/POS
#   s/JJ
#   Investors/NNS
#   felt/VBD
#   the/DT
#   need/NN
#   to/TO
#   have/VB
#   a/DT
#   strong/JJ
#   internal/JJ
#   management/NN
#   ,/,
#   and/CC
#   they/PRP
#   agreed/VBD
#   to/TO
#   hire/VB
#   (PERSON Eric/NNP Schmidt/NNP)
#   as/IN
#   the/DT
#   Chairman/NNP
#   and/CC
#   (ORGANIZATION CEO/NNP)
#   of/IN
#   (PERSON Google/NNP)
#   [/NNP
#   45/CD
#   ]/NNP
#   (PERSON Silicon/NNP Graphics/NNP Mountain/NNP View/NNP)
#   ,/,
#   (GPE California/NNP)
#   [/VBZ
#   41/CD
#   ]/NN
#   (ORGANIZATION Googleplex/NNP)
#   googolplex/NN
#   [/VBD
#   42/CD
#   ]/NNP
#   google/NN
#   (PERSON Merriam/NNP)
#   -/:
#   (PERSON
#     Webster/NN
#     Collegiate/NNP
#     Dictionary/NNP
#     Oxford/NNP
#     English/NNP
#     Dictionary/NNP)
#   [/VBD
#   43/CD
#   ]/NNP
#   [/VBD
#   44/CD
#   ]/NNP
#   (PERSON Eric/NNP Schmidt/NNP)
#   [/VBD
#   45/CD
#   ]/JJ
#   Initial/NNP
#   public/JJ
#   offering/NN
#   Initial/NNP
#   public/JJ
#   offering/NN
#   (PERSON Google/NNP)
#   '/POS
#   s/JJ
#   initial/JJ
#   public/JJ
#   offering/NN
#   (/(
#   (ORGANIZATION IPO/NNP)
#   )/)
#   took/VBD
#   place/NN
#   five/CD
#   years/NNS
#   later/RB
#   ,/,
#   on/IN
#   August/NNP
#   19/CD
#   ,/,
#   2004/CD
#   ./.
#   At/IN
#   that/DT
#   time/NN
#   (PERSON Larry/NNP Page/NNP)
#   ,/,
#   (PERSON Sergey/NNP Brin/NNP)
#   ,/,
#   and/CC
#   (PERSON Eric/NNP Schmidt/NNP)
#   agreed/VBD
#   to/TO
#   work/VB
#   together/RB
#   at/IN
#   (ORGANIZATION Google/NNP)
#   for/IN
#   20/CD
#   years/NNS
#   ,/,
#   until/IN
#   the/DT
#   year/NN
#   2024/CD
#   .[/NNP
#   46/CD
#   ]/NN
#   At/IN
#   (ORGANIZATION IPO/NNP)
#   ,/,
#   the/DT
#   company/NN
#   offered/VBD
#   19/CD
#   ,/,
#   605/CD
#   ,/,
#   052/CD
#   shares/NNS
#   at/IN
#   a/DT
#   price/NN
#   of/IN
#   $/$
#   85/CD
#   per/IN
#   share/NN
#   .[/VBZ
#   47/CD
#   ][/NN
#   48/CD
#   ]/JJ
#   Shares/NNS
#   were/VBD
#   sold/VBN
#   in/IN
#   an/DT
#   online/JJ
#   auction/NN
#   format/NN
#   using/VBG
#   a/DT
#   system/NN
#   built/VBN
#   by/IN
#   (PERSON Morgan/NNP Stanley/NNP)
#   and/CC
#   (ORGANIZATION Credit/NNP Suisse/NNP)
#   ,/,
#   underwriters/NNS
#   for/IN
#   the/DT
#   deal/NN
#   .[/VBZ
#   49/CD
#   ][/NN
#   50/CD
#   ]/PDT
#   The/DT
#   sale/NN
#   of/IN
#   $/$
#   1/CD
#   ./.
#   67/CD
#   billion/CD
#   gave/VBD
#   (PERSON Google/NNP)
#   a/DT
#   market/NN
#   capitalization/NN
#   of/IN
#   more/JJR
#   than/IN
#   $/$
#   23/CD
#   billion/CD
#   .[/NNS
#   51/CD
#   ]/JJ
#   initial/JJ
#   public/JJ
#   offering/NN
#   [/$
#   46/CD
#   ]/NNP
#   [/VBD
#   47/CD
#   ]/NNP
#   [/VBD
#   48/CD
#   ]/NNP
#   Morgan/NNP
#   (PERSON Stanley/NNP Credit/NNP Suisse/NNP)
#   [/VBD
#   49/CD
#   ]/NNP
#   [/VBD
#   50/CD
#   ]/JJ
#   market/NN
#   capitalization/NN
#   [/VBD
#   51/CD
#   ]/NNP
#   (PERSON Eric/NNP Schmidt/NNP)
#   In/IN
#   October/NNP
#   2006/CD
#   ,/,
#   (PERSON Google/NNP)
#   announced/VBD
#   that/IN
#   it/PRP
#   had/VBD
#   acquired/VBN
#   the/DT
#   video/NN
#   -/:
#   sharing/VBG
#   site/NN
#   (ORGANIZATION YouTube/NNP)
#   for/IN
#   $/$
#   1/CD
#   ./.
#   65/CD
#   billion/CD
#   in/IN
#   (GPE Google/NNP)
#   stock/NN
#   ,[/VBD
#   52/CD
#   ][/JJ
#   53/CD
#   ]/NN
#   and/CC
#   the/DT
#   deal/NN
#   was/VBD
#   finalized/VBN
#   on/IN
#   November/NNP
#   13/CD
#   ,/,
#   2006/CD
#   .[/VBD
#   54/CD
#   ][/JJ
#   55/CD
#   ]/NN
#   On/IN
#   April/NNP
#   13/CD
#   ,/,
#   2007/CD
#   ,/,
#   (PERSON Google/NNP)
#   reached/VBD
#   an/DT
#   agreement/NN
#   to/TO
#   acquire/VB
#   (ORGANIZATION DoubleClick/NNP)
#   for/IN
#   $/$
#   3/CD
#   ./.
#   1/CD
#   billion/CD
#   ,/,
#   transferring/VBG
#   to/TO
#   (GPE Google/NNP)
#   valuable/JJ
#   relationships/NNS
#   that/WDT
#   (ORGANIZATION DoubleClick/NNP)
#   had/VBD
#   with/IN
#   Web/NNP
#   publishers/NNS
#   and/CC
#   advertising/NN
#   agencies/NNS
#   .[/VBP
#   56/CD
#   ]/NNP
#   [/VBD
#   52/CD
#   ]/NNP
#   [/VBD
#   53/CD
#   ]/NNP
#   [/VBD
#   54/CD
#   ]/NNP
#   [/VBD
#   55/CD
#   ]/NNP
#   DoubleClick/NNP
#   [/NNP
#   56/CD
#   ]/NN
#   In/IN
#   2005/CD
#   ,/,
#   The/DT
#   (ORGANIZATION Washington/NNP Post/NNP)
#   reported/VBD
#   on/IN
#   a/DT
#   700/CD
#   percent/NN
#   increase/NN
#   in/IN
#   third/JJ
#   -/:
#   quarter/NN
#   profit/NN
#   for/IN
#   (PERSON Google/NNP)
#   ,/,
#   largely/RB
#   thanks/NNS
#   to/TO
#   large/JJ
#   companies/NNS
#   shifting/VBG
#   their/PRP$
#   advertising/NN
#   strategies/NNS
#   from/IN
#   newspapers/NNS
#   ,/,
#   magazines/NNS
#   ,/,
#   and/CC
#   television/NN
#   to/TO
#   the/DT
#   Internet/NNP
#   .[/VBD
#   57/CD
#   ]/NNS
#   In/IN
#   May/NNP
#   2011/CD
#   ,/,
#   the/DT
#   number/NN
#   of/IN
#   monthly/JJ
#   unique/JJ
#   visitors/NNS
#   to/TO
#   (PERSON Google/NNP)
#   surpassed/VBD
#   one/CD
#   billion/CD
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   .[/$
#   58/CD
#   ]/NN
#   By/IN
#   2011/CD
#   ,/,
#   (PERSON Google/NNP)
#   was/VBD
#   handling/VBG
#   approximately/RB
#   3/CD
#   billion/CD
#   searches/NNS
#   per/IN
#   day/NN
#   ./.
#   To/TO
#   handle/VB
#   this/DT
#   workload/NN
#   ,/,
#   (PERSON Google/NNP)
#   built/VBD
#   11/CD
#   datacenters/NNS
#   around/IN
#   the/DT
#   world/NN
#   with/IN
#   some/DT
#   several/JJ
#   thousand/CD
#   servers/NNS
#   in/IN
#   each/DT
#   ./.
#   These/DT
#   datacenters/NNS
#   allowed/VBD
#   (PERSON Google/NNP)
#   to/TO
#   handle/VB
#   the/DT
#   ever/RB
#   changing/VBG
#   workload/NN
#   more/RBR
#   efficiently/RB
#   .[/VBZ
#   45/CD
#   ]/NN
#   The/DT
#   (ORGANIZATION Washington/NNP Post/NNP)
#   [/NNP
#   57/CD
#   ]/NNP
#   [/VBD
#   58/CD
#   ]/JJ
#   datacenters/NNS
#   [/VBP
#   45/CD
#   ]/NN
#   On/IN
#   August/NNP
#   15/CD
#   ,/,
#   2011/CD
#   ,/,
#   (PERSON Google/NNP)
#   made/VBD
#   its/PRP$
#   largest/JJS
#   -/:
#   ever/RB
#   acquisition/NN
#   to/TO
#   date/NN
#   when/WRB
#   it/PRP
#   announced/VBD
#   that/IN
#   it/PRP
#   would/MD
#   acquire/VB
#   (ORGANIZATION Motorola/NNP Mobility/NNP)
#   for/IN
#   $/$
#   12/CD
#   ./.
#   5/CD
#   billion/CD
#   [/NNS
#   59/CD
#   ][/$
#   60/CD
#   ]/NN
#   This/DT
#   purchase/NN
#   was/VBD
#   made/VBN
#   in/IN
#   part/NN
#   to/TO
#   help/VB
#   (PERSON Google/NNP)
#   gain/VB
#   (ORGANIZATION Motorola/NNP)
#   '/POS
#   s/NN
#   considerable/JJ
#   patent/NN
#   portfolio/NN
#   on/IN
#   mobile/JJ
#   phones/NNS
#   and/CC
#   wireless/NN
#   technologies/NNS
#   ,/,
#   to/TO
#   help/VB
#   protect/VB
#   (PERSON Google/NNP)
#   in/IN
#   its/PRP$
#   ongoing/JJ
#   patent/NN
#   disputes/NNS
#   with/IN
#   other/JJ
#   companies/NNS
#   ,[/VBP
#   61/CD
#   ]/NNP
#   mainly/RB
#   (PERSON Apple/NNP)
#   and/CC
#   (ORGANIZATION Microsoft/NNP)
#   ,[/NNP
#   62/CD
#   ]/NN
#   and/CC
#   to/TO
#   allow/VB
#   it/PRP
#   to/TO
#   continue/VB
#   to/TO
#   freely/RB
#   offer/VB
#   (PERSON Android/NNP)
#   .[/NNP
#   63/CD
#   ]/NNP
#   Motorola/NNP
#   Mobility/NNP
#   [/NNP
#   59/CD
#   ]/NNP
#   [/VBD
#   60/CD
#   ]/NNP
#   [/VBD
#   61/CD
#   ]/NN
#   (PERSON Apple/NNP Microsoft/NNP)
#   [/VBD
#   62/CD
#   ]/NNP
#   (PERSON Android/NNP)
#   [/VBD
#   63/CD
#   ]/NN
#   2012/CD
#   onward/NN
#   2012/CD
#   onward/IN
#   The/DT
#   year/NN
#   2012/CD
#   was/VBD
#   the/DT
#   first/JJ
#   time/NN
#   that/WDT
#   (PERSON Google/NNP)
#   generated/VBD
#   $/$
#   50/CD
#   billion/CD
#   in/IN
#   annual/JJ
#   revenue/NN
#   ,/,
#   generating/VBG
#   $/$
#   38/CD
#   billion/CD
#   the/DT
#   previous/JJ
#   year/NN
#   ./.
#   In/IN
#   January/NNP
#   2013/CD
#   ,/,
#   then/RB
#   -/:
#   (ORGANIZATION CEO/NN Larry/NNP Page/NNP)
#   commented/VBD
#   ,/,
#   "/IN
#   We/PRP
#   ended/VBD
#   2012/CD
#   with/IN
#   a/DT
#   strong/JJ
#   quarter/NN
#   .../:
#   Revenues/NNS
#   were/VBD
#   up/RB
#   36/CD
#   %/NN
#   year/NN
#   -/:
#   on/IN
#   -/:
#   year/NN
#   ,/,
#   and/CC
#   8/CD
#   %/NN
#   quarter/NN
#   -/:
#   on/IN
#   -/:
#   quarter/NN
#   ./.
#   And/CC
#   we/PRP
#   hit/VBD
#   $/$
#   50/CD
#   billion/CD
#   in/IN
#   revenues/NNS
#   for/IN
#   the/DT
#   first/JJ
#   time/NN
#   last/JJ
#   year/NN
#   –/VBD
#   not/RB
#   a/DT
#   bad/JJ
#   achievement/NN
#   in/IN
#   just/RB
#   a/DT
#   decade/NN
#   and/CC
#   a/DT
#   half/JJ
#   ."[/JJ
#   64/CD
#   ]/JJ
#   [/$
#   64/CD
#   ]/NN
#   In/IN
#   June/NNP
#   2013/CD
#   ,/,
#   (PERSON Google/NNP)
#   acquired/VBD
#   (PERSON Waze/NNP)
#   ,/,
#   a/DT
#   $/$
#   966/CD
#   million/CD
#   deal/NN
#   .[/CC
#   65/CD
#   ]/NNS
#   While/IN
#   (PERSON Waze/NNP)
#   would/MD
#   remain/VB
#   an/DT
#   independent/JJ
#   entity/NN
#   ,/,
#   its/PRP$
#   social/JJ
#   features/NNS
#   ,/,
#   such/JJ
#   as/IN
#   its/PRP$
#   crowdsourced/JJ
#   location/NN
#   platform/NN
#   ,/,
#   were/VBD
#   reportedly/RB
#   valuable/JJ
#   integrations/NNS
#   between/IN
#   (PERSON Waze/NNP)
#   and/CC
#   (PERSON Google/NNP Maps/NNP)
#   ,/,
#   (PERSON Google/NNP)
#   '/POS
#   s/NN
#   own/IN
#   mapping/VBG
#   service/NN
#   .[/VBD
#   66/CD
#   ]/NNP
#   (PERSON Waze/NNP)
#   [/VBD
#   65/CD
#   ]/NNP
#   Google/NNP
#   Maps/NNP
#   [/VBD
#   66/CD
#   ]/NNP
#   (PERSON Google/NNP)
#   announced/VBD
#   the/DT
#   launch/NN
#   of/IN
#   a/DT
#   new/JJ
#   company/NN
#   ,/,
#   called/VBD
#   (GPE Calico/NNP)
#   ,/,
#   on/IN
#   September/NNP
#   19/CD
#   ,/,
#   2013/CD
#   ,/,
#   to/TO
#   be/VB
#   led/VBN
#   by/IN
#   (PERSON Apple/NNP)
#   ,/,
#   (PERSON Inc/NNP)
#   ./.
#   chairman/NN
#   (PERSON Arthur/NNP Levinson/NNP)
#   ./.
#   In/IN
#   the/DT
#   official/JJ
#   public/JJ
#   statement/NN
#   ,/,
#   (PERSON Page/NNP)
#   explained/VBD
#   that/IN
#   the/DT
#   "/NNP
#   health/NN
#   and/CC
#   well/RB
#   -/:
#   being/VBG
#   "/JJ
#   company/NN
#   would/MD
#   focus/VB
#   on/IN
#   "/PDT
#   the/DT
#   challenge/NN
#   of/IN
#   ageing/VBG
#   and/CC
#   associated/VBN
#   diseases/NNS
#   ".[/VBP
#   67/CD
#   ]/JJ
#   (PERSON Calico/NNP Apple/NNP)
#   ,/,
#   (PERSON Inc/NNP)
#   ./.
#   (PERSON Arthur/NNP Levinson/NNP)
#   [/VBD
#   67/CD
#   ]/NN
#   On/IN
#   January/NNP
#   26/CD
#   ,/,
#   2014/CD
#   ,/,
#   (PERSON Google/NNP)
#   announced/VBD
#   it/PRP
#   had/VBD
#   agreed/VBN
#   to/TO
#   acquire/VB
#   (ORGANIZATION DeepMind/NNP Technologies/NNPS)
#   ,/,
#   a/DT
#   privately/RB
#   held/VBN
#   artificial/JJ
#   intelligence/NN
#   company/NN
#   from/IN
#   (GPE London/NNP)
#   .[/$
#   68/CD
#   ]/NNP
#   Technology/NNP
#   news/NN
#   website/NN
#   (PERSON Recode/NNP)
#   reported/VBD
#   that/IN
#   the/DT
#   company/NN
#   was/VBD
#   purchased/VBN
#   for/IN
#   $/$
#   400/CD
#   million/CD
#   though/IN
#   it/PRP
#   was/VBD
#   not/RB
#   disclosed/VBN
#   where/WRB
#   the/DT
#   information/NN
#   came/VBD
#   from/IN
#   ./.
#   A/DT
#   (GPE Google/NNP)
#   spokesman/NN
#   would/MD
#   not/RB
#   comment/VB
#   of/IN
#   the/DT
#   price/NN
#   .[/VBD
#   69/CD
#   ][/JJ
#   70/CD
#   ]/IN
#   The/DT
#   purchase/NN
#   of/IN
#   (ORGANIZATION DeepMind/NNP)
#   aids/NNS
#   in/IN
#   (GPE Google/NNP)
#   '/POS
#   s/JJ
#   recent/JJ
#   growth/NN
#   in/IN
#   the/DT
#   artificial/JJ
#   intelligence/NN
#   and/CC
#   robotics/NNS
#   community/NN
#   .[/VBP
#   71/CD
#   ]/JJ
#   (ORGANIZATION DeepMind/NNP Technologies/NNPS London/NNP)
#   [/VBD
#   68/CD
#   ]/JJ
#   (PERSON Recode/NNP)
#   [/NNP
#   69/CD
#   ]/NNP
#   [/VBD
#   70/CD
#   ]/NNP
#   [/VBD
#   71/CD
#   ]/NN
#   According/VBG
#   to/TO
#   (ORGANIZATION Interbrand/NNP)
#   '/POS
#   s/JJ
#   annual/JJ
#   Best/NNP
#   Global/NNP
#   Brands/NNP
#   report/NN
#   ,/,
#   (PERSON Google/NNP)
#   has/VBZ
#   been/VBN
#   the/DT
#   second/JJ
#   most/RBS
#   valuable/JJ
#   brand/NN
#   in/IN
#   the/DT
#   world/NN
#   (/(
#   behind/IN
#   (PERSON Apple/NNP Inc/NNP)
#   .)/NNP
#   in/IN
#   2013/CD
#   ,[/$
#   72/CD
#   ]/JJ
#   2014/CD
#   ,[/$
#   73/CD
#   ]/JJ
#   2015/CD
#   ,[/$
#   74/CD
#   ]/NN
#   and/CC
#   2016/CD
#   ,/,
#   with/IN
#   a/DT
#   valuation/NN
#   of/IN
#   $/$
#   133/CD
#   billion/CD
#   .[/NNS
#   75/CD
#   ]/JJ
#   (ORGANIZATION Interbrand/NNP Apple/NNP Inc/NNP)
#   ./.
#   [/CC
#   72/CD
#   ]/JJ
#   [/$
#   73/CD
#   ]/NNP
#   [/VBD
#   74/CD
#   ]/NNP
#   [/VBD
#   75/CD
#   ]/NN
#   On/IN
#   August/NNP
#   10/CD
#   ,/,
#   2015/CD
#   ,/,
#   (PERSON Google/NNP)
#   announced/VBD
#   plans/NNS
#   to/TO
#   reorganize/VB
#   its/PRP$
#   various/JJ
#   interests/NNS
#   as/IN
#   a/DT
#   conglomerate/NN
#   called/VBN
#   (GPE Alphabet/NNP)
#   ./.
#   (PERSON Google/NNP)
#   became/VBD
#   (PERSON Alphabet/NNP)
#   '/POS
#   s/JJ
#   leading/VBG
#   subsidiary/NN
#   ,/,
#   and/CC
#   will/MD
#   continue/VB
#   to/TO
#   be/VB
#   the/DT
#   umbrella/JJ
#   company/NN
#   for/IN
#   (ORGANIZATION Alphabet/NNP)
#   '/POS
#   s/JJ
#   Internet/NNP
#   interests/NNS
#   ./.
#   Upon/IN
#   completion/NN
#   of/IN
#   the/DT
#   restructure/NN
#   ,/,
#   (PERSON Sundar/NNP Pichai/NNP)
#   became/VBD
#   (ORGANIZATION CEO/NNP)
#   of/IN
#   (GPE Google/NNP)
#   ,/,
#   replacing/VBG
#   (PERSON Larry/NNP Page/NNP)
#   ,/,
#   who/WP
#   became/VBD
#   (ORGANIZATION CEO/NNP)
#   of/IN
#   (ORGANIZATION Alphabet/NNP)
#   .[/NNP
#   76/CD
#   ][/VBD
#   77/CD
#   ][/JJ
#   78/CD
#   ]/JJ
#   conglomerate/NN
#   (PERSON Alphabet/NNP Sundar/NNP Pichai/NNP Larry/NNP Page/NNP)
#   [/VBD
#   76/CD
#   ]/NNP
#   [/VBD
#   77/CD
#   ]/NNP
#   [/VBD
#   78/CD
#   ]/NNP
#   As/IN
#   of/IN
#   October/NNP
#   2016/CD
#   ,[/NNP
#   update/JJ
#   ]/NNP
#   Google/NNP
#   operates/VBZ
#   70/CD
#   offices/NNS
#   in/IN
#   more/JJR
#   than/IN
#   40/CD
#   countries/NNS
#   .[/VBP
#   79/CD
#   ]/JJ
#   (PERSON Alexa/NNP)
#   ,/,
#   a/DT
#   company/NN
#   that/WDT
#   monitors/VBZ
#   commercial/JJ
#   web/NN
#   traffic/NN
#   ,/,
#   lists/VBZ
#   (PERSON Google/NNP)
#   ./.
#   com/NN
#   as/IN
#   the/DT
#   most/RBS
#   visited/JJ
#   website/NN
#   in/IN
#   the/DT
#   world/NN
#   .[/VBZ
#   9/CD
#   ]/JJ
#   Several/NNP
#   other/JJ
#   Google/NNP
#   services/NNS
#   also/RB
#   figure/VBP
#   in/IN
#   the/DT
#   top/JJ
#   100/CD
#   most/JJS
#   visited/JJ
#   websites/NNS
#   ,/,
#   including/VBG
#   (ORGANIZATION YouTube/NNP)
#   [/$
#   80/CD
#   ]/NN
#   and/CC
#   (PERSON Blogger/NNP)
#   .[/VBP
#   81/CD
#   ]/JJ
#   [/NNP
#   update/NN
#   ]/NNP
#   [/VBZ
#   79/CD
#   ]/NN
#   (PERSON Alexa/NNP)
#   [/VBZ
#   9/CD
#   ]/NN
#   [/VBD
#   80/CD
#   ]/NNP
#   [/VBD
#   81/CD
#   ]/NN
#   On/IN
#   August/NNP
#   8/CD
#   ,/,
#   2017/CD
#   ,/,
#   (PERSON Google/NNP)
#   fired/VBD
#   employee/NN
#   (PERSON James/NNP Damore/NNP)
#   after/IN
#   he/PRP
#   distributed/VBD
#   a/DT
#   memo/NN
#   throughout/IN
#   the/DT
#   company/NN
#   which/WDT
#   argued/VBD
#   that/IN
#   "/NNP
#   (PERSON Google/NNP)
#   '/POS
#   s/JJ
#   ideological/JJ
#   echo/JJ
#   chamber/NN
#   "/NNP
#   and/CC
#   bias/RB
#   clouded/VBD
#   their/PRP$
#   thinking/NN
#   about/IN
#   diversity/NN
#   and/CC
#   inclusion/NN
#   ,/,
#   and/CC
#   that/IN
#   it/PRP
#   is/VBZ
#   also/RB
#   biological/JJ
#   factors/NNS
#   ,/,
#   not/RB
#   discrimination/NN
#   alone/RB
#   ,/,
#   that/IN
#   cause/VBP
#   the/DT
#   average/JJ
#   woman/NN
#   to/TO
#   be/VB
#   less/RBR
#   interested/JJ
#   than/IN
#   men/NNS
#   in/IN
#   technical/JJ
#   positions/NNS
#   .[/VBP
#   82/CD
#   ]/JJ
#   (PERSON Google/NNP CEO/NNP Sundar/NNP Pichai/NNP)
#   accused/VBD
#   (GPE Damore/NNP)
#   in/IN
#   violating/VBG
#   company/NN
#   policy/NN
#   by/IN
#   "/NNP
#   advancing/VBG
#   harmful/JJ
#   gender/NN
#   stereotypes/NNS
#   in/IN
#   our/PRP$
#   workplace/NN
#   ",/NN
#   and/CC
#   he/PRP
#   was/VBD
#   fired/VBN
#   on/IN
#   the/DT
#   same/JJ
#   day/NN
#   .[/VBD
#   83/CD
#   ][/JJ
#   84/CD
#   ][/JJ
#   85/CD
#   ]/JJ
#   (GPE New/NNP York/NNP Times/NNP)
#   columnist/NN
#   (PERSON David/NNP Brooks/NNP)
#   argued/VBD
#   (PERSON Pichai/NNP)
#   had/VBD
#   mishandled/VBN
#   the/DT
#   case/NN
#   ,/,
#   and/CC
#   called/VBD
#   for/IN
#   his/PRP$
#   resignation/NN
#   .[/VBZ
#   86/CD
#   ][/NN
#   87/CD
#   ]/JJ
#   (PERSON Google/NNP)
#   '/POS
#   s/JJ
#   ideological/JJ
#   echo/JJ
#   chamber/NN
#   [/VBD
#   82/CD
#   ]/NNP
#   [/VBD
#   83/CD
#   ]/NNP
#   [/VBD
#   84/CD
#   ]/NNP
#   [/VBD
#   85/CD
#   ]/NN
#   (PERSON David/NNP Brooks/NNP)
#   [/VBD
#   86/CD
#   ]/NNP
#   [/VBD
#   87/CD
#   ]/NNS
#   On/IN
#   October/NNP
#   25/CD
#   ,/,
#   2018/CD
#   ,/,
#   The/DT
#   (GPE New/NNP York/NNP Times/NNP)
#   published/VBD
#   the/DT
#   exposé/NN
#   ,/,
#   "/VB
#   (PERSON How/NNP Google/NNP Protected/NNP)
#   (PERSON Andy/NNP Rubin/NNP)
#   ,/,
#   the/DT
#   ‘/NNP
#   Father/NNP
#   of/IN
#   (PERSON Android/NNP)
#   ’"./VBD
#   The/DT
#   company/NN
#   subsequently/RB
#   announced/VBD
#   that/IN
#   "/$
#   48/CD
#   employees/NNS
#   have/VBP
#   been/VBN
#   fired/VBN
#   over/IN
#   the/DT
#   last/JJ
#   two/CD
#   years/NNS
#   "/VBP
#   for/IN
#   sexual/JJ
#   misconduct/NN
#   .[/VBZ
#   88/CD
#   ]/NN
#   On/IN
#   November/NNP
#   1/CD
#   ,/,
#   2018/CD
#   ,/,
#   more/JJR
#   than/IN
#   20/CD
#   ,/,
#   000/CD
#   Google/NNP
#   employees/NNS
#   and/CC
#   contractors/NNS
#   staged/VBD
#   a/DT
#   global/JJ
#   walk/NN
#   -/:
#   out/IN
#   to/TO
#   protest/VB
#   the/DT
#   company/NN
#   '/POS
#   s/NN
#   handling/NN
#   of/IN
#   sexual/JJ
#   harassment/NN
#   complaints/NNS
#   .[/VBP
#   89/CD
#   ][/$
#   90/CD
#   ]/NNP
#   The/DT
#   (GPE New/NNP York/NNP)
#   (PERSON Times/NNP Andy/NNP Rubin/NNP)
#   [/VBD
#   88/CD
#   ]/NNP
#   [/VBD
#   89/CD
#   ]/NNP
#   [/VBD
#   90/CD
#   ]/NN
#   On/IN
#   March/NNP
#   19/CD
#   ,/,
#   2019/CD
#   ,/,
#   (PERSON Google/NNP)
#   announced/VBD
#   that/IN
#   it/PRP
#   would/MD
#   enter/VB
#   the/DT
#   video/NN
#   game/NN
#   market/NN
#   ,/,
#   launching/VBG
#   a/DT
#   cloud/NN
#   gaming/VBG
#   platform/NN
#   called/VBN
#   (PERSON Google/NNP Stadia/NNP)
#   .[/NNP
#   91/CD
#   ]/NNP
#   cloud/NN
#   gaming/VBG
#   (PERSON Google/NNP Stadia/NNP)
#   [/NNP
#   91/CD
#   ]/NN
#   On/IN
#   June/NNP
#   3/CD
#   ,/,
#   2019/CD
#   ,/,
#   the/DT
#   (GPE United/NNP States/NNPS)
#   Department/NNP
#   of/IN
#   (ORGANIZATION Justice/NNP)
#   reported/VBD
#   that/IN
#   it/PRP
#   would/MD
#   investigate/VB
#   (PERSON Google/NNP)
#   for/IN
#   antitrust/JJ
#   violations/NNS
#   .[/VBP
#   92/CD
#   ]/NNS
#   (GPE United/NNP States/NNPS)
#   Department/NNP
#   of/IN
#   (ORGANIZATION Justice/NNP)
#   antitrust/JJ
#   [/NN
#   92/CD
#   ]/NN
#   Products/NNPS
#   and/CC
#   services/NNS
#   Products/NNPS
#   and/CC
#   services/NNS
#   List/NNP
#   of/IN
#   (GPE Google/NNP)
#   products/NNS
#   Search/NNP
#   engine/NN
#   Search/NNP
#   engine/NN
#   (PERSON Google/NNP Search/NNP Google/NNP Images/NNP)
#   [/NNP
#   update/JJ
#   ]/NNP
#   Google/NNP
#   indexes/JJ
#   billions/NNS
#   of/IN
#   web/JJ
#   pages/NNS
#   to/TO
#   allow/VB
#   users/NNS
#   to/TO
#   search/VB
#   for/IN
#   the/DT
#   information/NN
#   they/PRP
#   desire/VBP
#   through/IN
#   the/DT
#   use/NN
#   of/IN
#   keywords/NNS
#   and/CC
#   operators/NNS
#   .[/VBP
#   93/CD
#   ]/JJ
#   According/VBG
#   to/TO
#   (ORGANIZATION comScore/NN)
#   market/NN
#   research/NN
#   from/IN
#   November/NNP
#   2009/CD
#   ,/,
#   (PERSON Google/NNP Search/NNP)
#   is/VBZ
#   the/DT
#   dominant/JJ
#   search/NN
#   engine/NN
#   in/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   market/NN
#   ,/,
#   with/IN
#   a/DT
#   market/NN
#   share/NN
#   of/IN
#   65/CD
#   ./.
#   6/CD
#   %.[/JJ
#   94/CD
#   ]/NNS
#   In/IN
#   May/NNP
#   2017/CD
#   ,/,
#   (PERSON Google/NNP)
#   enabled/VBD
#   a/DT
#   new/JJ
#   "/NNP
#   Personal/NNP
#   "/NNP
#   tab/NN
#   in/IN
#   (GPE Google/NNP Search/NNP)
#   ,/,
#   letting/VBG
#   users/NNS
#   search/VBP
#   for/IN
#   content/NN
#   in/IN
#   their/PRP$
#   Google/NNP
#   accounts/NNS
#   '/POS
#   various/JJ
#   services/NNS
#   ,/,
#   including/VBG
#   email/JJ
#   messages/NNS
#   from/IN
#   (GPE Gmail/NNP)
#   and/CC
#   photos/NNS
#   from/IN
#   (PERSON Google/NNP Photos/NNP)
#   .[/VBZ
#   95/CD
#   ][/NN
#   96/CD
#   ]/NN
#   indexes/NNS
#   operators/NNS
#   [/VBP
#   93/CD
#   ]/NNS
#   comScore/RB
#   (PERSON Google/NNP Search/NNP)
#   market/NN
#   share/NN
#   [/VBZ
#   94/CD
#   ]/NN
#   (PERSON Gmail/NNP Google/NNP Photos/NNP)
#   [/VBZ
#   95/CD
#   ]/NN
#   [/VBD
#   96/CD
#   ]/NNP
#   (PERSON Google/NNP)
#   launched/VBD
#   its/PRP$
#   (ORGANIZATION Google/NNP News/NNP)
#   service/NN
#   in/IN
#   2002/CD
#   ,/,
#   an/DT
#   automated/VBN
#   service/NN
#   which/WDT
#   summarizes/VBZ
#   news/NN
#   articles/NNS
#   from/IN
#   various/JJ
#   websites/NNS
#   .[/VBP
#   97/CD
#   ]/NNP
#   Google/NNP
#   also/RB
#   hosts/VBZ
#   (PERSON Google/NNP Books/NNP)
#   ,/,
#   a/DT
#   service/NN
#   which/WDT
#   searches/VBZ
#   the/DT
#   text/NN
#   found/VBD
#   in/IN
#   books/NNS
#   in/IN
#   its/PRP$
#   database/NN
#   and/CC
#   shows/NNS
#   limited/VBN
#   previews/NNS
#   or/CC
#   and/CC
#   the/DT
#   full/JJ
#   book/NN
#   where/WRB
#   allowed/VBN
#   .[/$
#   98/CD
#   ]/NNP
#   Google/NNP
#   News/NNP
#   [/VBD
#   97/CD
#   ]/NNP
#   Google/NNP
#   (PERSON Books/NNP)
#   [/VBD
#   98/CD
#   ]/JJ
#   Advertising/NNP
#   Advertising/NNP
#   As/IN
#   per/IN
#   its/PRP$
#   2017/CD
#   Annual/NNP
#   report/NN
#   ,/,
#   (PERSON Google/NNP)
#   generates/VBZ
#   most/JJS
#   of/IN
#   its/PRP$
#   revenues/NNS
#   from/IN
#   advertising/NN
#   ./.
#   This/DT
#   includes/VBZ
#   sales/NNS
#   of/IN
#   apps/NN
#   ,/,
#   purchases/NNS
#   made/VBN
#   in/IN
#   -/:
#   app/NN
#   ,/,
#   digital/JJ
#   content/NN
#   products/NNS
#   on/IN
#   google/NN
#   and/CC
#   (ORGANIZATION YouTube/NNP)
#   ,/,
#   android/NN
#   and/CC
#   licensing/NN
#   and/CC
#   service/NN
#   fees/NNS
#   ,/,
#   including/VBG
#   fees/NNS
#   received/VBD
#   for/IN
#   (PERSON Google/NNP Cloud/NNP)
#   offerings/NNS
#   ./.
#   46/CD
#   %/NN
#   of/IN
#   this/DT
#   was/VBD
#   from/IN
#   clicks/NNS
#   (/(
#   cost/NN
#   per/IN
#   clicks/NNS
#   ),/VBP
#   amounting/VBG
#   to/TO
#   (GSP US/NNP)
#   $/$
#   109/CD
#   ,/,
#   652/CD
#   million/CD
#   in/IN
#   2017/CD
#   ./.
#   This/DT
#   includes/VBZ
#   three/CD
#   principal/NN
#   methods/NNS
#   ,/,
#   namely/RB
#   (ORGANIZATION AdMob/NNP)
#   ,/,
#   (ORGANIZATION AdSense/NNP)
#   (/(
#   such/JJ
#   as/IN
#   (ORGANIZATION AdSense/NNP)
#   for/IN
#   (ORGANIZATION Content/NNP)
#   ,/,
#   (ORGANIZATION AdSense/NNP)
#   for/IN
#   (GPE Search/NNP)
#   ,/,
#   etc/FW
#   .)/FW
#   and/CC
#   (ORGANIZATION DoubleClick/NNP)
#   (ORGANIZATION AdExchange/NNP)
#   .[/NNP
#   99/CD
#   ]/NNP
#   (ORGANIZATION AdMob/NNP)
#   AdSense/NNP
#   AdSense/NNP
#   [/VBD
#   99/CD
#   ]/NN
#   For/IN
#   the/DT
#   2006/CD
#   fiscal/JJ
#   year/NN
#   ,/,
#   the/DT
#   company/NN
#   reported/VBD
#   $/$
#   10/CD
#   ./.
#   492/CD
#   billion/CD
#   in/IN
#   total/JJ
#   advertising/NN
#   revenues/NNS
#   and/CC
#   only/RB
#   $/$
#   112/CD
#   million/CD
#   in/IN
#   licensing/NN
#   and/CC
#   other/JJ
#   revenues/NNS
#   .[/VBP
#   100/CD
#   ]/NN
#   In/IN
#   2011/CD
#   ,/,
#   96/CD
#   %/NN
#   of/IN
#   (PERSON Google/NNP)
#   '/POS
#   s/NN
#   revenue/NN
#   was/VBD
#   derived/VBN
#   from/IN
#   its/PRP$
#   advertising/NN
#   programs/NNS
#   .[/VBP
#   101/CD
#   ]/NN
#   In/IN
#   addition/NN
#   to/TO
#   its/PRP$
#   own/JJ
#   algorithms/NN
#   for/IN
#   understanding/VBG
#   search/NN
#   requests/NNS
#   ,/,
#   (PERSON Google/NNP)
#   uses/VBZ
#   technology/NN
#   from/IN
#   the/DT
#   company/NN
#   (ORGANIZATION DoubleClick/NNP)
#   ,/,
#   to/TO
#   project/VB
#   user/JJ
#   interest/NN
#   and/CC
#   target/NN
#   advertising/NN
#   to/TO
#   the/DT
#   search/NN
#   context/NN
#   and/CC
#   the/DT
#   user/JJ
#   history/NN
#   .[/$
#   102/CD
#   ][/$
#   103/CD
#   ]/NNP
#   [/VBD
#   100/CD
#   ]/NNP
#   [/VBD
#   101/CD
#   ]/NNP
#   DoubleClick/NNP
#   [/NNP
#   102/CD
#   ]/NNP
#   [/VBD
#   103/CD
#   ]/NN
#   In/IN
#   2007/CD
#   ,/,
#   (PERSON Google/NNP)
#   launched/VBD
#   "/NNP
#   AdSense/NNP
#   for/IN
#   (PERSON Mobile/NNP)
#   ",/NNP
#   taking/VBG
#   advantage/NN
#   of/IN
#   the/DT
#   emerging/VBG
#   mobile/JJ
#   advertising/NN
#   market/NN
#   .[/VBD
#   104/CD
#   ]/JJ
#   (ORGANIZATION AdSense/NNP)
#   for/IN
#   Mobile/NNP
#   [/$
#   104/CD
#   ]/NNP
#   Google/NNP
#   Analytics/NNP
#   allows/VBZ
#   website/NN
#   owners/NNS
#   to/TO
#   track/VB
#   where/WRB
#   and/CC
#   how/WRB
#   people/NNS
#   use/VBP
#   their/PRP$
#   website/NN
#   ,/,
#   for/IN
#   example/NN
#   by/IN
#   examining/VBG
#   click/JJ
#   rates/NNS
#   for/IN
#   all/PDT
#   the/DT
#   links/NNS
#   on/IN
#   a/DT
#   page/NN
#   .[/VBZ
#   105/CD
#   ]/NN
#   Google/NNP
#   advertisements/NNS
#   can/MD
#   be/VB
#   placed/VBN
#   on/IN
#   third/JJ
#   -/:
#   party/NN
#   websites/NNS
#   in/IN
#   a/DT
#   two/CD
#   -/:
#   part/NN
#   program/NN
#   ./.
#   (PERSON Google/NNP)
#   '/POS
#   s/NN
#   (ORGANIZATION AdWords/NNS)
#   allows/VBZ
#   advertisers/NNS
#   to/TO
#   display/VB
#   their/PRP$
#   advertisements/NNS
#   in/IN
#   the/DT
#   (ORGANIZATION Google/NNP)
#   content/NN
#   network/NN
#   ,/,
#   through/IN
#   a/DT
#   cost/NN
#   -/:
#   per/IN
#   -/:
#   click/NN
#   scheme/NN
#   .[/VBD
#   106/CD
#   ]/IN
#   The/DT
#   sister/NN
#   service/NN
#   ,/,
#   (PERSON Google/NNP AdSense/NNP)
#   ,/,
#   allows/VBZ
#   website/NN
#   owners/NNS
#   to/TO
#   display/VB
#   these/DT
#   advertisements/NNS
#   on/IN
#   their/PRP$
#   website/NN
#   and/CC
#   earn/VB
#   money/NN
#   every/DT
#   time/NN
#   ads/NNS
#   are/VBP
#   clicked/VBN
#   .[/JJ
#   107/CD
#   ]/JJ
#   One/CD
#   of/IN
#   the/DT
#   criticisms/NNS
#   of/IN
#   this/DT
#   program/NN
#   is/VBZ
#   the/DT
#   possibility/NN
#   of/IN
#   click/NN
#   fraud/NN
#   ,/,
#   which/WDT
#   occurs/VBZ
#   when/WRB
#   a/DT
#   person/NN
#   or/CC
#   automated/VBN
#   script/NN
#   clicks/NNS
#   on/IN
#   advertisements/NNS
#   without/IN
#   being/VBG
#   interested/JJ
#   in/IN
#   the/DT
#   product/NN
#   ,/,
#   causing/VBG
#   the/DT
#   advertiser/NN
#   to/TO
#   pay/VB
#   money/NN
#   to/TO
#   (PERSON Google/NNP)
#   unduly/RB
#   ./.
#   Industry/NN
#   reports/NNS
#   in/IN
#   2006/CD
#   claimed/VBD
#   that/IN
# ...
#   (GPE American/NNP)
#   corporate/JJ
#   subsidiaries/NNS
#   Webarchive/VBP
#   template/JJ
#   wayback/NN
#   (ORGANIZATION linksWebarchive/JJ)
#   template/NN
#   webcite/NN
#   (ORGANIZATION linksCS1/JJ)
#   maint/NN
#   :/:
#   Multiple/JJ
#   names/NNS
#   :/:
#   authors/NNS
#   listCS1/VBP
#   maint/NN
#   :/:
#   Archived/JJ
#   copy/NN
#   as/IN
#   (ORGANIZATION titleCS1/JJ)
#   maint/NN
#   :/:
#   BOT/NN
#   :/:
#   original/JJ
#   -/:
#   url/JJ
#   status/NN
#   unknownWebarchive/JJ
#   template/NN
#   archiveis/NN
#   linksPages/VBZ
#   containing/VBG
#   links/NNS
#   to/TO
#   subscription/VB
#   -/:
#   only/RB
#   contentWikipedia/VB
#   indefinitely/RB
#   semi/JJ
#   -/:
#   protected/JJ
#   (ORGANIZATION pagesWikipedia/NN)
#   indefinitely/RB
#   move/VB
#   -/:
#   protected/JJ
#   pagesArticles/NNS
#   with/IN
#   short/JJ
#   descriptionUse/NNS
#   (ORGANIZATION American/JJ English/NNP)
#   from/IN
#   July/NNP
#   2018All/CD
#   Wikipedia/NNP
#   articles/NNS
#   written/VBN
#   in/IN
#   (GPE American/NNP)
#   (ORGANIZATION EnglishUse/NNP)
#   mdy/NN
#   dates/NNS
#   from/IN
#   April/NNP
#   2019Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   2015All/CD
#   articles/NNS
#   containing/VBG
#   potentially/RB
#   dated/VBN
#   statementsArticles/NNS
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   December/NNP
#   2018Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   2017Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   October/NNP
#   2016Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   April/NNP
#   2019Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   August/NNP
#   2015Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   1998Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   June/NNP
#   2017Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   2007Articles/CD
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   February/NNP
#   2009Portal/CD
#   templates/NNS
#   with/IN
#   redlinked/JJ
#   (ORGANIZATION portalsCrunchbase/NN)
#   template/NN
#   with/IN
#   organization/NN
#   IDOpenCorporates/NNS
#   groupingsWikipedia/VBP
#   articles/NNS
#   with/IN
#   (ORGANIZATION BIBSYS/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION BNF/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION GND/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION ISNI/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION LCCN/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION NKC/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION NLA/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION SELIBR/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION SUDOC/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION VIAF/NNP)
#   identifiersWikipedia/NN
#   articles/NNS
#   with/IN
#   (ORGANIZATION WorldCat/NNP)
#   -/:
#   (ORGANIZATION VIAF/NN)
#   identifiers/NNS
#   Webarchive/VBP
#   template/JJ
#   wayback/NN
#   links/NNS
#   Webarchive/JJ
#   template/NN
#   webcite/JJ
#   links/NNS
#   (ORGANIZATION CS1/NNP)
#   maint/NN
#   :/:
#   Multiple/JJ
#   names/NNS
#   :/:
#   authors/NNS
#   list/VBP
#   (ORGANIZATION CS1/NNP)
#   maint/NN
#   :/:
#   Archived/JJ
#   copy/NN
#   as/IN
#   title/NN
#   (ORGANIZATION CS1/NNP)
#   maint/NN
#   :/:
#   BOT/NN
#   :/:
#   original/JJ
#   -/:
#   url/JJ
#   status/NN
#   unknown/JJ
#   Webarchive/NNP
#   template/NN
#   archiveis/NN
#   links/NNS
#   Pages/NNS
#   containing/VBG
#   links/NNS
#   to/TO
#   subscription/VB
#   -/:
#   only/RB
#   content/JJ
#   Wikipedia/NNP
#   indefinitely/RB
#   semi/VBD
#   -/:
#   protected/VBN
#   pages/NNS
#   (PERSON Wikipedia/NNP)
#   indefinitely/RB
#   move/VBP
#   -/:
#   protected/VBN
#   pages/NNS
#   (PERSON Articles/NNP)
#   with/IN
#   short/JJ
#   description/NN
#   Use/NNP
#   (ORGANIZATION American/JJ English/NNP)
#   from/IN
#   July/NNP
#   2018/CD
#   All/NNP
#   Wikipedia/NNP
#   articles/NNS
#   written/VBN
#   in/IN
#   (GPE American/NNP)
#   English/NNP
#   Use/NNP
#   mdy/FW
#   dates/NNS
#   from/IN
#   April/NNP
#   2019/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   2015/CD
#   All/DT
#   articles/NNS
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   Articles/NNPS
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   December/NNP
#   2018/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   2017/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   October/NNP
#   2016/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   April/NNP
#   2019/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   August/NNP
#   2015/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   1998/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   June/NNP
#   2017/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   2007/CD
#   Articles/NNP
#   containing/VBG
#   potentially/RB
#   dated/JJ
#   statements/NNS
#   from/IN
#   February/NNP
#   2009/CD
#   (GPE Portal/NNP)
#   templates/NNS
#   with/IN
#   redlinked/JJ
#   portals/NNS
#   Crunchbase/NNP
#   template/NN
#   with/IN
#   organization/NN
#   (ORGANIZATION ID/NNP)
#   OpenCorporates/NNP
#   groupings/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION BIBSYS/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION BNF/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION GND/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION ISNI/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION LCCN/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION NKC/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION NLA/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION SELIBR/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION SUDOC/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION VIAF/NNP)
#   identifiers/NNS
#   (GPE Wikipedia/NNP)
#   articles/NNS
#   with/IN
#   (ORGANIZATION WorldCat/NNP)
#   -/:
#   (ORGANIZATION VIAF/NNP)
#   identifiers/NNS
#   (PERSON Navigation/NNP)
#   menu/VBD
#   Personal/NNP
#   tools/NNS
#   Not/RB
#   logged/VBN
#   (ORGANIZATION inTalkContributionsCreate/NN)
#   (ORGANIZATION accountLog/NN)
#   in/IN
#   (GPE Talk/NNP)
#   Contributions/NNP
#   Create/NNP
#   account/NN
#   Log/NNP
#   in/IN
#   (GPE Namespaces/NNP)
#   ArticleTalk/NNP
#   (PERSON
#     Article/NNP
#     Article/NNP
#     Talk/NNP
#     Talk/NNP
#     Variants/NNP
#     Variants/NNP
#     Views/NNP)
#   ReadView/NNP
#   sourceView/VBP
#   history/NN
#   (PERSON Read/NNP Read/NNP View/NNP)
#   source/NN
#   View/NNP
#   source/NN
#   View/NNP
#   history/NN
#   View/NNP
#   history/NN
#   More/NNP
#   More/NNP
#   Search/NNP
#   Navigation/NNP
#   Main/NNP
#   pageContentsFeatured/VBD
#   (ORGANIZATION contentCurrent/JJ)
#   (ORGANIZATION eventsRandom/NN)
#   (ORGANIZATION articleDonate/NN)
#   to/TO
#   (ORGANIZATION WikipediaWikipedia/NNP)
#   store/NN
#   (GPE Main/NNP)
#   page/NN
#   Contents/NNS
#   Featured/VBD
#   content/JJ
#   Current/NNP
#   events/NNS
#   (PERSON Random/NNP)
#   article/NN
#   (ORGANIZATION Donate/NNP)
#   to/TO
#   (PERSON Wikipedia/NNP Wikipedia/NNP)
#   store/NN
#   (ORGANIZATION Interaction/NNP)
#   HelpAbout/NNP
#   WikipediaCommunity/NNP
#   portalRecent/NN
#   changesContact/NN
#   page/NN
#   Help/VBP
#   About/IN
#   (PERSON Wikipedia/NNP Community/NNP)
#   portal/JJ
#   Recent/NNP
#   changes/NNS
#   Contact/NNP
#   page/NN
#   Tools/NNP
#   What/WP
#   links/VBZ
#   hereRelated/VBN
#   (ORGANIZATION changesUpload/JJ)
#   (ORGANIZATION fileSpecial/JJ)
#   (ORGANIZATION pagesPermanent/NN)
#   (ORGANIZATION linkPage/NN)
#   (ORGANIZATION informationWikidata/NN)
#   (ORGANIZATION itemCite/NN)
#   this/DT
#   page/NN
#   What/WP
#   links/VBZ
#   here/RB
#   Related/VBN
#   changes/NNS
#   (PERSON Upload/NNP)
#   file/NN
#   Special/NNP
#   pages/NNS
#   Permanent/NNP
#   link/NN
#   Page/NNP
#   information/NN
#   (PERSON Wikidata/NNP)
#   item/NN
#   Cite/NNP
#   this/DT
#   page/NN
#   In/IN
#   other/JJ
#   projects/NNS
#   (PERSON Wikimedia/NNP)
#   (ORGANIZATION CommonsMeta/NNP)
#   -/:
#   (ORGANIZATION
#     WikiWikiquoteWikiversity/NNP
#     Wikimedia/NNP
#     Commons/NNP
#     Meta/NNP)
#   -/:
#   (PERSON Wiki/NNP Wikiquote/NNP Wikiversity/NNP Print/NNP)
#   //NNP
#   export/NN
#   Create/NNP
#   a/DT
#   bookDownload/NN
#   as/IN
#   (ORGANIZATION PDFPrintable/JJ)
#   version/NN
#   Create/NNP
#   a/DT
#   book/NN
#   Download/NNP
#   as/IN
#   (ORGANIZATION PDF/NNP)
#   Printable/NNP
#   version/NN
#   (PERSON Languages/NNP AfrikaansአማርኛÆngliscالعربيةঅসম/NNP)
#   ী/NNP
#   য/NNP
#   ়া/NNP
#   AsturianuAzərbaycancaتۆرکجهBamanankanব/NNP
#   াং/NNP
#   ল/NNP
#   া/NNP
#   (PERSON Bahasa/NNP BanjarBân/NNP)
#   -/:
#   lâm/NN
#   -/:
#   (ORGANIZATION gúБеларускаяБеларуская/NN)
#   (/(
#   тарашкевіца/JJ
#   )‎/NNP
#   भ/NNP
#   ो/NNP
#   जप/NNP
#   ु/NNP
#   र/NNP
#   ी/NNP
#   БългарскиBoarischBosanskiBrezhonegCatalàЧӑвашлаCebuanoČeštinaCymraegDanskDeutschDolnoserbskiड/NNP
#   ो/NNP
#   ट/NNP
#   े/NNP
#   ल/NNP
#   ी/NNP
#   EestiΕλληνικάEspañolEsperantoEuskaraفارسیFøroysktFrançaisGaeilgeGalego贛語ગ/NNP
#   ુ/NNP
#   જર/NNP
#   ા/NNP
#   ત/NNP
#   ી/NNP
#   客家語/NNP
#   //NNP
#   Hak/NNP
#   -/:
#   kâ/NN
#   -/:
#   (ORGANIZATION ngî한국어Հայերենह/NN)
#   ि/JJ
#   न/NNP
#   ्/NNP
#   द/NNP
#   ी/NNP
#   HornjoserbsceHrvatskiBahasa/NNP
#   HulontaloIdoBahasa/NNP
#   Indonesiaᐃᓄᒃᑎᑐᑦ/NNP
#   //NNP
#   inuktitutÍslenskaItalianoעבריתJawaKabɩyɛಕನ/NN
#   ್/NNP
#   ನಡქართულიҚазақшаKirundiKreyòl/NNP
#   ayisyenKurdîКыргызчаລາວلۊری/VBZ
#   (ORGANIZATION شومالیLatinaLatviešuLietuviųMagyarम/NNP)
#   ै/NNP
#   थ/NNP
#   ि/NNP
#   ल/NNP
#   ी/NNP
#   МакедонскиMalagasyമലയ/NNP
#   ാ/NNP
#   ള/NNP
#   ം/NNP
#   मर/NNP
#   ा/NNP
#   ठ/NNP
#   ी/NNP
#   მარგალურიمصرىماز/NNP
#   ِ/NNP
#   رونیBahasa/NNP
#   (ORGANIZATION MelayuMìng/NNP)
#   -/:
#   dĕ/NN
#   ̤/NN
#   ng/SYM
#   -/:
#   ngṳ/JJ
#   ̄/NNP
#   (PERSON Монголမ/NNP)
#   ြ/NNP
#   န/NNP
#   ်/NNP
#   မ/NNP
#   ာ/NNP
#   ဘ/NNP
#   ာ/NNP
#   သ/NNP
#   ာ/NNP
#   NāhuatlNederlandsन/NNP
#   े/NNP
#   प/NNP
#   ा/NNP
#   ल/NNP
#   ी/NNP
#   日本語NorskNorsk/NNP
#   nynorskOccitanଓଡ/MD
#   ଼ି/VB
#   (ORGANIZATION ଆOʻzbekcha/NNP)
#   //NNP
#   ўзбекчаਪ/NNP
#   ੰ/NNP
#   ਜ/NNP
#   ਾ/NNP
#   ਬ/NNP
#   ੀ/NNP
#   پنجابیپښتوភ/NNP
#   ា/NNP
#   ស/NNP
#   ា/NNP
#   ខ/NNP
#   ្/NNP
#   ម/NNP
#   ែ/NNP
#   រPiemontèisPlattdüütschPolskiPortuguêsQaraqalpaqshaRomânăRuna/NNP
#   SimiРусскийСаха/NNP
#   тылаᱥᱟᱱᱛᱟᱲᱤScotsShqipSicilianuස/NNP
#   ිං/NNP
#   හලSimple/NNP
#   EnglishسنڌيSlovenčinaSlovenščinaSoomaaligaکوردیСрпски/NNP
#   //NNP
#   srpskiSrpskohrvatski/VBD
#   //NNP
#   српскохрватскиBasa/NNP
#   SundaSuomiSvenskaTagalogதம/NNP
#   ி/NNP
#   ழ/NNP
#   ்/NNP
#   (PERSON Татарча/NNP)
#   //NNP
#   tatarçaత/NN
#   ె/NNP
#   ల/NNP
#   ు/NNP
#   గ/NNP
#   ు/NNP
#   TetunไทยТоҷикӣತ/NNP
#   ು/NNP
#   ಳ/NNP
#   ು/NNP
#   TürkçeTürkmençeThuɔŋjäŋУкраїнськаاردوئۇيغۇرچە/NNP
#   //NNP
#   UyghurcheVènetoTiếng/NNP
#   (ORGANIZATION ViệtWalon文言West/NNP)
#   -/:
#   (ORGANIZATION VlamsWinaray吴语יי/NNP)
#   ִ/NNP
#   דישYorùbá粵語ZazakiZeêuwsŽemaitėška中文/NNP
#   Afrikaans/NNP
#   አማርኛ/NNP
#   (PERSON Ænglisc/NNP العربية/NNP)
#   অসম/NNP
#   ী/NNP
#   য/NNP
#   ়া/NNP
#   Asturianu/NNP
#   Azərbaycanca/NNP
#   تۆرکجه/NNP
#   Bamanankan/NNP
#   ব/NNP
#   াং/NNP
#   ল/NNP
#   া/NNP
#   (PERSON Bahasa/NNP Banjar/NNP Bân/NNP)
#   -/:
#   lâm/NN
#   -/:
#   gú/NN
#   (PERSON Беларуская/NN Беларуская/NNP)
#   (/(
#   тарашкевіца/NNP
#   )‎/NNP
#   भ/NNP
#   ो/NNP
#   जप/NNP
#   ु/NNP
#   र/NNP
#   ी/NNP
#   Български/NNP
#   Boarisch/NNP
#   Bosanski/NNP
#   Brezhoneg/NNP
#   (PERSON
#     Català/NNP
#     Чӑвашла/NNP
#     Cebuano/NNP
#     Čeština/NNP
#     Cymraeg/NNP
#     Dansk/NNP
#     Deutsch/NNP
#     Dolnoserbski/NNP)
#   ड/NNP
#   ो/NNP
#   ट/NNP
#   े/NNP
#   ल/NNP
#   ी/NNP
#   Eesti/NNP
#   Ελληνικά/NNP
#   (PERSON Español/NNP Esperanto/NNP Euskara/NNP)
#   فارسی/NNP
#   Føroyskt/NNP
#   Français/NNP
#   (PERSON Gaeilge/NNP Galego/NNP 贛語/NNP)
#   ગ/NNP
#   ુ/NNP
#   જર/NNP
#   ા/NNP
#   ત/NNP
#   ી/NNP
#   客家語/NNP
#   //NNP
#   Hak/NNP
#   -/:
#   kâ/NN
#   -/:
#   ngî/NN
#   (ORGANIZATION 한국어/JJ Հայերեն/NNP)
#   ह/NNP
#   ि/NNP
#   न/NNP
#   ्/NNP
#   द/NNP
#   ी/NNP
#   Hornjoserbsce/NNP
#   (PERSON
#     Hrvatski/NNP
#     Bahasa/NNP
#     Hulontalo/NNP
#     Ido/NNP
#     Bahasa/NNP
#     Indonesia/NNP)
#   ᐃᓄᒃᑎᑐᑦ/NNP
#   //NNP
#   inuktitut/NN
#   (PERSON Íslenska/NNP Italiano/NNP)
#   עברית/NNP
#   Jawa/NNP
#   (PERSON Kabɩyɛ/NNP ಕನ/NNP)
#   ್/NNP
#   ನಡ/NNP
#   ქართული/NNP
#   (PERSON Қазақша/NNP Kirundi/NNP Kreyòl/NNP)
#   ayisyen/JJ
#   (PERSON Kurdî/NNP Кыргызча/NNP)
#   ລາວ/NNP
#   لۊری/NNP
#   شومالی/NNP
#   (PERSON Latina/NNP Latviešu/NNP Lietuvių/NNP Magyar/NNP)
#   म/NNP
#   ै/NNP
#   थ/NNP
#   ि/NNP
#   ल/NNP
#   ी/NNP
#   Македонски/NNP
#   (PERSON Malagasy/NNP മലയ/NNP)
#   ാ/NNP
#   ള/NNP
#   ം/NNP
#   मर/NNP
#   ा/NNP
#   ठ/NNP
#   ी/NNP
#   მარგალური/NNP
#   مصرى/NNP
#   ماز/NNP
#   ِ/NNP
#   رونی/NNP
#   (PERSON Bahasa/NNP Melayu/NNP Mìng/NNP)
#   -/:
#   dĕ/NN
#   ̤/NN
#   ng/SYM
#   -/:
#   ngṳ/JJ
#   ̄/NNP
#   (PERSON Монгол/NNP)
#   မ/NNP
#   ြ/NNP
#   န/NNP
#   ်/NNP
#   မ/NNP
#   ာ/NNP
#   ဘ/NNP
#   ာ/NNP
#   သ/NNP
#   ာ/NNP
#   (PERSON Nāhuatl/NNP Nederlands/NNP)
#   न/NNP
#   े/NNP
#   प/NNP
#   ा/NNP
#   ल/NNP
#   ी/NNP
#   日本語/NNP
#   Norsk/NNP
#   Norsk/NNP
#   nynorsk/JJ
#   (PERSON Occitan/NNP ଓଡ/NNP)
#   ଼ି/NNP
#   ଆ/NNP
#   Oʻzbekcha/NNP
#   //NNP
#   ўзбекча/NNP
#   ਪ/NNP
#   ੰ/NNP
#   ਜ/NNP
#   ਾ/NNP
#   ਬ/NNP
#   ੀ/NNP
#   پنجابی/NNP
#   پښتو/NNP
#   ភ/NNP
#   ា/NNP
#   ស/NNP
#   ា/NNP
#   ខ/NNP
#   ្/NNP
#   ម/NNP
#   ែ/NNP
#   រ/NNP
#   Piemontèis/NNP
#   Plattdüütsch/NNP
#   Polski/NNP
#   (PERSON
#     Português/NNP
#     Qaraqalpaqsha/NNP
#     Română/NNP
#     Runa/NNP
#     Simi/NNP
#     Русский/NNP
#     Саха/NNP)
#   тыла/NNP
#   ᱥᱟᱱᱛᱟᱲᱤ/NNP
#   Scots/NNP
#   Shqip/NNP
#   Sicilianu/NNP
#   ස/NNP
#   ිං/NNP
#   හල/NNP
#   Simple/NNP
#   English/NNP
#   سنڌي/NNP
#   (PERSON Slovenčina/NNP Slovenščina/NNP Soomaaliga/NNP)
#   کوردی/NNP
#   (PERSON Српски/NNP)
#   //NNP
#   srpski/VBD
#   (PERSON Srpskohrvatski/NNP)
#   //NNP
#   српскохрватски/NNP
#   Basa/NNP
#   Sunda/NNP
#   Suomi/NNP
#   (PERSON Svenska/NNP Tagalog/NNP தம/NNP)
#   ி/NNP
#   ழ/NNP
#   ்/NNP
#   (PERSON Татарча/NNP)
#   //NNP
#   tatarça/NN
#   త/NNP
#   ె/NNP
#   ల/NNP
#   ు/NNP
#   గ/NNP
#   ు/NNP
#   Tetun/NNP
#   ไทย/NNP
#   (PERSON Тоҷикӣ/NNP)
#   ತ/NNP
#   ು/NNP
#   ಳ/NNP
#   ು/NNP
#   (PERSON Türkçe/NNP Türkmençe/NNP Thuɔŋjäŋ/NNP Українська/NNP)
#   اردو/NNP
#   ئۇيغۇرچە/NNP
#   //NNP
#   (PERSON
#     Uyghurche/NNP
#     Vèneto/NNP
#     Tiếng/NNP
#     Việt/NNP
#     Walon/NNP
#     文言/NNP
#     West/NNP)
#   -/:
#   (PERSON Vlams/NNP Winaray/NNP 吴语/NNP יי/NNP)
#   ִ/NNP
#   דיש/NNP
#   Yorùbá/NNP
#   粵語/NNP
#   (PERSON Zazaki/NNP Zeêuws/NNP Žemaitėška/NNP 中文/NNP Edit/NNP)
#   links/VBZ
#   (ORGANIZATION Edit/NNP)
#   links/NNS
#   This/DT
#   page/NN
#   was/VBD
#   last/JJ
#   edited/VBN
#   on/IN
#   16/CD
#   June/NNP
#   2019/CD
#   ,/,
#   at/IN
#   18/CD
#   :/:
#   31/CD
#   (/(
#   (ORGANIZATION UTC/NNP)
#   )./NNP
#   Text/NNP
#   is/VBZ
#   available/JJ
#   under/IN
#   the/DT
#   (ORGANIZATION Creative/JJ Commons/NNPS Attribution/NNP)
#   -/:
#   (ORGANIZATION ShareAlike/NNP License/NNP)
#   ;/:
#   additional/JJ
#   terms/NNS
#   may/MD
#   apply/VB
#   ./.
#   By/IN
#   using/VBG
#   this/DT
#   site/NN
#   ,/,
#   you/PRP
#   agree/VBP
#   to/TO
#   the/DT
#   Terms/NNS
#   of/IN
#   (ORGANIZATION Use/NNP)
#   and/CC
#   (ORGANIZATION Privacy/NNP Policy/NNP)
#   ./.
#   (PERSON Wikipedia/NNP)
#   ®/NNP
#   is/VBZ
#   a/DT
#   registered/JJ
#   trademark/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Wikimedia/NNP Foundation/NNP)
#   ,/,
#   (PERSON Inc/NNP)
#   .,/VBZ
#   a/DT
#   non/JJ
#   -/:
#   profit/NN
#   organization/NN
#   ./.
#   (/(
#   (ORGANIZATION UTC/NNP)
#   )/)
#   (ORGANIZATION Creative/NNP Commons/NNPS Attribution/NNP)
#   -/:
#   (ORGANIZATION
#     ShareAlike/NN
#     License/NNP
#     Terms/NNS
#     of/IN
#     Use/NNP
#     Privacy/NNP
#     Policy/NNP
#     Wikimedia/NNP
#     Foundation/NNP)
#   ,/,
#   (PERSON Inc/NNP)
#   ./.
#   Privacy/NN
#   policy/NN
#   About/IN
#   (PERSON
#     Wikipedia/NNP
#     Disclaimers/NNP
#     Contact/NNP
#     Wikipedia/NNP
#     Developers/NNP
#     Cookie/NNP)
#   statement/NN
#   Mobile/NNP
#   view/NN
#   Privacy/NN
#   policy/NN
#   About/IN
#   (PERSON
#     Wikipedia/NNP
#     Disclaimers/NNP
#     Contact/NNP
#     Wikipedia/NNP
#     Developers/NNP
#     Cookie/NNP)
#   statement/NN
#   Mobile/NNP
#   view/NN)

# %%
from sklearn.datasets import fetch_20newsgroups

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier 

twenty_train = fetch_20newsgroups(subset='train', shuffle=True)

tfidf_Vect = TfidfVectorizer()
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)
clf = KNeighborsClassifier()
clf.fit(X_train_tfidf, twenty_train.target)

twenty_test = fetch_20newsgroups(subset='test', shuffle=True)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

predicted = clf.predict(X_test_tfidf)

score = metrics.accuracy_score(twenty_test.target, predicted)
print('using KNeighborsClassifier')
print(score)
print('_____________________________')

from sklearn.datasets import fetch_20newsgroups

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier 

twenty_train = fetch_20newsgroups(subset='train', shuffle=True)

tfidf_Vect = TfidfVectorizer(ngram_range=(1,2))
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)
clf = KNeighborsClassifier()
clf.fit(X_train_tfidf, twenty_train.target)

twenty_test = fetch_20newsgroups(subset='test', shuffle=True)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

predicted = clf.predict(X_test_tfidf)

score = metrics.accuracy_score(twenty_test.target, predicted)
print('using bigram')
print(score)
print('_____________________________')

from sklearn.datasets import fetch_20newsgroups

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier 

twenty_train = fetch_20newsgroups(subset='train', shuffle=True)

tfidf_Vect = TfidfVectorizer(stop_words='english')
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)
clf = KNeighborsClassifier()
clf.fit(X_train_tfidf, twenty_train.target)

twenty_test = fetch_20newsgroups(subset='test', shuffle=True)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

predicted = clf.predict(X_test_tfidf)

score = metrics.accuracy_score(twenty_test.target, predicted)
print('using stop words')
print(score)
print('_____________________________')
# Out:
# using KNeighborsClassifier
# 0.6591874668082847
# _____________________________
# using bigram
# 0.6196229421136484
# _____________________________
# using stop words
# 0.6757833244822092
# _____________________________
